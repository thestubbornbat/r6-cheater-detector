# %%
data = """
{
    "bans": [
        {
            "profile": {
                "userId": "e656cd62-898d-4556-af24-be01439d3346",
                "profileId": "e656cd62-898d-4556-af24-be01439d3346",
                "displayName": "vroyyyy",
                "platform": "uplay",
                "level": 105,
                "headshotRate": 57.1232249198,
                "leaderboardPosition": 2671,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1439,
                            "deaths": 1084,
                            "wins": 167,
                            "losses": 91,
                            "abandons": 4,
                            "rankPoints": 1000,
                            "maxRankPoints": 4511,
                            "maxTopRankPosition": 2775,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:40.140Z",
                "fetchedAt": "2025-04-03T06:32:40.044Z"
            },
            "createdAt": "2025-04-03T04:56:24.378Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ea4abcf4-1c57-4df7-9108-c9d489d88d48",
                "profileId": "ea4abcf4-1c57-4df7-9108-c9d489d88d48",
                "displayName": "zHnzT02-_",
                "platform": "uplay",
                "level": 83,
                "headshotRate": 56.0356652949,
                "leaderboardPosition": 1626,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 706,
                            "deaths": 424,
                            "wins": 71,
                            "losses": 28,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4573,
                            "maxTopRankPosition": 1294,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-03T01:37:49.732Z",
                "fetchedAt": "2025-04-03T01:37:49.656Z"
            },
            "createdAt": "2025-04-03T04:56:24.378Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6fdd6697-4c99-4506-9689-f1239b6f5f2a",
                "profileId": "6fdd6697-4c99-4506-9689-f1239b6f5f2a",
                "displayName": "DerE4sy",
                "platform": "uplay",
                "level": 76,
                "headshotRate": 55.6910569106,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 136,
                            "deaths": 85,
                            "wins": 16,
                            "losses": 4,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2855,
                            "rank": "unranked",
                            "maxRank": "gold-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:40.140Z",
                "fetchedAt": "2025-04-03T06:32:40.044Z"
            },
            "createdAt": "2025-04-03T04:56:24.378Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "df7359e0-077b-4fcc-9c9f-335c52776610",
                "profileId": "df7359e0-077b-4fcc-9c9f-335c52776610",
                "displayName": "ononoqinusihe",
                "platform": "uplay",
                "level": 69,
                "headshotRate": 54.128440367,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 359,
                            "deaths": 186,
                            "wins": 27,
                            "losses": 20,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2285,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:37:11.998Z",
                "fetchedAt": "2025-04-03T06:37:11.922Z"
            },
            "createdAt": "2025-04-03T04:46:28.278Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1d599cec-2349-42fe-ae37-2f6dc064541c",
                "profileId": "1d599cec-2349-42fe-ae37-2f6dc064541c",
                "displayName": "NeYRaZ",
                "platform": "uplay",
                "level": 223,
                "headshotRate": 53.1316725979,
                "leaderboardPosition": 3791,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1401,
                            "deaths": 987,
                            "wins": 143,
                            "losses": 93,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 4526,
                            "maxTopRankPosition": 2659,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:10.598Z",
                "fetchedAt": "2025-04-03T06:22:10.503Z"
            },
            "createdAt": "2025-04-03T04:46:28.278Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d20d6d7e-ef34-498d-92e4-43878bc0bf46",
                "profileId": "d20d6d7e-ef34-498d-92e4-43878bc0bf46",
                "displayName": "iConnieXD",
                "platform": "uplay",
                "level": 86,
                "headshotRate": 55.9625212947,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:40.352Z",
                "fetchedAt": "2025-04-03T06:32:40.281Z"
            },
            "createdAt": "2025-04-03T04:46:28.278Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d2284010-8303-47b5-b0b4-a5d3b8af2024",
                "profileId": "d2284010-8303-47b5-b0b4-a5d3b8af2024",
                "displayName": "Polkita-",
                "platform": "uplay",
                "level": 103,
                "headshotRate": 54.0322580645,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 74,
                            "deaths": 64,
                            "wins": 10,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1962,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:02.954Z",
                "fetchedAt": "2025-04-03T06:22:02.862Z"
            },
            "createdAt": "2025-04-03T04:46:28.278Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7f08add5-b540-463b-9570-73533dfb8045",
                "profileId": "7f08add5-b540-463b-9570-73533dfb8045",
                "displayName": "xXburger123Xx",
                "platform": "uplay",
                "level": 64,
                "headshotRate": 38.5674931129,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 423,
                            "deaths": 249,
                            "wins": 40,
                            "losses": 21,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3058,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:42.030Z",
                "fetchedAt": "2025-04-03T06:32:41.934Z"
            },
            "createdAt": "2025-04-03T04:36:25.156Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e8986c81-2141-4312-bcf9-49748e67ef6c",
                "profileId": "e8986c81-2141-4312-bcf9-49748e67ef6c",
                "displayName": "SiegeXH",
                "platform": "uplay",
                "level": 50,
                "headshotRate": 63.3393829401,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:38.240Z",
                "fetchedAt": "2025-04-03T06:32:38.176Z"
            },
            "createdAt": "2025-04-03T04:36:25.156Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "057daf05-518b-4c4e-a587-324788511d8b",
                "profileId": "057daf05-518b-4c4e-a587-324788511d8b",
                "displayName": "ORWASTAKEN",
                "platform": "uplay",
                "level": 114,
                "headshotRate": 53.5283993115,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:40.966Z",
                "fetchedAt": "2025-04-03T06:32:40.904Z"
            },
            "createdAt": "2025-04-03T04:36:25.156Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "30a8c4ef-21cc-4378-a101-6426b9a1e5cb",
                "profileId": "30a8c4ef-21cc-4378-a101-6426b9a1e5cb",
                "displayName": "howdoiexplain",
                "platform": "uplay",
                "level": 92,
                "headshotRate": 55.1410373066,
                "leaderboardPosition": 9975,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 480,
                            "deaths": 539,
                            "wins": 58,
                            "losses": 49,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 3775,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:02.787Z",
                "fetchedAt": "2025-04-03T06:22:02.692Z"
            },
            "createdAt": "2025-04-03T04:36:25.156Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1cb92a45-14c4-4c36-bb10-c5aa2aa3d140",
                "profileId": "1cb92a45-14c4-4c36-bb10-c5aa2aa3d140",
                "displayName": "asdfxdhaha",
                "platform": "uplay",
                "level": 69,
                "headshotRate": 52.2884882108,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 456,
                            "deaths": 325,
                            "wins": 56,
                            "losses": 25,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4178,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:06.655Z",
                "fetchedAt": "2025-04-03T06:22:06.516Z"
            },
            "createdAt": "2025-04-03T04:26:25.121Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d427fd81-726e-4a62-be01-bf946fead98c",
                "profileId": "d427fd81-726e-4a62-be01-bf946fead98c",
                "displayName": "RMCO.",
                "platform": "uplay",
                "level": 68,
                "headshotRate": 50.5217391304,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:06.655Z",
                "fetchedAt": "2025-04-03T06:22:06.516Z"
            },
            "createdAt": "2025-04-03T04:26:25.121Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "aeeaa16f-3ebb-4e79-9253-a1026d3b48ef",
                "profileId": "aeeaa16f-3ebb-4e79-9253-a1026d3b48ef",
                "displayName": "bruninho10.",
                "platform": "uplay",
                "level": 108,
                "headshotRate": 62.1807465619,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:10.714Z",
                "fetchedAt": "2025-04-03T06:22:10.650Z"
            },
            "createdAt": "2025-04-03T04:26:25.121Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a825c3de-f967-44a8-8cd9-2066f08821e0",
                "profileId": "a825c3de-f967-44a8-8cd9-2066f08821e0",
                "displayName": "vSxrgio.exe",
                "platform": "uplay",
                "level": 120,
                "headshotRate": 51.0114702815,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 245,
                            "deaths": 97,
                            "wins": 20,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3260,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:39.985Z",
                "fetchedAt": "2025-04-03T06:32:39.861Z"
            },
            "createdAt": "2025-04-03T04:26:25.121Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2eee1067-f7a4-4a2c-b303-e701d4f6ba9f",
                "profileId": "2eee1067-f7a4-4a2c-b303-e701d4f6ba9f",
                "displayName": "Aviestz.",
                "platform": "uplay",
                "level": 54,
                "headshotRate": 57.0117955439,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:39.668Z",
                "fetchedAt": "2025-04-03T06:32:39.574Z"
            },
            "createdAt": "2025-04-03T04:16:28.747Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8fbd224b-9d96-4700-a3aa-2d17e98252fc",
                "profileId": "8fbd224b-9d96-4700-a3aa-2d17e98252fc",
                "displayName": "qwerttyuyiojhb",
                "platform": "uplay",
                "level": 18,
                "headshotRate": 46.511627907,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:02.622Z",
                "fetchedAt": "2025-04-03T06:22:02.539Z"
            },
            "createdAt": "2025-04-03T04:16:28.747Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "82dae9e2-c45a-49e9-836a-c0cdc0492f25",
                "profileId": "82dae9e2-c45a-49e9-836a-c0cdc0492f25",
                "displayName": "tkyo.M80",
                "platform": "uplay",
                "level": 72,
                "headshotRate": 57.7861163227,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 169,
                            "deaths": 129,
                            "wins": 21,
                            "losses": 11,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2474,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:36:18.260Z",
                "fetchedAt": "2025-04-03T06:36:18.154Z"
            },
            "createdAt": "2025-04-03T04:16:28.747Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c0b12fc3-7f27-459e-89a2-e42cf99d86e8",
                "profileId": "c0b12fc3-7f27-459e-89a2-e42cf99d86e8",
                "displayName": "Clapzzzz__",
                "platform": "uplay",
                "level": 149,
                "headshotRate": 53.2439678284,
                "leaderboardPosition": 9996,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 97,
                            "deaths": 92,
                            "wins": 6,
                            "losses": 11,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1635,
                            "rank": "unranked",
                            "maxRank": "bronze-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:10.714Z",
                "fetchedAt": "2025-04-03T06:22:10.650Z"
            },
            "createdAt": "2025-04-03T04:16:28.747Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e0ae5415-d717-4cf8-aff8-6cfb335b4061",
                "profileId": "e0ae5415-d717-4cf8-aff8-6cfb335b4061",
                "displayName": "IlIlIlI23480",
                "platform": "uplay",
                "level": 74,
                "headshotRate": 60.9259259259,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:02.622Z",
                "fetchedAt": "2025-04-03T06:22:02.539Z"
            },
            "createdAt": "2025-04-03T04:06:25.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1b41b98f-b53e-4804-85f8-d52dacda4590",
                "profileId": "1b41b98f-b53e-4804-85f8-d52dacda4590",
                "displayName": "CheeseHub..",
                "platform": "uplay",
                "level": 122,
                "headshotRate": 71.0451977401,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 149,
                            "deaths": 43,
                            "wins": 14,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2665,
                            "rank": "unranked",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:40.140Z",
                "fetchedAt": "2025-04-03T06:32:40.044Z"
            },
            "createdAt": "2025-04-03T04:06:25.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a9abdf8e-b713-4d8a-a5a5-d132edc011d1",
                "profileId": "a9abdf8e-b713-4d8a-a5a5-d132edc011d1",
                "displayName": "king-of-rice",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 31.1688311688,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:21:58.753Z",
                "fetchedAt": "2025-04-03T06:21:58.676Z"
            },
            "createdAt": "2025-04-03T04:06:25.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "061754ab-5b91-4547-ba40-79e73fd6b6fc",
                "profileId": "061754ab-5b91-4547-ba40-79e73fd6b6fc",
                "displayName": "fittetaco",
                "platform": "uplay",
                "level": 45,
                "headshotRate": 59.9067599068,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:40.234Z",
                "fetchedAt": "2025-04-03T06:32:40.169Z"
            },
            "createdAt": "2025-04-03T04:06:25.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e56e1d67-9572-4631-8a14-70b8fefbcea2",
                "profileId": "e56e1d67-9572-4631-8a14-70b8fefbcea2",
                "displayName": "Ademsyy",
                "platform": "uplay",
                "level": 23,
                "headshotRate": 58.7064676617,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:36:11.978Z",
                "fetchedAt": "2025-04-03T06:36:11.898Z"
            },
            "createdAt": "2025-04-03T03:56:26.020Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2b4fbaf9-d954-4bfc-8a82-742a5c47b32d",
                "profileId": "2b4fbaf9-d954-4bfc-8a82-742a5c47b32d",
                "displayName": "mXKwithTryaCup",
                "platform": "uplay",
                "level": 88,
                "headshotRate": 61.9986403807,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 500,
                            "deaths": 383,
                            "wins": 45,
                            "losses": 54,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3876,
                            "rank": "unranked",
                            "maxRank": "emerald-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:21:58.703Z",
                "fetchedAt": "2025-04-03T06:21:58.579Z"
            },
            "createdAt": "2025-04-03T03:56:26.020Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4e68552e-6756-4dc6-a296-dd4a424a401b",
                "profileId": "4e68552e-6756-4dc6-a296-dd4a424a401b",
                "displayName": "w2ffle",
                "platform": "uplay",
                "level": 80,
                "headshotRate": 56.5003080715,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 398,
                            "deaths": 279,
                            "wins": 43,
                            "losses": 18,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4208,
                            "rank": "unranked",
                            "maxRank": "diamond-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:41.168Z",
                "fetchedAt": "2025-04-03T06:32:41.104Z"
            },
            "createdAt": "2025-04-03T03:56:26.020Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f9f94256-68a1-4906-9f03-8fcd0f939340",
                "profileId": "f9f94256-68a1-4906-9f03-8fcd0f939340",
                "displayName": "abo3losh.",
                "platform": "uplay",
                "level": 155,
                "headshotRate": 51.1591231667,
                "leaderboardPosition": 9846,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 335,
                            "deaths": 116,
                            "wins": 30,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3937,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:03.113Z",
                "fetchedAt": "2025-04-03T06:22:03.030Z"
            },
            "createdAt": "2025-04-03T03:56:26.020Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1cc1afdc-9540-495a-aef6-ad5b0f8d6cbb",
                "profileId": "3cbcca12-73bf-4301-a23c-602d1dbda4b3",
                "displayName": "Myndzs",
                "platform": "xbl",
                "level": 115,
                "headshotRate": 45.4398273071,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:21:58.703Z",
                "fetchedAt": "2025-04-03T06:21:58.579Z"
            },
            "createdAt": "2025-04-03T03:56:26.020Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b297a48f-db54-4bfc-9b10-4c0834165c04",
                "profileId": "b297a48f-db54-4bfc-9b10-4c0834165c04",
                "displayName": "Encite",
                "platform": "uplay",
                "level": 146,
                "headshotRate": 50.0818124607,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 448,
                            "deaths": 208,
                            "wins": 40,
                            "losses": 13,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3540,
                            "rank": "unranked",
                            "maxRank": "emerald-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:38.794Z",
                "fetchedAt": "2025-04-03T06:32:38.719Z"
            },
            "createdAt": "2025-04-03T03:56:26.020Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "83579870-50b6-4fe8-9e8e-7bbece443266",
                "profileId": "83579870-50b6-4fe8-9e8e-7bbece443266",
                "displayName": "DIDDYSPLAYLAND",
                "platform": "uplay",
                "level": 61,
                "headshotRate": 44.4295302013,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:33:55.990Z",
                "fetchedAt": "2025-04-03T06:33:55.887Z"
            },
            "createdAt": "2025-04-03T03:46:29.203Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "693a8038-5f40-41c5-9a85-974f01eaca1e",
                "profileId": "693a8038-5f40-41c5-9a85-974f01eaca1e",
                "displayName": "sereyonce",
                "platform": "uplay",
                "level": 88,
                "headshotRate": 53.125,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 333,
                            "deaths": 268,
                            "wins": 42,
                            "losses": 25,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3200,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:36:05.197Z",
                "fetchedAt": "2025-04-03T06:36:05.029Z"
            },
            "createdAt": "2025-04-03T03:46:29.203Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "87de4e6c-307a-4ffe-8e4b-477f45f00490",
                "profileId": "87de4e6c-307a-4ffe-8e4b-477f45f00490",
                "displayName": "O.06KD",
                "platform": "uplay",
                "level": 121,
                "headshotRate": 37.8996499417,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 89,
                            "deaths": 85,
                            "wins": 7,
                            "losses": 12,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1345,
                            "rank": "unranked",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:39.592Z",
                "fetchedAt": "2025-04-03T06:32:39.495Z"
            },
            "createdAt": "2025-04-03T03:46:29.203Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2f91e9a6-425b-488b-8e1b-9ba88f66f26d",
                "profileId": "2f91e9a6-425b-488b-8e1b-9ba88f66f26d",
                "displayName": "Neitroengine",
                "platform": "uplay",
                "level": 32,
                "headshotRate": 73.1428571429,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:40.140Z",
                "fetchedAt": "2025-04-03T06:32:40.044Z"
            },
            "createdAt": "2025-04-03T03:36:25.019Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a61f508e-e0a7-46e0-86dd-638edf670b58",
                "profileId": "a61f508e-e0a7-46e0-86dd-638edf670b58",
                "displayName": "znji-",
                "platform": "uplay",
                "level": 53,
                "headshotRate": 52.808988764,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 22,
                            "deaths": 8,
                            "wins": 1,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1105,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:02.954Z",
                "fetchedAt": "2025-04-03T06:22:02.862Z"
            },
            "createdAt": "2025-04-03T03:36:25.019Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6367e864-989f-4f9f-b0b0-8e8f0a92ebc5",
                "profileId": "6367e864-989f-4f9f-b0b0-8e8f0a92ebc5",
                "displayName": "D147z",
                "platform": "uplay",
                "level": 111,
                "headshotRate": 47.1020408163,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:06.723Z",
                "fetchedAt": "2025-04-03T06:22:06.612Z"
            },
            "createdAt": "2025-04-03T03:36:25.019Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f9171c9c-2e30-4bb9-80db-0041f9ddd5e4",
                "profileId": "f9171c9c-2e30-4bb9-80db-0041f9ddd5e4",
                "displayName": "dokiG2ssss",
                "platform": "uplay",
                "level": 58,
                "headshotRate": 58.813559322,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 62,
                            "deaths": 30,
                            "wins": 10,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1979,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:34:49.268Z",
                "fetchedAt": "2025-04-03T06:34:49.192Z"
            },
            "createdAt": "2025-04-03T03:26:26.005Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d928366d-eb02-4fca-88f9-1838d88951d2",
                "profileId": "6057206e-1525-4614-803e-a38e0a5234df",
                "displayName": "gardien-faste",
                "platform": "psn",
                "level": 115,
                "headshotRate": 43.2908912831,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:10.714Z",
                "fetchedAt": "2025-04-03T06:22:10.650Z"
            },
            "createdAt": "2025-04-03T03:26:26.005Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c52a14f8-ddb8-40f4-9191-367519c94a09",
                "profileId": "c52a14f8-ddb8-40f4-9191-367519c94a09",
                "displayName": "DNdexx",
                "platform": "uplay",
                "level": 65,
                "headshotRate": 57.8406169666,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 238,
                            "deaths": 143,
                            "wins": 26,
                            "losses": 9,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3072,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:36:03.007Z",
                "fetchedAt": "2025-04-03T06:36:02.927Z"
            },
            "createdAt": "2025-04-03T03:26:26.005Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c0c7a3f9-c6e2-45b8-ac72-bd65518150a9",
                "profileId": "c0c7a3f9-c6e2-45b8-ac72-bd65518150a9",
                "displayName": "beans.and.toast",
                "platform": "uplay",
                "level": 145,
                "headshotRate": 47.1504307488,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 227,
                            "deaths": 161,
                            "wins": 20,
                            "losses": 17,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3139,
                            "rank": "unranked",
                            "maxRank": "platinum-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:41.285Z",
                "fetchedAt": "2025-04-03T06:32:41.192Z"
            },
            "createdAt": "2025-04-03T03:26:26.005Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a118994e-d904-40f5-b890-ba142fe40923",
                "profileId": "a118994e-d904-40f5-b890-ba142fe40923",
                "displayName": "dqvid_s7",
                "platform": "uplay",
                "level": 145,
                "headshotRate": 52.4031007752,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:21:58.703Z",
                "fetchedAt": "2025-04-03T06:21:58.579Z"
            },
            "createdAt": "2025-04-03T03:26:26.005Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d928366d-eb02-4fca-88f9-1838d88951d2",
                "profileId": "d928366d-eb02-4fca-88f9-1838d88951d2",
                "displayName": "BluePoliceBox54",
                "platform": "uplay",
                "level": 115,
                "headshotRate": 43.2908912831,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 20,
                            "deaths": 18,
                            "wins": 4,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1406,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:33:36.013Z",
                "fetchedAt": "2025-04-03T06:33:35.932Z"
            },
            "createdAt": "2025-04-03T03:26:26.005Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "33acff4f-12be-450a-b816-98a115e00706",
                "profileId": "33acff4f-12be-450a-b816-98a115e00706",
                "displayName": "exodia.....",
                "platform": "uplay",
                "level": 80,
                "headshotRate": 51.0917030568,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 85,
                            "deaths": 77,
                            "wins": 9,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1534,
                            "maxRankPoints": 1534,
                            "rank": "bronze-5",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-03-26T05:25:38.010Z",
                "fetchedAt": "2025-03-26T05:25:37.935Z"
            },
            "createdAt": "2025-04-03T03:16:29.716Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7baf3863-ec8c-4ede-83b3-ea22ff3ae704",
                "profileId": "eaabec72-7bbe-444b-a8a1-6a8a544a80d9",
                "displayName": "X1M_IS-C00L",
                "platform": "psn",
                "level": 86,
                "headshotRate": 44.8951048951,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:42.030Z",
                "fetchedAt": "2025-04-03T06:32:41.934Z"
            },
            "createdAt": "2025-04-03T03:06:25.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "be298ba4-f18d-43d7-b13b-7d3f4f4edaed",
                "profileId": "be298ba4-f18d-43d7-b13b-7d3f4f4edaed",
                "displayName": "Matth_M_O_N_K_E",
                "platform": "uplay",
                "level": 87,
                "headshotRate": 49.8290598291,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1190,
                            "deaths": 1004,
                            "wins": 109,
                            "losses": 98,
                            "abandons": 7,
                            "rankPoints": 1000,
                            "maxRankPoints": 3207,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:10.498Z",
                "fetchedAt": "2025-04-03T06:22:10.418Z"
            },
            "createdAt": "2025-04-03T03:06:25.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bab78160-e696-499c-b606-16b686a82f6c",
                "profileId": "bab78160-e696-499c-b606-16b686a82f6c",
                "displayName": "runawayhigh",
                "platform": "uplay",
                "level": 89,
                "headshotRate": 50.3365384615,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 542,
                            "deaths": 542,
                            "wins": 51,
                            "losses": 65,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3011,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:33:55.990Z",
                "fetchedAt": "2025-04-03T06:33:55.887Z"
            },
            "createdAt": "2025-04-03T03:06:25.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b971619c-51b3-4ab0-8468-c0009075f2bf",
                "profileId": "b971619c-51b3-4ab0-8468-c0009075f2bf",
                "displayName": "mtssss.",
                "platform": "uplay",
                "level": 116,
                "headshotRate": 63.0589430894,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 787,
                            "deaths": 635,
                            "wins": 76,
                            "losses": 65,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3432,
                            "rank": "unranked",
                            "maxRank": "platinum-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:33:58.283Z",
                "fetchedAt": "2025-04-03T06:33:58.218Z"
            },
            "createdAt": "2025-04-03T03:06:25.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bb40e5f9-930c-4858-a8a5-1c82af640033",
                "profileId": "bb40e5f9-930c-4858-a8a5-1c82af640033",
                "displayName": "iEatAshes",
                "platform": "uplay",
                "level": 104,
                "headshotRate": 60.4067365745,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 18,
                            "deaths": 7,
                            "wins": 1,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1122,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:03.113Z",
                "fetchedAt": "2025-04-03T06:22:03.030Z"
            },
            "createdAt": "2025-04-03T03:06:25.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fcb0b53f-e3a2-4265-ba24-4a18bab94b5b",
                "profileId": "fcb0b53f-e3a2-4265-ba24-4a18bab94b5b",
                "displayName": "Wayrix_",
                "platform": "uplay",
                "level": 85,
                "headshotRate": 79.1208791209,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 131,
                            "deaths": 48,
                            "wins": 16,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2718,
                            "rank": "unranked",
                            "maxRank": "gold-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:41.168Z",
                "fetchedAt": "2025-04-03T06:32:41.104Z"
            },
            "createdAt": "2025-04-03T02:56:25.263Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b996d796-f7ae-440f-85d0-311b6daf20fe",
                "profileId": "b996d796-f7ae-440f-85d0-311b6daf20fe",
                "displayName": "FentGoon",
                "platform": "uplay",
                "level": 130,
                "headshotRate": 43.2066631963,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 51,
                            "deaths": 49,
                            "wins": 6,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1579,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:33:46.193Z",
                "fetchedAt": "2025-04-03T06:33:46.061Z"
            },
            "createdAt": "2025-04-03T02:56:25.263Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "87d6603c-7bb1-478e-9195-fa9802ac99f8",
                "profileId": "87d6603c-7bb1-478e-9195-fa9802ac99f8",
                "displayName": "JoliStyle",
                "platform": "uplay",
                "level": 73,
                "headshotRate": 54.2857142857,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 418,
                            "deaths": 316,
                            "wins": 47,
                            "losses": 32,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4097,
                            "rank": "unranked",
                            "maxRank": "diamond-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:37:04.965Z",
                "fetchedAt": "2025-04-03T06:37:04.887Z"
            },
            "createdAt": "2025-04-03T02:46:29.293Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "259d5d75-e617-497d-be9d-8bb67aa709b6",
                "profileId": "259d5d75-e617-497d-be9d-8bb67aa709b6",
                "displayName": "Yin",
                "platform": "uplay",
                "level": 55,
                "headshotRate": 44.1428571429,
                "overlayUser": true,
                "overlayOnline": false,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 137,
                            "deaths": 71,
                            "wins": 15,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2481,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:10.598Z",
                "fetchedAt": "2025-04-03T06:22:10.503Z"
            },
            "createdAt": "2025-04-03T02:46:29.293Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "495ae2a5-ffc2-4303-8ca5-749402754ab1",
                "profileId": "d8165cec-3448-41c9-b347-7589a95b8f1a",
                "displayName": "Fe4rless1649",
                "platform": "xbl",
                "level": 78,
                "headshotRate": 51.2944983819,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:38.171Z",
                "fetchedAt": "2025-04-03T06:32:38.098Z"
            },
            "createdAt": "2025-04-03T02:46:29.293Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "392a0a10-51f0-4f3d-be72-a0d4423516ca",
                "profileId": "392a0a10-51f0-4f3d-be72-a0d4423516ca",
                "displayName": "Punisher_.-._",
                "platform": "uplay",
                "level": 171,
                "headshotRate": 53.1386861314,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 92,
                            "deaths": 62,
                            "wins": 7,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1730,
                            "rank": "unranked",
                            "maxRank": "bronze-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:02.954Z",
                "fetchedAt": "2025-04-03T06:22:02.862Z"
            },
            "createdAt": "2025-04-03T02:36:43.563Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "16e95289-1223-4802-8480-3375abc34b18",
                "profileId": "16e95289-1223-4802-8480-3375abc34b18",
                "displayName": "randhir_mann",
                "platform": "uplay",
                "level": 192,
                "headshotRate": 38.4637431929,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:41.322Z",
                "fetchedAt": "2025-04-03T06:32:41.243Z"
            },
            "createdAt": "2025-04-03T02:36:43.563Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "16e95289-1223-4802-8480-3375abc34b18",
                "profileId": "eaeb51ea-b770-48aa-9abb-7c71755fd6ce",
                "displayName": "La_Flame640",
                "platform": "psn",
                "level": 192,
                "headshotRate": 38.4637431929,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:38.171Z",
                "fetchedAt": "2025-04-03T06:32:38.098Z"
            },
            "createdAt": "2025-04-03T02:36:43.563Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6ee9c15f-4a6d-4ea0-9d2c-3eb1fe391d53",
                "profileId": "a2ab4494-9516-45aa-bd3d-766790a2e5bb",
                "displayName": "EndRelations",
                "platform": "xbl",
                "level": 154,
                "headshotRate": 34.82231487,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 650,
                            "deaths": 677,
                            "wins": 80,
                            "losses": 65,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1940,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:14.940Z",
                "fetchedAt": "2025-04-03T06:22:14.796Z"
            },
            "createdAt": "2025-04-03T02:36:43.563Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "463be064-9077-4318-99b2-242b9eefa0db",
                "profileId": "463be064-9077-4318-99b2-242b9eefa0db",
                "displayName": "RegentalNut257",
                "platform": "uplay",
                "level": 89,
                "headshotRate": 43.6176302232,
                "leaderboardPosition": 3291,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1079,
                            "deaths": 823,
                            "wins": 117,
                            "losses": 76,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4516,
                            "maxTopRankPosition": 2576,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:21:58.703Z",
                "fetchedAt": "2025-04-03T06:21:58.579Z"
            },
            "createdAt": "2025-04-03T02:36:43.563Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "55c74f0f-cf1f-42cf-a935-60fb9bc54a92",
                "profileId": "55c74f0f-cf1f-42cf-a935-60fb9bc54a92",
                "displayName": "sfshdog",
                "platform": "uplay",
                "level": 171,
                "headshotRate": 51.9943272469,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1073,
                            "deaths": 1122,
                            "wins": 110,
                            "losses": 128,
                            "abandons": 5,
                            "rankPoints": 1000,
                            "maxRankPoints": 3977,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:06.820Z",
                "fetchedAt": "2025-04-03T06:22:06.744Z"
            },
            "createdAt": "2025-04-03T02:36:43.563Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8620fc87-ec06-4bba-998f-610495a81e81",
                "profileId": "8620fc87-ec06-4bba-998f-610495a81e81",
                "displayName": "PeterSvart",
                "platform": "uplay",
                "level": 57,
                "headshotRate": 55.4785020804,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 173,
                            "deaths": 54,
                            "wins": 11,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2178,
                            "rank": "unranked",
                            "maxRank": "silver-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:34:03.361Z",
                "fetchedAt": "2025-04-03T06:34:03.240Z"
            },
            "createdAt": "2025-04-03T02:26:43.477Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "50502640-af51-48fa-91a2-aaba1f7b4f5f",
                "profileId": "50502640-af51-48fa-91a2-aaba1f7b4f5f",
                "displayName": "iLuvironsites",
                "platform": "uplay",
                "level": 85,
                "headshotRate": 59.8106712565,
                "leaderboardPosition": 6961,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 980,
                            "deaths": 670,
                            "wins": 109,
                            "losses": 55,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4388,
                            "rank": "unranked",
                            "maxRank": "diamond-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:39.269Z",
                "fetchedAt": "2025-04-03T06:32:39.173Z"
            },
            "createdAt": "2025-04-03T02:26:43.477Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "50162a80-38fc-49a4-a6f8-7e1fbd7b44e4",
                "profileId": "50162a80-38fc-49a4-a6f8-7e1fbd7b44e4",
                "displayName": "vfentie",
                "platform": "uplay",
                "level": 97,
                "headshotRate": 53.1693472091,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 444,
                            "deaths": 64,
                            "wins": 37,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4116,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:37.962Z",
                "fetchedAt": "2025-04-03T06:32:37.887Z"
            },
            "createdAt": "2025-04-03T02:26:43.477Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "50162a80-38fc-49a4-a6f8-7e1fbd7b44e4",
                "profileId": "e46cf3d7-f207-436e-98de-d174faf49c36",
                "displayName": "slzezy",
                "platform": "psn",
                "level": 97,
                "headshotRate": 53.1693472091,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:42.182Z",
                "fetchedAt": "2025-04-03T06:32:42.106Z"
            },
            "createdAt": "2025-04-03T02:26:43.477Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2c7c91ec-52e4-4683-9558-6e4ec990caaa",
                "profileId": "9366ecb9-a565-40fe-ac50-ef933716bc41",
                "displayName": "imtrash5234",
                "platform": "xbl",
                "level": 154,
                "headshotRate": 50.1258178158,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:37:44.407Z",
                "fetchedAt": "2025-04-03T06:37:44.243Z"
            },
            "createdAt": "2025-04-03T02:26:43.477Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1eb8a818-5bdb-42fe-a24d-0555768840a3",
                "profileId": "1eb8a818-5bdb-42fe-a24d-0555768840a3",
                "displayName": "ANTI-.ExE",
                "platform": "uplay",
                "level": 323,
                "headshotRate": 61.6394643231,
                "leaderboardPosition": 9859,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 790,
                            "deaths": 562,
                            "wins": 59,
                            "losses": 63,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4283,
                            "rank": "unranked",
                            "maxRank": "diamond-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:11.169Z",
                "fetchedAt": "2025-04-03T06:22:11.063Z"
            },
            "createdAt": "2025-04-03T02:26:43.477Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a1346d36-4d8f-4b18-a947-9715c9379afd",
                "profileId": "a1346d36-4d8f-4b18-a947-9715c9379afd",
                "displayName": "CuteMilkers",
                "platform": "uplay",
                "level": 217,
                "headshotRate": 55.2162031828,
                "overlayUser": true,
                "overlayOnline": false,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:34:35.793Z",
                "fetchedAt": "2025-04-03T06:34:35.702Z"
            },
            "createdAt": "2025-04-03T02:16:54.107Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "de4fd65f-7fb2-4832-8122-a77a2a3c07a2",
                "profileId": "de4fd65f-7fb2-4832-8122-a77a2a3c07a2",
                "displayName": "DackelaBog",
                "platform": "uplay",
                "level": 149,
                "headshotRate": 48.5359801489,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:21:58.753Z",
                "fetchedAt": "2025-04-03T06:21:58.676Z"
            },
            "createdAt": "2025-04-03T02:06:44.016Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "005a0b48-cac2-4808-9156-0d38e9051354",
                "profileId": "005a0b48-cac2-4808-9156-0d38e9051354",
                "displayName": "SenseiTryhard",
                "platform": "uplay",
                "level": 82,
                "headshotRate": 54.8548548549,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 860,
                            "deaths": 555,
                            "wins": 87,
                            "losses": 55,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4186,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:06.723Z",
                "fetchedAt": "2025-04-03T06:22:06.612Z"
            },
            "createdAt": "2025-04-03T02:06:44.016Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "601a1b26-cac8-49bb-9790-fbade73910a6",
                "profileId": "601a1b26-cac8-49bb-9790-fbade73910a6",
                "displayName": "Drummystixk",
                "platform": "uplay",
                "level": 29,
                "headshotRate": 55.9139784946,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:22:10.598Z",
                "fetchedAt": "2025-04-03T06:22:10.503Z"
            },
            "createdAt": "2025-04-03T01:56:43.308Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f11cca33-4412-416e-b231-0da9d8536e74",
                "profileId": "f11cca33-4412-416e-b231-0da9d8536e74",
                "displayName": "swungximera.m80",
                "platform": "uplay",
                "level": 93,
                "headshotRate": 44.1662493741,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 51,
                            "deaths": 58,
                            "wins": 4,
                            "losses": 8,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1369,
                            "rank": "unranked",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:22:02.622Z",
                "fetchedAt": "2025-04-03T06:22:02.539Z"
            },
            "createdAt": "2025-04-03T01:56:43.308Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bb4bc845-bf22-4fdf-9e6a-b56beedcb429",
                "profileId": "6f317567-f1a7-48c8-a1a3-a7a1e7b87ce8",
                "displayName": "arnzf",
                "platform": "xbl",
                "level": 92,
                "headshotRate": 44.0941572089,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:21:58.703Z",
                "fetchedAt": "2025-04-03T06:21:58.579Z"
            },
            "createdAt": "2025-04-03T01:56:43.308Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3a3fe516-e3d2-471b-a18a-9afe2894ec2e",
                "profileId": "45669bec-5dfd-4488-ab69-d0b7a41a9132",
                "displayName": "Krypt0nian66",
                "platform": "xbl",
                "level": 188,
                "headshotRate": 34.7571523619,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:10:40.351Z",
                "fetchedAt": "2025-04-03T02:10:40.168Z"
            },
            "createdAt": "2025-04-03T01:56:43.308Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "57c4a1a0-379b-4c4f-867d-c776c738f616",
                "profileId": "57c4a1a0-379b-4c4f-867d-c776c738f616",
                "displayName": "R4C.GOD",
                "platform": "uplay",
                "level": 451,
                "headshotRate": 53.0113527035,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:42.030Z",
                "fetchedAt": "2025-04-03T06:32:41.934Z"
            },
            "createdAt": "2025-04-03T01:56:43.308Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "764c79ec-ce0d-4248-9d79-ae4875c3f8a9",
                "profileId": "764c79ec-ce0d-4248-9d79-ae4875c3f8a9",
                "displayName": "EmqIsStraightAh",
                "platform": "uplay",
                "level": 69,
                "headshotRate": 45.1704545455,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 296,
                            "deaths": 180,
                            "wins": 38,
                            "losses": 10,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3944,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T02:10:43.240Z",
                "fetchedAt": "2025-04-03T02:10:43.044Z"
            },
            "createdAt": "2025-04-03T01:26:43.785Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b7eade46-3256-4d07-ba10-1704be196f98",
                "profileId": "db21e0a4-46ca-47f7-af68-85bab2956d4f",
                "displayName": "y__905",
                "platform": "psn",
                "level": 282,
                "headshotRate": 33.4434396491,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 75,
                            "deaths": 72,
                            "wins": 5,
                            "losses": 11,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1533,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T04:06:48.734Z",
                "fetchedAt": "2025-04-03T04:06:48.541Z"
            },
            "createdAt": "2025-04-03T01:26:43.785Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "191b5de2-3102-4570-bdb5-4adf88b3cf7a",
                "profileId": "cebdf0e6-dba8-43dd-a48b-67fc4f673da9",
                "displayName": "hcxim",
                "platform": "psn",
                "level": 134,
                "headshotRate": 37.3831775701,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:10:40.124Z",
                "fetchedAt": "2025-04-03T02:10:39.987Z"
            },
            "createdAt": "2025-04-03T01:26:43.785Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "34a75415-b566-4708-96fa-aa62d607ebdb",
                "profileId": "34a75415-b566-4708-96fa-aa62d607ebdb",
                "displayName": "jaegrr-",
                "platform": "uplay",
                "level": 172,
                "headshotRate": 51.0213556175,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 235,
                            "deaths": 135,
                            "wins": 24,
                            "losses": 9,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3406,
                            "rank": "unranked",
                            "maxRank": "platinum-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:37:10.171Z",
                "fetchedAt": "2025-04-03T06:37:10.095Z"
            },
            "createdAt": "2025-04-03T01:16:54.489Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3ceaa3a1-3a2f-4612-9d74-594034ac05ca",
                "profileId": "f04add88-0555-4960-a932-a5a4e0a6a346",
                "displayName": "KDEC Trax",
                "platform": "xbl",
                "level": 116,
                "headshotRate": 50.8960573477,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:12:49.083Z",
                "fetchedAt": "2025-04-03T02:12:48.994Z"
            },
            "createdAt": "2025-04-03T01:16:54.489Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ddc1a41f-91b1-452e-8f7b-e29af4083e9b",
                "profileId": "ddc1a41f-91b1-452e-8f7b-e29af4083e9b",
                "displayName": "SpruceWillis22",
                "platform": "uplay",
                "level": 160,
                "headshotRate": 52.7243589744,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 39,
                            "deaths": 20,
                            "wins": 8,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1807,
                            "rank": "unranked",
                            "maxRank": "bronze-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T04:09:37.685Z",
                "fetchedAt": "2025-04-03T04:09:37.591Z"
            },
            "createdAt": "2025-04-03T01:16:54.489Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "17f79765-9bb2-4a92-afa3-0684c7b16949",
                "profileId": "17f79765-9bb2-4a92-afa3-0684c7b16949",
                "displayName": "O.200.IQ.O",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 47.5009255831,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:29:11.403Z",
                "fetchedAt": "2025-04-03T02:29:11.267Z"
            },
            "createdAt": "2025-04-03T01:06:44.294Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "17f79765-9bb2-4a92-afa3-0684c7b16949",
                "profileId": "cb095f5b-4559-4a15-9b25-34be8e104fa0",
                "displayName": "Glare 45k",
                "platform": "xbl",
                "level": 1000000,
                "headshotRate": 47.5009255831,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:37:24.496Z",
                "fetchedAt": "2025-04-03T06:37:24.412Z"
            },
            "createdAt": "2025-04-03T01:06:44.294Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ea4abcf4-1c57-4df7-9108-c9d489d88d48",
                "profileId": "ea4abcf4-1c57-4df7-9108-c9d489d88d48",
                "displayName": "zHnzT02-_",
                "platform": "uplay",
                "level": 83,
                "headshotRate": 56.0356652949,
                "leaderboardPosition": 1626,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 706,
                            "deaths": 424,
                            "wins": 71,
                            "losses": 28,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4573,
                            "maxTopRankPosition": 1294,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-03T01:37:49.732Z",
                "fetchedAt": "2025-04-03T01:37:49.656Z"
            },
            "createdAt": "2025-04-03T01:06:44.294Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "cf3e9048-1296-422d-865f-7d2d0d476ab7",
                "profileId": "2f6b446a-e160-446f-925d-4012a8dbcd92",
                "displayName": "Jh1tr",
                "platform": "xbl",
                "level": 132,
                "headshotRate": 60.9108910891,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:32:39.269Z",
                "fetchedAt": "2025-04-03T06:32:39.173Z"
            },
            "createdAt": "2025-04-03T00:56:42.779Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0021a92f-3dd0-4016-a7f5-d4b68a1073d2",
                "profileId": "8f3df084-c026-4c0b-a63a-c4268c338a99",
                "displayName": "CNL_Ben_543",
                "platform": "psn",
                "level": 130,
                "headshotRate": 41.124166402,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:16:14.211Z",
                "fetchedAt": "2025-04-03T02:16:14.124Z"
            },
            "createdAt": "2025-04-03T00:56:42.779Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b3b08e49-ceaa-4846-adfc-aaf78ed64624",
                "profileId": "b3b08e49-ceaa-4846-adfc-aaf78ed64624",
                "displayName": "SkibityNut",
                "platform": "uplay",
                "level": 121,
                "headshotRate": 37.9865269461,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:15:03.976Z",
                "fetchedAt": "2025-04-03T02:15:03.871Z"
            },
            "createdAt": "2025-04-03T00:56:42.779Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f219b07b-7d99-47be-8701-b18a9d5ce191",
                "profileId": "f219b07b-7d99-47be-8701-b18a9d5ce191",
                "displayName": "kc3hidd3n.",
                "platform": "uplay",
                "level": 134,
                "headshotRate": 52.1141875939,
                "leaderboardPosition": 9999,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 127,
                            "deaths": 123,
                            "wins": 14,
                            "losses": 13,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2353,
                            "rank": "unranked",
                            "maxRank": "silver-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T02:10:40.059Z",
                "fetchedAt": "2025-04-03T02:10:39.961Z"
            },
            "createdAt": "2025-04-03T00:56:42.779Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "799b10d5-f76a-4cd0-8d5d-8cf53d9178e0",
                "profileId": "799b10d5-f76a-4cd0-8d5d-8cf53d9178e0",
                "displayName": "viiixvmmvi",
                "platform": "uplay",
                "level": 91,
                "headshotRate": 38.3082158483,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:10:40.351Z",
                "fetchedAt": "2025-04-03T02:10:40.168Z"
            },
            "createdAt": "2025-04-03T00:56:42.779Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "98e1b3a0-5b05-4977-9c65-4d8e76648f9a",
                "profileId": "98e1b3a0-5b05-4977-9c65-4d8e76648f9a",
                "displayName": "suizidgefahr",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 50.7068803016,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:29:25.203Z",
                "fetchedAt": "2025-04-03T02:29:25.117Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6def4097-bff7-480d-aa3a-32c7ff9b8be7",
                "profileId": "6def4097-bff7-480d-aa3a-32c7ff9b8be7",
                "displayName": "imsothrowed99",
                "platform": "uplay",
                "level": 117,
                "headshotRate": 57.4160952725,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 98,
                            "deaths": 69,
                            "wins": 11,
                            "losses": 6,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1479,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T02:15:55.839Z",
                "fetchedAt": "2025-04-03T02:15:55.751Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e50245f6-8ccc-4a1d-9d90-1b654d0e3e08",
                "profileId": "12573d27-81bf-4602-aa4a-6caf62d2faad",
                "displayName": "TcnyMontqnaa",
                "platform": "psn",
                "level": 1000000,
                "headshotRate": 54.4544234541,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T01:37:53.370Z",
                "fetchedAt": "2025-04-03T01:37:53.291Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4f8fe027-f645-4575-b6db-1c22231bf886",
                "profileId": "4f8fe027-f645-4575-b6db-1c22231bf886",
                "displayName": "THN.neverlose",
                "platform": "uplay",
                "level": 91,
                "headshotRate": 52.6267702147,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 807,
                            "deaths": 668,
                            "wins": 87,
                            "losses": 66,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 3298,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T06:32:42.138Z",
                "fetchedAt": "2025-04-03T06:32:42.030Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "43981fb9-7e2b-4e8f-8a15-19d74ca8bc81",
                "profileId": "43981fb9-7e2b-4e8f-8a15-19d74ca8bc81",
                "displayName": "zvn8",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 58.1205866377,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T04:48:20.097Z",
                "fetchedAt": "2025-04-03T04:48:20.022Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d8ca1a2a-2129-4a84-ab47-e5d75f9ba0d5",
                "profileId": "d8ca1a2a-2129-4a84-ab47-e5d75f9ba0d5",
                "displayName": "RizzMister69",
                "platform": "uplay",
                "level": 83,
                "headshotRate": 48.4179104478,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:13:41.138Z",
                "fetchedAt": "2025-04-03T02:13:41.055Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e50245f6-8ccc-4a1d-9d90-1b654d0e3e08",
                "profileId": "e50245f6-8ccc-4a1d-9d90-1b654d0e3e08",
                "displayName": "glocktxbers.tv",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 54.4544234541,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:37:26.416Z",
                "fetchedAt": "2025-04-03T06:37:26.333Z"
            },
            "createdAt": "2025-04-03T00:46:53.011Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c2c78c3d-f01b-4023-a541-d1c878408a52",
                "profileId": "c2c78c3d-f01b-4023-a541-d1c878408a52",
                "displayName": "Diddling_Darren",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 57.2944297082,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:35:07.308Z",
                "fetchedAt": "2025-04-03T06:35:07.207Z"
            },
            "createdAt": "2025-04-03T00:36:42.466Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b8bdeb0c-dcfc-42df-9b0d-ddd7cdd0d28a",
                "profileId": "b8bdeb0c-dcfc-42df-9b0d-ddd7cdd0d28a",
                "displayName": "volteeeee",
                "platform": "uplay",
                "level": 147,
                "headshotRate": 33.3639705882,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 340,
                            "deaths": 310,
                            "wins": 40,
                            "losses": 39,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2155,
                            "rank": "unranked",
                            "maxRank": "silver-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T04:47:10.563Z",
                "fetchedAt": "2025-04-03T04:47:10.421Z"
            },
            "createdAt": "2025-04-03T00:36:42.466Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "dd06212e-a3e3-4ad9-b933-505deb6ac17b",
                "profileId": "dd06212e-a3e3-4ad9-b933-505deb6ac17b",
                "displayName": "tckzy.",
                "platform": "uplay",
                "level": 79,
                "headshotRate": 61.0951008646,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:10:42.217Z",
                "fetchedAt": "2025-04-03T02:10:42.126Z"
            },
            "createdAt": "2025-04-03T00:36:42.466Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a6c5fa0c-c497-4198-8cef-6ac84b972cbb",
                "profileId": "a6c5fa0c-c497-4198-8cef-6ac84b972cbb",
                "displayName": "PocketYuty",
                "platform": "uplay",
                "level": 179,
                "headshotRate": 55.4163596168,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 110,
                            "deaths": 54,
                            "wins": 8,
                            "losses": 5,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1929,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T01:37:56.601Z",
                "fetchedAt": "2025-04-03T01:37:56.517Z"
            },
            "createdAt": "2025-04-03T00:36:42.466Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "266aa8b5-8c5d-48c1-bfa8-8cf55e89bd1b",
                "profileId": "266aa8b5-8c5d-48c1-bfa8-8cf55e89bd1b",
                "displayName": "kta.",
                "platform": "uplay",
                "level": 79,
                "headshotRate": 47.9691876751,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 65,
                            "deaths": 42,
                            "wins": 6,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1599,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T02:10:39.473Z",
                "fetchedAt": "2025-04-03T02:10:39.272Z"
            },
            "createdAt": "2025-04-03T00:26:42.952Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a33525c3-d780-4207-8829-89879de4cb8f",
                "profileId": "63e943c2-0898-4e2f-846f-84b89a88bfd0",
                "displayName": "Emiliostefanrosa",
                "platform": "psn",
                "level": 123,
                "headshotRate": 56.5997322624,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T02:10:39.087Z",
                "fetchedAt": "2025-04-03T02:10:38.932Z"
            },
            "createdAt": "2025-04-03T00:26:42.952Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bf7b4c92-2743-4968-b0f8-a52de945d421",
                "profileId": "bf7b4c92-2743-4968-b0f8-a52de945d421",
                "displayName": "eltitotompa",
                "platform": "uplay",
                "level": 80,
                "headshotRate": 35.4714064915,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T06:35:12.702Z",
                "fetchedAt": "2025-04-03T06:35:12.591Z"
            },
            "createdAt": "2025-04-03T00:26:42.952Z",
            "reason": "cheating"
        }
    ]
}
"""

# %%
import json
data2 = json.loads(data)

# %%
import pandas as pd
import numpy as np

# %%
# Extract relevant fields into a list of dictionaries
records = [
    {
        "Display Name": ban["profile"]["displayName"],
        "Platform": ban["profile"]["platform"],
        "Level": ban["profile"]["level"],
        "Headshot Rate (%)": ban["profile"]["headshotRate"],
        "Reason": ban["reason"]
    }
    for ban in data2["bans"]
]

# Convert to DataFrame
df = pd.DataFrame(records)

# Display basic statistics
summary = {
    "Total Bans": len(df),
    "Average Level": df["Level"].mean(),
    "Average Headshot Rate (%)": df["Headshot Rate (%)"].mean(),
    "Max Headshot Rate (%)": df["Headshot Rate (%)"].max(),
    "Min Headshot Rate (%)": df["Headshot Rate (%)"].min(),
    "Most Common Platform": df["Platform"].mode()[0]
}

summary_df = pd.DataFrame([summary])

# %%
summary_df
# Out:
#    Total Bans  Average Level  Average Headshot Rate (%)  \
# 0         100       70104.25                  51.371074
#
#    Max Headshot Rate (%)  Min Headshot Rate (%) Most Common Platform
# 0              79.120879              31.168831                uplay

# %%
# Updated parsing to include seasonal records if present
parsed_with_seasonal_df = pd.DataFrame([
    {
        "Display Name": entry["profile"].get("displayName"),
        "Platform": entry["profile"].get("platform"),
        "Level": entry["profile"].get("level"),
        "Headshot Rate (%)": entry["profile"].get("headshotRate"),
        "Kills": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("kills", np.nan),
        "Deaths": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("deaths", np.nan),
        "Wins": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("wins", np.nan),
        "Losses": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("losses", np.nan),
        "Abandons": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("abandons", np.nan),
        "Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rankPoints", np.nan),
        "Max Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRankPoints", np.nan),
        "Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rank", np.nan),
        "Max Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRank", np.nan),
        "Reason": entry.get("reason", "N/A")
    }
    for entry in data2['bans']
])

# %%
parsed_with_seasonal_df
# Out:
#         Display Name Platform  Level  Headshot Rate (%)   Kills  Deaths  \
# 0            vroyyyy    uplay    105          57.123225  1439.0  1084.0
# 1          zHnzT02-_    uplay     83          56.035665   706.0   424.0
# 2            DerE4sy    uplay     76          55.691057   136.0    85.0
# 3      ononoqinusihe    uplay     69          54.128440   359.0   186.0
# 4             NeYRaZ    uplay    223          53.131673  1401.0   987.0
# ..               ...      ...    ...                ...     ...     ...
# 95            tckzy.    uplay     79          61.095101     NaN     NaN
# 96        PocketYuty    uplay    179          55.416360   110.0    54.0
# 97              kta.    uplay     79          47.969188    65.0    42.0
# 98  Emiliostefanrosa      psn    123          56.599732     NaN     NaN
# 99       eltitotompa    uplay     80          35.471406     NaN     NaN
#
#      Wins  Losses  Abandons  Rank Points  Max Rank Points      Rank  Max Rank  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(parsed_with_seasonal_df['Headshot Rate (%)'], edgecolor='black', bins=20)
# Out:
# (array([ 3.,  3.,  4.,  3.,  1., 11.,  5.,  7., 14., 16., 14.,  7.,  7.,
#          2.,  0.,  0.,  1.,  1.,  0.,  1.]),
#  array([31.16883117, 33.56643357, 35.96403596, 38.36163836, 40.75924076,
#         43.15684316, 45.55444555, 47.95204795, 50.34965035, 52.74725275,
#         55.14485514, 57.54245754, 59.94005994, 62.33766234, 64.73526474,
#         67.13286713, 69.53046953, 71.92807193, 74.32567433, 76.72327672,
#         79.12087912]),
#  <BarContainer object of 20 artists>)

# %%
import json

with open('../cheater_usernames_statscc/usernames.txt', 'r') as file:
    data = json.load(file)

# %%
len(data)
# Out:
# 2

# %%
def add_usernames(df, data):
    current_append = len(data) + 1
    append_name = 'append' + f'{current_append}'
    append_list = [x for x in df['Display Name']]
    
    data[append_name] = append_list
    
    return data
data_new = add_usernames(df, data)

# %%
len(data_new)
# Out:
# 3

# %%
# Write data to file
with open('../cheater_usernames_statscc/usernames.txt', 'w') as file:
    json.dump(data_new, file, indent=1)
