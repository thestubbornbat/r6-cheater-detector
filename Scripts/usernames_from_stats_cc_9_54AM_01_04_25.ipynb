# %%
data = {
    "bans": [
        {
            "profile": {
                "userId": "4c8c848f-c720-4631-89ce-e9eafb8d62d1",
                "profileId": "3bfa29f0-fd46-4683-bcf3-0696932402f6",
                "displayName": "PremeLuvz",
                "platform": "xbl",
                "level": 132,
                "headshotRate": 36.8625546382,
                "seasonalRecords": {},
                "updatedAt": "2025-03-05T18:36:22.969Z",
                "fetchedAt": "2024-11-06T23:43:49.850Z"
            },
            "createdAt": "2025-04-01T03:16:37.735Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "57bf854a-8da0-4cdb-9496-9121c1638529",
                "profileId": "57bf854a-8da0-4cdb-9496-9121c1638529",
                "displayName": "ahdapter.",
                "platform": "uplay",
                "level": 202,
                "headshotRate": 40.5474491426,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 574,
                            "deaths": 313,
                            "wins": 67,
                            "losses": 15,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3951,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:09:54.288Z",
                "fetchedAt": "2025-04-01T02:09:54.209Z"
            },
            "createdAt": "2025-04-01T02:06:38.806Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "35b7a692-a359-4531-9fe7-a775c1b08233",
                "profileId": "35b7a692-a359-4531-9fe7-a775c1b08233",
                "displayName": "Edz1994",
                "platform": "uplay",
                "level": 42,
                "headshotRate": 59.3959731544,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:09:52.862Z",
                "fetchedAt": "2025-04-01T02:09:52.775Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b7e1069d-3095-4a88-bce7-c48cd039a1db",
                "profileId": "b7e1069d-3095-4a88-bce7-c48cd039a1db",
                "displayName": "mazoquismo",
                "platform": "uplay",
                "level": 60,
                "headshotRate": 60.3066439523,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:23:52.908Z",
                "fetchedAt": "2025-04-01T02:23:52.828Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "565808ee-7b86-441e-b5c1-9c237181b872",
                "profileId": "9c73ea77-1744-41b5-abff-9ed5d74b8e46",
                "displayName": "Thibeau202012",
                "platform": "psn",
                "level": 77,
                "headshotRate": 55.3078556263,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:09:52.235Z",
                "fetchedAt": "2025-04-01T02:09:52.151Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "565808ee-7b86-441e-b5c1-9c237181b872",
                "profileId": "565808ee-7b86-441e-b5c1-9c237181b872",
                "displayName": "TDF.SWINGSS",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 55.3078556263,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 59,
                            "deaths": 64,
                            "wins": 9,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1364,
                            "rank": "unranked",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:20:35.815Z",
                "fetchedAt": "2025-04-01T02:20:35.734Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f60bc4c0-da00-4707-9c41-9acae8af2dae",
                "profileId": "f60bc4c0-da00-4707-9c41-9acae8af2dae",
                "displayName": "ilyjahh",
                "platform": "uplay",
                "level": 76,
                "headshotRate": 59.9385245902,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 95,
                            "deaths": 35,
                            "wins": 12,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2280,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T04:01:14.371Z",
                "fetchedAt": "2025-04-01T04:01:14.268Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ef10f532-3106-44b0-9116-9edd16c8289e",
                "profileId": "ef10f532-3106-44b0-9116-9edd16c8289e",
                "displayName": "sluuhn.",
                "platform": "uplay",
                "level": 93,
                "headshotRate": 58.88177053,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:09:54.288Z",
                "fetchedAt": "2025-04-01T02:09:54.209Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e092b65d-cfea-4f21-bca4-6faf4f6147c3",
                "profileId": "e092b65d-cfea-4f21-bca4-6faf4f6147c3",
                "displayName": "Schlumpfprofil.",
                "platform": "uplay",
                "level": 93,
                "headshotRate": 45.5477855478,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 469,
                            "deaths": 329,
                            "wins": 52,
                            "losses": 28,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3536,
                            "rank": "unranked",
                            "maxRank": "emerald-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:16:01.148Z",
                "fetchedAt": "2025-04-01T02:16:01.056Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ed840d22-9d04-4e6d-a5de-91b5a0df9171",
                "profileId": "ed840d22-9d04-4e6d-a5de-91b5a0df9171",
                "displayName": "Obidum",
                "platform": "uplay",
                "level": 104,
                "headshotRate": 53.431372549,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 131,
                            "deaths": 92,
                            "wins": 10,
                            "losses": 11,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2036,
                            "rank": "unranked",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:09:54.415Z",
                "fetchedAt": "2025-04-01T02:09:54.306Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "19aa58bc-4cf4-4ca0-9756-c2641e6f07df",
                "profileId": "19aa58bc-4cf4-4ca0-9756-c2641e6f07df",
                "displayName": "namatorerom",
                "platform": "uplay",
                "level": 78,
                "headshotRate": 54.3464262717,
                "leaderboardPosition": 9996,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 293,
                            "deaths": 258,
                            "wins": 31,
                            "losses": 27,
                            "abandons": 0,
                            "rankPoints": 3377,
                            "maxRankPoints": 3378,
                            "rank": "platinum-2",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-03-19T17:32:03.335Z",
                "fetchedAt": "2025-03-19T17:32:03.256Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e9e80879-09fc-4055-956e-82ed80d9bf88",
                "profileId": "e9e80879-09fc-4055-956e-82ed80d9bf88",
                "displayName": "A__DOG",
                "platform": "uplay",
                "level": 45,
                "headshotRate": 52.6011560694,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:09:53.003Z",
                "fetchedAt": "2025-04-01T02:09:52.924Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bef586f3-e9f1-4b4b-a1a6-04106bf1a30d",
                "profileId": "bef586f3-e9f1-4b4b-a1a6-04106bf1a30d",
                "displayName": "k5da.",
                "platform": "uplay",
                "level": 68,
                "headshotRate": 41.4798206278,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:16:58.097Z",
                "fetchedAt": "2025-04-01T02:16:58.017Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7c2f5f9e-8cd7-4c49-81c1-b99c293443fa",
                "profileId": "7c2f5f9e-8cd7-4c49-81c1-b99c293443fa",
                "displayName": "Shor3tyyyy",
                "platform": "uplay",
                "level": 17,
                "headshotRate": 56.25,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:15:11.120Z",
                "fetchedAt": "2025-04-01T02:15:11.031Z"
            },
            "createdAt": "2025-04-01T01:36:31.413Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fa19bac4-385f-489f-b293-ed7159ea8569",
                "profileId": "fa19bac4-385f-489f-b293-ed7159ea8569",
                "displayName": "shaw____08",
                "platform": "uplay",
                "level": 90,
                "headshotRate": 51.9454269833,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T03:23:44.445Z",
                "fetchedAt": "2025-04-01T03:23:44.359Z"
            },
            "createdAt": "2025-04-01T01:36:31.413Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "62c9120a-2848-4a70-80be-ec71a355eb57",
                "profileId": "62c9120a-2848-4a70-80be-ec71a355eb57",
                "displayName": "FUMEZ.K",
                "platform": "uplay",
                "level": 57,
                "headshotRate": 92.2480620155,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 43,
                            "deaths": 24,
                            "wins": 4,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1433,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:09:51.164Z",
                "fetchedAt": "2025-04-01T02:09:51.073Z"
            },
            "createdAt": "2025-04-01T01:26:31.967Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0f00caba-46cd-4b0f-97ee-0dd226a31e4f",
                "profileId": "0f00caba-46cd-4b0f-97ee-0dd226a31e4f",
                "displayName": "BruchTouPUissan",
                "platform": "uplay",
                "level": 130,
                "headshotRate": 45.4467903604,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 569,
                            "deaths": 302,
                            "wins": 67,
                            "losses": 25,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 4076,
                            "rank": "unranked",
                            "maxRank": "diamond-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:09:49.977Z",
                "fetchedAt": "2025-04-01T02:09:49.883Z"
            },
            "createdAt": "2025-04-01T01:26:31.967Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ee3519c0-e242-4424-84e0-e9b152c4e228",
                "profileId": "ee3519c0-e242-4424-84e0-e9b152c4e228",
                "displayName": "MAF7565",
                "platform": "uplay",
                "level": 61,
                "headshotRate": 53.3577533578,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 203,
                            "deaths": 165,
                            "wins": 28,
                            "losses": 7,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3663,
                            "rank": "unranked",
                            "maxRank": "emerald-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:25:59.917Z",
                "fetchedAt": "2025-04-01T02:25:59.825Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8cad4584-9a44-4b24-a91f-e64b7b19f595",
                "profileId": "8cad4584-9a44-4b24-a91f-e64b7b19f595",
                "displayName": "Slit.exe",
                "platform": "uplay",
                "level": 40,
                "headshotRate": 56.4485981308,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T03:24:23.027Z",
                "fetchedAt": "2025-04-01T03:24:22.885Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bdea2d15-056e-4cc5-a2e8-25213341a868",
                "profileId": "bdea2d15-056e-4cc5-a2e8-25213341a868",
                "displayName": "uiatxnfdd3",
                "platform": "uplay",
                "level": 58,
                "headshotRate": 62.0111731844,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T02:09:51.013Z",
                "fetchedAt": "2025-04-01T02:09:50.927Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7c95a8c1-0b09-44dc-941e-2a2a11d365f7",
                "profileId": "7c95a8c1-0b09-44dc-941e-2a2a11d365f7",
                "displayName": "Hugepanda34",
                "platform": "uplay",
                "level": 87,
                "headshotRate": 53.2214401733,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 120,
                            "deaths": 72,
                            "wins": 16,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2658,
                            "rank": "unranked",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:09:54.504Z",
                "fetchedAt": "2025-04-01T02:09:54.417Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6b916bd1-4dd5-4bcb-bae8-d19046bd58d5",
                "profileId": "6b916bd1-4dd5-4bcb-bae8-d19046bd58d5",
                "displayName": "Bl4ckD34th_47",
                "platform": "uplay",
                "level": 145,
                "headshotRate": 50.1869857891,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 155,
                            "deaths": 140,
                            "wins": 21,
                            "losses": 9,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1817,
                            "rank": "unranked",
                            "maxRank": "bronze-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:09:49.977Z",
                "fetchedAt": "2025-04-01T02:09:49.883Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8d773571-74a1-49d8-8b00-ce5807e55e2b",
                "profileId": "8d773571-74a1-49d8-8b00-ce5807e55e2b",
                "displayName": "llIllIlIlIIlIII",
                "platform": "uplay",
                "level": 114,
                "headshotRate": 53.2340862423,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2,
                            "deaths": 9,
                            "wins": 0,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T02:19:14.069Z",
                "fetchedAt": "2025-04-01T02:19:13.888Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3c68bb5e-ae30-4568-9382-412205332ba5",
                "profileId": "3c68bb5e-ae30-4568-9382-412205332ba5",
                "displayName": "Crayon-Eater2",
                "platform": "uplay",
                "level": 148,
                "headshotRate": 40.0131984162,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 116,
                            "deaths": 88,
                            "wins": 14,
                            "losses": 7,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2288,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:06:59.110Z",
                "fetchedAt": "2025-04-01T01:06:59.034Z"
            },
            "createdAt": "2025-04-01T00:56:29.983Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "11826378-73bf-4b08-aadd-45c2f201be9c",
                "profileId": "b94b348d-6105-4ec6-8fbd-6f675c4ace02",
                "displayName": "My kd fears",
                "platform": "xbl",
                "level": 121,
                "headshotRate": 43.2898967676,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 43,
                            "deaths": 144,
                            "wins": 7,
                            "losses": 23,
                            "abandons": 0,
                            "rankPoints": 1274,
                            "maxRankPoints": 1316,
                            "rank": "copper-3",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:05:49.702Z",
                "fetchedAt": "2025-04-01T01:05:49.627Z"
            },
            "createdAt": "2025-03-31T23:46:33.271Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "09eaff98-46ff-46fc-8d1a-e5a732b09ca6",
                "profileId": "8e99179e-228c-45b4-ad92-e67d743b0cc7",
                "displayName": "Seqxnce",
                "platform": "xbl",
                "level": 191,
                "headshotRate": 45.6117021277,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:07:00.819Z",
                "fetchedAt": "2025-04-01T01:07:00.755Z"
            },
            "createdAt": "2025-03-31T22:56:29.811Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "98bb7d5b-1160-4a00-bcbf-545bad76129f",
                "profileId": "98bb7d5b-1160-4a00-bcbf-545bad76129f",
                "displayName": "alvatoss.NRV",
                "platform": "uplay",
                "level": 208,
                "headshotRate": 51.9621109608,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 20,
                            "deaths": 28,
                            "wins": 2,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1213,
                            "rank": "unranked",
                            "maxRank": "copper-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:06:59.039Z",
                "fetchedAt": "2025-04-01T01:06:58.886Z"
            },
            "createdAt": "2025-03-31T21:56:32.941Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "76a80eb1-2cd8-41b7-ad2e-53dcb2446203",
                "profileId": "76a80eb1-2cd8-41b7-ad2e-53dcb2446203",
                "displayName": "STOMPNSTEPBRO",
                "platform": "uplay",
                "level": 41,
                "headshotRate": 40.6367041199,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:07:01.674Z",
                "fetchedAt": "2025-04-01T01:07:01.477Z"
            },
            "createdAt": "2025-03-31T21:36:27.633Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f2f67ca9-2151-4a7b-a35a-9d513d374c32",
                "profileId": "843322c9-fa4b-4e18-93f7-b0eecdcfc64d",
                "displayName": "Netrunnings",
                "platform": "xbl",
                "level": 90,
                "headshotRate": 47.6462196862,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:06:57.650Z",
                "fetchedAt": "2025-04-01T01:06:57.435Z"
            },
            "createdAt": "2025-03-31T21:36:27.633Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "911227a9-1e99-41c6-997b-db53cd153ed1",
                "profileId": "911227a9-1e99-41c6-997b-db53cd153ed1",
                "displayName": "YouTbeNBAFan",
                "platform": "uplay",
                "level": 32,
                "headshotRate": 64.6288209607,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:07:01.055Z",
                "fetchedAt": "2025-04-01T01:07:00.869Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6a6bb210-10c5-43d4-8c5d-2fdb1a19f501",
                "profileId": "6a6bb210-10c5-43d4-8c5d-2fdb1a19f501",
                "displayName": "phil-76",
                "platform": "uplay",
                "level": 55,
                "headshotRate": 48.4486873508,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 90,
                            "deaths": 71,
                            "wins": 10,
                            "losses": 7,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1458,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:07:00.766Z",
                "fetchedAt": "2025-04-01T01:07:00.667Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d3a74085-adf0-4f1f-bbfd-0860af7bb5e3",
                "profileId": "d3a74085-adf0-4f1f-bbfd-0860af7bb5e3",
                "displayName": "WashedOTV",
                "platform": "uplay",
                "level": 61,
                "headshotRate": 68.6070686071,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 190,
                            "deaths": 112,
                            "wins": 23,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3199,
                            "rank": "unranked",
                            "maxRank": "platinum-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:06:57.674Z",
                "fetchedAt": "2025-04-01T01:06:57.543Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d9e2b6f0-c219-4c25-91bf-ef8d3e487cb2",
                "profileId": "fcea4186-aa80-485b-ae1d-c70ad773f34e",
                "displayName": "Trashlikeurkid",
                "platform": "psn",
                "level": 97,
                "headshotRate": 50.6973500697,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:06:59.110Z",
                "fetchedAt": "2025-04-01T01:06:59.034Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "481822bb-a228-406c-aed9-353bf72cd83f",
                "profileId": "481822bb-a228-406c-aed9-353bf72cd83f",
                "displayName": "your_not_him...",
                "platform": "uplay",
                "level": 96,
                "headshotRate": 49.5647442873,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 17,
                            "deaths": 15,
                            "wins": 3,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1156,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:07:00.025Z",
                "fetchedAt": "2025-04-01T01:06:59.876Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fe170d0d-8db2-435b-94a1-0c39726b0761",
                "profileId": "fe170d0d-8db2-435b-94a1-0c39726b0761",
                "displayName": "LikoPasOuf",
                "platform": "uplay",
                "level": 154,
                "headshotRate": 60.4252144722,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2,
                            "deaths": 4,
                            "wins": 0,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T00:38:24.035Z",
                "fetchedAt": "2025-04-01T00:38:23.939Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d9e2b6f0-c219-4c25-91bf-ef8d3e487cb2",
                "profileId": "d9e2b6f0-c219-4c25-91bf-ef8d3e487cb2",
                "displayName": "ShaiikosDaddy",
                "platform": "uplay",
                "level": 97,
                "headshotRate": 50.6973500697,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 189,
                            "deaths": 71,
                            "wins": 27,
                            "losses": 4,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3783,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:06:57.845Z",
                "fetchedAt": "2025-04-01T01:06:57.771Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "13240d14-e79e-4f02-bac0-b9b8256e294b",
                "profileId": "13240d14-e79e-4f02-bac0-b9b8256e294b",
                "displayName": "LethalCatboy",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 54.6546546547,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 211,
                            "deaths": 84,
                            "wins": 30,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3848,
                            "rank": "unranked",
                            "maxRank": "emerald-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:10:28.477Z",
                "fetchedAt": "2025-04-01T01:10:28.259Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "efa88109-d6d5-408b-bd93-fb2668139b8d",
                "profileId": "0be55570-478b-4aeb-83b2-904901a2f299",
                "displayName": "MainMontagn",
                "platform": "psn",
                "level": 59,
                "headshotRate": 46.1756373938,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T00:00:42.169Z",
                "fetchedAt": "2025-04-01T00:00:42.045Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "efa88109-d6d5-408b-bd93-fb2668139b8d",
                "profileId": "efa88109-d6d5-408b-bd93-fb2668139b8d",
                "displayName": "Z1Kago",
                "platform": "uplay",
                "level": 59,
                "headshotRate": 46.1756373938,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 89,
                            "deaths": 40,
                            "wins": 9,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1903,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T03:23:59.968Z",
                "fetchedAt": "2025-04-01T03:23:59.882Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d779f092-8b55-4fb7-851d-8573e827d03c",
                "profileId": "379e7105-5cb8-4104-801c-885d331286a3",
                "displayName": "iXLXM-",
                "platform": "psn",
                "level": 119,
                "headshotRate": 63.8370118846,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T00:08:09.980Z",
                "fetchedAt": "2025-04-01T00:08:09.907Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "79630bf7-a77f-4992-8b36-cf3741c508f4",
                "profileId": "79630bf7-a77f-4992-8b36-cf3741c508f4",
                "displayName": "toxicbno1",
                "platform": "uplay",
                "level": 101,
                "headshotRate": 48.8652824722,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:26:58.505Z",
                "fetchedAt": "2025-04-01T01:26:58.434Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "883a5dcd-4236-4851-bfaa-ebf1e9e9de0d",
                "profileId": "883a5dcd-4236-4851-bfaa-ebf1e9e9de0d",
                "displayName": "Extratight69",
                "platform": "uplay",
                "level": 94,
                "headshotRate": 46.9094393867,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 720,
                            "deaths": 605,
                            "wins": 89,
                            "losses": 48,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3810,
                            "rank": "unranked",
                            "maxRank": "emerald-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T00:33:42.436Z",
                "fetchedAt": "2025-04-01T00:33:42.369Z"
            },
            "createdAt": "2025-03-31T20:56:33.193Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0c2df60e-2b78-4a1a-b104-abe30521ee9c",
                "profileId": "0c2df60e-2b78-4a1a-b104-abe30521ee9c",
                "displayName": "slashug-",
                "platform": "uplay",
                "level": 274,
                "headshotRate": 58.9060308555,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 136,
                            "deaths": 71,
                            "wins": 14,
                            "losses": 6,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2613,
                            "rank": "unranked",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T00:00:46.194Z",
                "fetchedAt": "2025-04-01T00:00:46.088Z"
            },
            "createdAt": "2025-03-31T20:56:33.193Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bf6ce1e3-0946-411e-947d-d09e868c4bfd",
                "profileId": "743a4158-5ddb-4d33-82a2-764869ab4495",
                "displayName": "SND Respond",
                "platform": "xbl",
                "level": 119,
                "headshotRate": 45.830797322,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T23:19:20.503Z",
                "fetchedAt": "2025-03-31T23:19:20.420Z"
            },
            "createdAt": "2025-03-31T18:46:21.045Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bf6ce1e3-0946-411e-947d-d09e868c4bfd",
                "profileId": "bf6ce1e3-0946-411e-947d-d09e868c4bfd",
                "displayName": "PinkUnicorn72",
                "platform": "uplay",
                "level": 119,
                "headshotRate": 45.830797322,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 117,
                            "deaths": 49,
                            "wins": 17,
                            "losses": 2,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2967,
                            "rank": "unranked",
                            "maxRank": "gold-1"
                        }
                    }
                },
                "updatedAt": "2025-03-31T19:26:48.636Z",
                "fetchedAt": "2025-03-31T19:26:48.561Z"
            },
            "createdAt": "2025-03-31T18:46:21.045Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d28919e8-5a3a-4029-a157-caec6d95f78a",
                "profileId": "d28919e8-5a3a-4029-a157-caec6d95f78a",
                "displayName": "ELBESTEVER",
                "platform": "uplay",
                "level": 212,
                "headshotRate": 36.8790397045,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 385,
                            "deaths": 212,
                            "wins": 55,
                            "losses": 17,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2887,
                            "rank": "unranked",
                            "maxRank": "gold-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T22:42:45.647Z",
                "fetchedAt": "2025-03-31T22:42:45.527Z"
            },
            "createdAt": "2025-03-31T18:36:20.861Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9888c613-5f1c-44c5-95b6-114fec37f31f",
                "profileId": "9888c613-5f1c-44c5-95b6-114fec37f31f",
                "displayName": "SUPERNICK24",
                "platform": "uplay",
                "level": 110,
                "headshotRate": 42.4194815397,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T18:19:36.183Z",
                "fetchedAt": "2025-03-31T18:19:36.077Z"
            },
            "createdAt": "2025-03-31T18:16:21.035Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c95cbaef-0856-47b2-b2b0-d2e1c2a6613a",
                "profileId": "c95cbaef-0856-47b2-b2b0-d2e1c2a6613a",
                "displayName": "CLK_Putty",
                "platform": "uplay",
                "level": 85,
                "headshotRate": 57.1537872992,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 74,
                            "deaths": 95,
                            "wins": 6,
                            "losses": 13,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 1271,
                            "rank": "unranked",
                            "maxRank": "copper-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T18:11:49.194Z",
                "fetchedAt": "2025-03-31T18:11:49.112Z"
            },
            "createdAt": "2025-03-31T17:56:20.885Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "48b8d09a-1a52-47dc-a897-641566284916",
                "profileId": "48b8d09a-1a52-47dc-a897-641566284916",
                "displayName": "Avq-",
                "platform": "uplay",
                "level": 182,
                "headshotRate": 52.2069292833,
                "leaderboardPosition": 8444,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 352,
                            "deaths": 274,
                            "wins": 34,
                            "losses": 31,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3982,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-03-31T21:03:46.193Z",
                "fetchedAt": "2025-03-31T21:03:46.082Z"
            },
            "createdAt": "2025-03-31T17:26:20.956Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a530a7d8-b144-4c81-8915-ba3f9f194d2d",
                "profileId": "a530a7d8-b144-4c81-8915-ba3f9f194d2d",
                "displayName": "Pocoloco02",
                "platform": "uplay",
                "level": 75,
                "headshotRate": 55.0847457627,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T17:23:34.198Z",
                "fetchedAt": "2025-03-31T17:23:34.009Z"
            },
            "createdAt": "2025-03-31T14:06:34.521Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e1bf98d7-628d-4c36-ad32-592036f4bf0a",
                "profileId": "e1bf98d7-628d-4c36-ad32-592036f4bf0a",
                "displayName": "FadedDem0n",
                "platform": "uplay",
                "level": 59,
                "headshotRate": 20.9054593875,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 281,
                            "deaths": 109,
                            "wins": 25,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3370,
                            "rank": "unranked",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T14:18:38.389Z",
                "fetchedAt": "2025-03-31T14:18:38.307Z"
            },
            "createdAt": "2025-03-31T13:56:27.357Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2500202c-9821-4db9-8d47-b624054ee905",
                "profileId": "955993ff-c2ec-49c7-9665-4d57d41c7c4f",
                "displayName": "FSGimpactYT",
                "platform": "xbl",
                "level": 155,
                "headshotRate": 52.776875609,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T15:07:34.327Z",
                "fetchedAt": "2025-03-31T15:07:34.225Z"
            },
            "createdAt": "2025-03-31T13:56:27.357Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0e9dbe62-9c22-4341-9a6a-4f02bc38357c",
                "profileId": "0e9dbe62-9c22-4341-9a6a-4f02bc38357c",
                "displayName": "RaidX10",
                "platform": "uplay",
                "level": 26,
                "headshotRate": 73.7762237762,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T21:13:06.293Z",
                "fetchedAt": "2025-03-31T21:13:06.207Z"
            },
            "createdAt": "2025-03-31T13:56:27.357Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a5ed7b32-ed1a-4719-8eea-dc88526e100e",
                "profileId": "a5ed7b32-ed1a-4719-8eea-dc88526e100e",
                "displayName": "ekitten17",
                "platform": "uplay",
                "level": 128,
                "headshotRate": 48.0370533745,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 213,
                            "deaths": 50,
                            "wins": 22,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1901,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-03-31T14:20:56.325Z",
                "fetchedAt": "2025-03-31T14:20:56.245Z"
            },
            "createdAt": "2025-03-31T13:56:27.357Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "236c6260-bacd-40e5-9736-6a9c123dfffe",
                "profileId": "236c6260-bacd-40e5-9736-6a9c123dfffe",
                "displayName": "leftouttt",
                "platform": "uplay",
                "level": 90,
                "headshotRate": 43.4108527132,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 521,
                            "deaths": 320,
                            "wins": 51,
                            "losses": 25,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 2349,
                            "rank": "unranked",
                            "maxRank": "silver-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T14:13:33.216Z",
                "fetchedAt": "2025-03-31T14:13:33.125Z"
            },
            "createdAt": "2025-03-31T13:56:27.357Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "25c39da1-6a38-4e82-b319-79b4b42bd38e",
                "profileId": "25c39da1-6a38-4e82-b319-79b4b42bd38e",
                "displayName": "y5k.dnd",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 50.3184713376,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 450,
                            "deaths": 266,
                            "wins": 47,
                            "losses": 16,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 4239,
                            "rank": "unranked",
                            "maxRank": "diamond-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T14:25:46.840Z",
                "fetchedAt": "2025-03-31T14:25:46.755Z"
            },
            "createdAt": "2025-03-31T13:46:27.638Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "30267e9c-8a22-4b5f-ae20-ca48f23fb066",
                "profileId": "30267e9c-8a22-4b5f-ae20-ca48f23fb066",
                "displayName": "Cutoux",
                "platform": "uplay",
                "level": 78,
                "headshotRate": 53.3172496984,
                "leaderboardPosition": 8567,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 780,
                            "deaths": 534,
                            "wins": 72,
                            "losses": 50,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4351,
                            "rank": "unranked",
                            "maxRank": "diamond-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T23:02:42.489Z",
                "fetchedAt": "2025-03-31T23:02:42.391Z"
            },
            "createdAt": "2025-03-31T13:46:27.638Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "852f6f7f-3256-4b5d-871b-0862f4e3a4d5",
                "profileId": "852f6f7f-3256-4b5d-871b-0862f4e3a4d5",
                "displayName": "monke041910",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 52.6077097506,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 148,
                            "deaths": 128,
                            "wins": 16,
                            "losses": 14,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2250,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:23:07.037Z",
                "fetchedAt": "2025-03-31T16:23:06.952Z"
            },
            "createdAt": "2025-03-31T13:46:27.638Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2b5d0190-df9b-49da-a603-c9de15bdc5fe",
                "profileId": "2b5d0190-df9b-49da-a603-c9de15bdc5fe",
                "displayName": "ilovespooned",
                "platform": "uplay",
                "level": 123,
                "headshotRate": 53.4971644612,
                "leaderboardPosition": 6396,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 695,
                            "deaths": 428,
                            "wins": 65,
                            "losses": 40,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4433,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T03:21:40.245Z",
                "fetchedAt": "2025-04-01T03:21:40.111Z"
            },
            "createdAt": "2025-03-31T13:46:27.638Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d1a71f8c-d3d9-498a-89b7-5358da2a8847",
                "profileId": "d1a71f8c-d3d9-498a-89b7-5358da2a8847",
                "displayName": "laleettomigit",
                "platform": "uplay",
                "level": 53,
                "headshotRate": 35,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 48,
                            "deaths": 13,
                            "wins": 5,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1498,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-03-31T13:53:09.343Z",
                "fetchedAt": "2025-03-31T13:53:08.996Z"
            },
            "createdAt": "2025-03-31T13:36:29.363Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "47870fad-37a9-4f91-bfb4-b1f481900a74",
                "profileId": "47870fad-37a9-4f91-bfb4-b1f481900a74",
                "displayName": "skidoomotocross",
                "platform": "uplay",
                "level": 54,
                "headshotRate": 55.5319148936,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T15:07:02.932Z",
                "fetchedAt": "2025-03-31T15:07:02.838Z"
            },
            "createdAt": "2025-03-31T13:36:29.363Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "87f407c8-6785-4fa2-855e-0b5c11378311",
                "profileId": "87f407c8-6785-4fa2-855e-0b5c11378311",
                "displayName": "ZenRogue",
                "platform": "uplay",
                "level": 121,
                "headshotRate": 46.3131731566,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 544,
                            "deaths": 325,
                            "wins": 40,
                            "losses": 43,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 1653,
                            "rank": "unranked",
                            "maxRank": "bronze-4"
                        }
                    }
                },
                "updatedAt": "2025-03-31T14:00:42.395Z",
                "fetchedAt": "2025-03-31T14:00:42.306Z"
            },
            "createdAt": "2025-03-31T13:36:29.363Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fce3ea4f-73fe-40eb-a681-9a3d0911820d",
                "profileId": "fce3ea4f-73fe-40eb-a681-9a3d0911820d",
                "displayName": "DMA.Cheater",
                "platform": "uplay",
                "level": 81,
                "headshotRate": 56.0621761658,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 243,
                            "deaths": 143,
                            "wins": 21,
                            "losses": 13,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3311,
                            "rank": "unranked",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T04:00:41.059Z",
                "fetchedAt": "2025-04-01T04:00:40.967Z"
            },
            "createdAt": "2025-03-31T13:26:26.560Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "dd3081b7-b31e-4c06-995f-a65275d8b640",
                "profileId": "a0deeb28-ae1c-4b92-8123-3846ebb8c8f8",
                "displayName": "Lowkeyyzennn",
                "platform": "xbl",
                "level": 138,
                "headshotRate": 60.3325415677,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 57,
                            "deaths": 63,
                            "wins": 13,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2016,
                            "rank": "unranked",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T03:23:43.341Z",
                "fetchedAt": "2025-04-01T03:23:43.255Z"
            },
            "createdAt": "2025-03-31T13:26:26.560Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "36572fb7-6e0d-4da4-b62e-bef01c0d5780",
                "profileId": "36572fb7-6e0d-4da4-b62e-bef01c0d5780",
                "displayName": "Zoit...",
                "platform": "uplay",
                "level": 142,
                "headshotRate": 56.0257589696,
                "leaderboardPosition": 1083,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1004,
                            "deaths": 580,
                            "wins": 98,
                            "losses": 50,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4617,
                            "maxTopRankPosition": 1011,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T01:41:09.727Z",
                "fetchedAt": "2025-04-01T01:41:09.644Z"
            },
            "createdAt": "2025-03-31T13:26:26.560Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4939ea5a-6613-4417-b03f-4b80f9a075f6",
                "profileId": "4939ea5a-6613-4417-b03f-4b80f9a075f6",
                "displayName": "Socks-.-",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 62.4,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T13:52:03.184Z",
                "fetchedAt": "2025-03-31T13:52:03.096Z"
            },
            "createdAt": "2025-03-31T13:26:26.560Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d552cb8d-819b-40f7-b130-d2721cb756fa",
                "profileId": "d552cb8d-819b-40f7-b130-d2721cb756fa",
                "displayName": "Aydentaxx",
                "platform": "uplay",
                "level": 122,
                "headshotRate": 50.2750611247,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1061,
                            "deaths": 889,
                            "wins": 121,
                            "losses": 84,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4101,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T03:23:14.389Z",
                "fetchedAt": "2025-04-01T03:23:14.304Z"
            },
            "createdAt": "2025-03-31T13:26:26.560Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "38fbdc9d-c6ed-40d7-a564-31ed73f0357d",
                "profileId": "38fbdc9d-c6ed-40d7-a564-31ed73f0357d",
                "displayName": "SixSeven._.",
                "platform": "uplay",
                "level": 56,
                "headshotRate": 17.5595238095,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 77,
                            "deaths": 41,
                            "wins": 12,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2187,
                            "rank": "unranked",
                            "maxRank": "silver-4"
                        }
                    }
                },
                "updatedAt": "2025-03-31T15:30:05.208Z",
                "fetchedAt": "2025-03-31T15:30:05.111Z"
            },
            "createdAt": "2025-03-31T13:16:27.422Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3042c3bb-cd54-4159-8634-c7c5a07b49f5",
                "profileId": "3042c3bb-cd54-4159-8634-c7c5a07b49f5",
                "displayName": "J9R.",
                "platform": "uplay",
                "level": 158,
                "headshotRate": 75.1295336788,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 243,
                            "deaths": 88,
                            "wins": 23,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3360,
                            "rank": "unranked",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T19:28:48.996Z",
                "fetchedAt": "2025-03-31T19:28:48.913Z"
            },
            "createdAt": "2025-03-31T13:16:27.422Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c18e787c-b025-41b2-a456-ad4ff34ce8e2",
                "profileId": "c18e787c-b025-41b2-a456-ad4ff34ce8e2",
                "displayName": "guest-54332224",
                "platform": "uplay",
                "level": 85,
                "headshotRate": 42.8662420382,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 78,
                            "deaths": 37,
                            "wins": 7,
                            "losses": 2,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1825,
                            "rank": "unranked",
                            "maxRank": "bronze-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T15:47:20.437Z",
                "fetchedAt": "2025-03-31T15:47:20.348Z"
            },
            "createdAt": "2025-03-31T13:16:27.422Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c18e787c-b025-41b2-a456-ad4ff34ce8e2",
                "profileId": "a328cb7a-114a-4fe8-8b6f-e79d24107707",
                "displayName": "oc spinz",
                "platform": "xbl",
                "level": 85,
                "headshotRate": 42.8662420382,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T13:28:42.041Z",
                "fetchedAt": "2025-03-31T13:28:41.952Z"
            },
            "createdAt": "2025-03-31T13:16:27.422Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d4374a42-f674-414d-883a-ef32b7cf8712",
                "profileId": "e2b42663-ae14-4322-96d5-a427ae94ccf1",
                "displayName": "sum rollr",
                "platform": "xbl",
                "level": 117,
                "headshotRate": 47.3595125254,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T00:00:44.173Z",
                "fetchedAt": "2025-04-01T00:00:44.071Z"
            },
            "createdAt": "2025-03-31T13:16:27.422Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "5acf00cb-fad7-4a34-b359-a36389fa4d2c",
                "profileId": "5acf00cb-fad7-4a34-b359-a36389fa4d2c",
                "displayName": "MeloStayMelo",
                "platform": "uplay",
                "level": 51,
                "headshotRate": 51.2658227848,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T16:22:25.320Z",
                "fetchedAt": "2025-03-31T16:22:25.228Z"
            },
            "createdAt": "2025-03-31T10:36:36.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bc2a5f35-8408-4b4b-b377-2fc63e9528db",
                "profileId": "bed512f0-1c1b-4a06-9a82-432a6ca9120b",
                "displayName": "Xd_fizz1e5",
                "platform": "psn",
                "level": 153,
                "headshotRate": 42.500472858,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T16:38:52.723Z",
                "fetchedAt": "2025-03-31T16:38:52.626Z"
            },
            "createdAt": "2025-03-31T10:36:36.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8341bd8d-42fa-4b4b-8619-744e67adc1f8",
                "profileId": "8341bd8d-42fa-4b4b-8619-744e67adc1f8",
                "displayName": "I--TRACER--I",
                "platform": "uplay",
                "level": 138,
                "headshotRate": 37.2163388805,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 134,
                            "deaths": 125,
                            "wins": 24,
                            "losses": 7,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2407,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-03-31T15:57:30.542Z",
                "fetchedAt": "2025-03-31T15:57:30.349Z"
            },
            "createdAt": "2025-03-31T10:36:36.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bc2a5f35-8408-4b4b-b377-2fc63e9528db",
                "profileId": "bc2a5f35-8408-4b4b-b377-2fc63e9528db",
                "displayName": "bigstim45",
                "platform": "uplay",
                "level": 153,
                "headshotRate": 42.500472858,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 352,
                            "deaths": 283,
                            "wins": 43,
                            "losses": 22,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3019,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:25.518Z",
                "fetchedAt": "2025-03-31T16:21:25.451Z"
            },
            "createdAt": "2025-03-31T10:36:36.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e51bf80b-4220-419b-9e57-fa1337a150f0",
                "profileId": "e51bf80b-4220-419b-9e57-fa1337a150f0",
                "displayName": "Gunnaaa.",
                "platform": "uplay",
                "level": 123,
                "headshotRate": 62.9187224098,
                "leaderboardPosition": 9999,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 637,
                            "deaths": 463,
                            "wins": 43,
                            "losses": 65,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3788,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:57.532Z",
                "fetchedAt": "2025-03-31T16:21:57.348Z"
            },
            "createdAt": "2025-03-31T10:36:36.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7286d1ed-7963-4fcc-923b-a51480a2813c",
                "profileId": "7286d1ed-7963-4fcc-923b-a51480a2813c",
                "displayName": "BFG-_-",
                "platform": "uplay",
                "level": 244,
                "headshotRate": 46.7945922372,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T03:18:37.776Z",
                "fetchedAt": "2025-04-01T03:18:37.700Z"
            },
            "createdAt": "2025-03-31T10:36:36.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e686eeac-5c6e-4241-90fe-1006e6dd5927",
                "profileId": "e686eeac-5c6e-4241-90fe-1006e6dd5927",
                "displayName": "booster82347211",
                "platform": "uplay",
                "level": 34,
                "headshotRate": 50.9036144578,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T01:07:00.741Z",
                "fetchedAt": "2025-04-01T01:07:00.667Z"
            },
            "createdAt": "2025-03-31T10:26:29.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c146355c-d4ef-45ce-8628-dbbcea016a24",
                "profileId": "b5bc46b2-c2a0-432e-93be-4b5434c66e3a",
                "displayName": "kl0xs",
                "platform": "xbl",
                "level": 151,
                "headshotRate": 47.3631508678,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T03:23:29.451Z",
                "fetchedAt": "2025-04-01T03:23:29.324Z"
            },
            "createdAt": "2025-03-31T10:26:29.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c146355c-d4ef-45ce-8628-dbbcea016a24",
                "profileId": "c146355c-d4ef-45ce-8628-dbbcea016a24",
                "displayName": "Peeping.",
                "platform": "uplay",
                "level": 151,
                "headshotRate": 47.3631508678,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 342,
                            "deaths": 210,
                            "wins": 41,
                            "losses": 15,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3839,
                            "rank": "unranked",
                            "maxRank": "emerald-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T03:02:58.561Z",
                "fetchedAt": "2025-04-01T03:02:58.457Z"
            },
            "createdAt": "2025-03-31T10:26:29.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e2f376a0-1675-4eca-a13a-efb8823b9d3a",
                "profileId": "56413c1f-7e9c-4543-b53f-e385ef484f11",
                "displayName": "T SZN T",
                "platform": "xbl",
                "level": 109,
                "headshotRate": 40.7373828951,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T11:16:59.887Z",
                "fetchedAt": "2025-03-31T11:16:59.680Z"
            },
            "createdAt": "2025-03-31T10:16:29.771Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "5fef31b0-08b8-47ab-a81b-b11d4961ad2c",
                "profileId": "5fef31b0-08b8-47ab-a81b-b11d4961ad2c",
                "displayName": "Raahannd",
                "platform": "uplay",
                "level": 64,
                "headshotRate": 58.273381295,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 298,
                            "deaths": 55,
                            "wins": 23,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3346,
                            "rank": "unranked",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:51.329Z",
                "fetchedAt": "2025-03-31T16:21:51.215Z"
            },
            "createdAt": "2025-03-31T10:16:29.771Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6e2a745d-fb2c-48ce-8853-c485f9392eaa",
                "profileId": "aea25dbf-28f1-40ef-bd7c-0898a26b8668",
                "displayName": "N0T Z3Z3R",
                "platform": "xbl",
                "level": 116,
                "headshotRate": 49.802890933,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T12:37:13.527Z",
                "fetchedAt": "2025-03-31T12:37:13.438Z"
            },
            "createdAt": "2025-03-31T10:16:29.771Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "21f5adbf-8ec6-430b-a1b2-5b631ae86239",
                "profileId": "21f5adbf-8ec6-430b-a1b2-5b631ae86239",
                "displayName": "Luxvd",
                "platform": "uplay",
                "level": 122,
                "headshotRate": 46.6649886735,
                "leaderboardPosition": 1442,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1163,
                            "deaths": 753,
                            "wins": 124,
                            "losses": 71,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4555,
                            "maxTopRankPosition": 1484,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:22:19.266Z",
                "fetchedAt": "2025-03-31T16:22:19.178Z"
            },
            "createdAt": "2025-03-31T10:16:29.771Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "73b29bd5-60c8-4553-92b8-a8fcf760b209",
                "profileId": "73b29bd5-60c8-4553-92b8-a8fcf760b209",
                "displayName": "Dybala13009",
                "platform": "uplay",
                "level": 32,
                "headshotRate": 52.3985239852,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T16:20:59.541Z",
                "fetchedAt": "2025-03-31T16:20:59.344Z"
            },
            "createdAt": "2025-03-31T10:06:29.004Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7d59f522-d27d-49ba-a3bf-6149247615d2",
                "profileId": "7d59f522-d27d-49ba-a3bf-6149247615d2",
                "displayName": "AshB0rnM0narch",
                "platform": "uplay",
                "level": 57,
                "headshotRate": 31.4183123878,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 241,
                            "deaths": 101,
                            "wins": 23,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3170,
                            "rank": "unranked",
                            "maxRank": "platinum-4"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:04.027Z",
                "fetchedAt": "2025-03-31T16:21:03.869Z"
            },
            "createdAt": "2025-03-31T10:06:29.004Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e16d251a-27b9-4697-bf09-48fb45d37ff5",
                "profileId": "e16d251a-27b9-4697-bf09-48fb45d37ff5",
                "displayName": "Yeet-.",
                "platform": "uplay",
                "level": 68,
                "headshotRate": 55.3658536585,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T16:21:51.279Z",
                "fetchedAt": "2025-03-31T16:21:51.060Z"
            },
            "createdAt": "2025-03-31T10:06:29.004Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7caed995-dd0b-4778-8893-01dba880b1a4",
                "profileId": "7caed995-dd0b-4778-8893-01dba880b1a4",
                "displayName": "Xylo.NP",
                "platform": "uplay",
                "level": 152,
                "headshotRate": 56.9138276553,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 120,
                            "deaths": 83,
                            "wins": 12,
                            "losses": 7,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2356,
                            "rank": "unranked",
                            "maxRank": "silver-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T03:33:46.304Z",
                "fetchedAt": "2025-04-01T03:33:46.144Z"
            },
            "createdAt": "2025-03-31T10:06:29.004Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "cfa4ffc5-0eea-4aeb-b785-b8b5dc091d85",
                "profileId": "cfa4ffc5-0eea-4aeb-b785-b8b5dc091d85",
                "displayName": "GokruxTV",
                "platform": "uplay",
                "level": 89,
                "headshotRate": 58.3249243189,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 135,
                            "deaths": 244,
                            "wins": 19,
                            "losses": 29,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1705,
                            "rank": "unranked",
                            "maxRank": "bronze-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:22:49.044Z",
                "fetchedAt": "2025-03-31T16:22:48.937Z"
            },
            "createdAt": "2025-03-31T09:56:28.534Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "5b08242c-0afa-4705-9bcb-cef3e667bc83",
                "profileId": "67d6d80a-cace-4ea8-b40a-45e604a0ef12",
                "displayName": "wyPerkss",
                "platform": "psn",
                "level": 75,
                "headshotRate": 65.6891495601,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T11:17:05.247Z",
                "fetchedAt": "2025-03-31T11:17:05.128Z"
            },
            "createdAt": "2025-03-31T09:56:28.534Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "acb56ec5-7cdf-4681-9b87-2162eb0ad3e8",
                "profileId": "acb56ec5-7cdf-4681-9b87-2162eb0ad3e8",
                "displayName": "MEZARCI_TR",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 47.1215351812,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T16:21:53.461Z",
                "fetchedAt": "2025-03-31T16:21:53.234Z"
            },
            "createdAt": "2025-03-31T09:56:28.534Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ec7a520b-5cec-423b-9256-f290faac92fe",
                "profileId": "ec7a520b-5cec-423b-9256-f290faac92fe",
                "displayName": "sigmasteve1",
                "platform": "uplay",
                "level": 85,
                "headshotRate": 46.2365591398,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 587,
                            "deaths": 650,
                            "wins": 85,
                            "losses": 64,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2965,
                            "rank": "unranked",
                            "maxRank": "gold-1"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:20:55.534Z",
                "fetchedAt": "2025-03-31T16:20:55.446Z"
            },
            "createdAt": "2025-03-31T09:46:28.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f5036ea7-06f2-4224-b140-ed0f32af0533",
                "profileId": "f5036ea7-06f2-4224-b140-ed0f32af0533",
                "displayName": "Rowloe.",
                "platform": "uplay",
                "level": 88,
                "headshotRate": 38.6726228462,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 198,
                            "deaths": 208,
                            "wins": 24,
                            "losses": 21,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1781,
                            "rank": "unranked",
                            "maxRank": "bronze-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:53.461Z",
                "fetchedAt": "2025-03-31T16:21:53.234Z"
            },
            "createdAt": "2025-03-31T09:46:28.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "cbcb6532-6258-417f-a8d5-184898f250f1",
                "profileId": "cbcb6532-6258-417f-a8d5-184898f250f1",
                "displayName": "duraa_",
                "platform": "uplay",
                "level": 114,
                "headshotRate": 64.6606914213,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 219,
                            "deaths": 104,
                            "wins": 16,
                            "losses": 10,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2823,
                            "rank": "unranked",
                            "maxRank": "gold-2"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:22:49.347Z",
                "fetchedAt": "2025-03-31T16:22:49.182Z"
            },
            "createdAt": "2025-03-31T09:46:28.505Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c71ea3f5-7f01-46de-9652-620a32d82e83",
                "profileId": "c71ea3f5-7f01-46de-9652-620a32d82e83",
                "displayName": "US2._.",
                "platform": "uplay",
                "level": 57,
                "headshotRate": 63.4850166482,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T12:35:08.782Z",
                "fetchedAt": "2025-03-31T12:35:08.618Z"
            },
            "createdAt": "2025-03-31T09:36:28.649Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fab33a73-bbfd-4b6a-895b-604623c29c14",
                "profileId": "fab33a73-bbfd-4b6a-895b-604623c29c14",
                "displayName": "Biggunnaar15",
                "platform": "uplay",
                "level": 68,
                "headshotRate": 58.9455488332,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1,
                            "deaths": 1,
                            "wins": 0,
                            "losses": 0,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:27.155Z",
                "fetchedAt": "2025-03-31T16:21:27.059Z"
            },
            "createdAt": "2025-03-31T09:36:28.649Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2aba33e3-358f-4920-b7da-c039b8aa1dea",
                "profileId": "2aba33e3-358f-4920-b7da-c039b8aa1dea",
                "displayName": "hrd",
                "platform": "uplay",
                "level": 44,
                "headshotRate": 49.9082568807,
                "seasonalRecords": {},
                "updatedAt": "2025-03-31T16:21:57.531Z",
                "fetchedAt": "2025-03-31T16:21:57.348Z"
            },
            "createdAt": "2025-03-31T09:36:28.649Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9c911360-8f20-4371-94b5-5bb7701876e8",
                "profileId": "9c911360-8f20-4371-94b5-5bb7701876e8",
                "displayName": "ChampIsntGood",
                "platform": "uplay",
                "level": 72,
                "headshotRate": 62.8498727735,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 24,
                            "deaths": 8,
                            "wins": 2,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1233,
                            "rank": "unranked",
                            "maxRank": "copper-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T12:37:10.511Z",
                "fetchedAt": "2025-03-31T12:37:10.423Z"
            },
            "createdAt": "2025-03-31T09:36:28.649Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "dee658f6-cc6a-434f-ad6c-a9a33f2b0299",
                "profileId": "dee658f6-cc6a-434f-ad6c-a9a33f2b0299",
                "displayName": "xJurkMyCLOCKx",
                "platform": "uplay",
                "level": 80,
                "headshotRate": 52.3555555556,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 117,
                            "deaths": 61,
                            "wins": 11,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2210,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T12:35:53.422Z",
                "fetchedAt": "2025-03-31T12:35:53.335Z"
            },
            "createdAt": "2025-03-31T09:36:28.649Z",
            "reason": "cheating"
        }
    ]
}

# %%
import pandas as pd
import numpy as np

# %%
# Extract relevant fields into a list of dictionaries
records = [
    {
        "Display Name": ban["profile"]["displayName"],
        "Platform": ban["profile"]["platform"],
        "Level": ban["profile"]["level"],
        "Headshot Rate (%)": ban["profile"]["headshotRate"],
        "Reason": ban["reason"]
    }
    for ban in data["bans"]
]

# Convert to DataFrame
df = pd.DataFrame(records)

# Display basic statistics
summary = {
    "Total Bans": len(df),
    "Average Level": df["Level"].mean(),
    "Average Headshot Rate (%)": df["Headshot Rate (%)"].mean(),
    "Max Headshot Rate (%)": df["Headshot Rate (%)"].max(),
    "Min Headshot Rate (%)": df["Headshot Rate (%)"].min(),
    "Most Common Platform": df["Platform"].mode()[0]
}

summary_df = pd.DataFrame([summary])

# %%
summary_df
# Out:
#    Total Bans  Average Level  Average Headshot Rate (%)  \
# 0         100          98.47                  51.364838
#
#    Max Headshot Rate (%)  Min Headshot Rate (%) Most Common Platform
# 0              92.248062              17.559524                uplay

# %%
# Updated parsing to include seasonal records if present
parsed_with_seasonal_df = pd.DataFrame([
    {
        "Display Name": entry["profile"].get("displayName"),
        "Platform": entry["profile"].get("platform"),
        "Level": entry["profile"].get("level"),
        "Headshot Rate (%)": entry["profile"].get("headshotRate"),
        "Kills": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("kills", np.nan),
        "Deaths": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("deaths", np.nan),
        "Wins": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("wins", np.nan),
        "Losses": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("losses", np.nan),
        "Abandons": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("abandons", np.nan),
        "Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rankPoints", np.nan),
        "Max Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRankPoints", np.nan),
        "Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rank", np.nan),
        "Max Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRank", np.nan),
        "Reason": entry.get("reason", "N/A")
    }
    for entry in data['bans']
])

# %%
parsed_with_seasonal_df
# Out:
#      Display Name Platform  Level  Headshot Rate (%)  Kills  Deaths  Wins  \
# 0       PremeLuvz      xbl    132          36.862555    NaN     NaN   NaN
# 1       ahdapter.    uplay    202          40.547449  574.0   313.0  67.0
# 2         Edz1994    uplay     42          59.395973    NaN     NaN   NaN
# 3      mazoquismo    uplay     60          60.306644    NaN     NaN   NaN
# 4   Thibeau202012      psn     77          55.307856    NaN     NaN   NaN
# ..            ...      ...    ...                ...    ...     ...   ...
# 95         US2._.    uplay     57          63.485017    NaN     NaN   NaN
# 96   Biggunnaar15    uplay     68          58.945549    1.0     1.0   0.0
# 97            hrd    uplay     44          49.908257    NaN     NaN   NaN
# 98  ChampIsntGood    uplay     72          62.849873   24.0     8.0   2.0
# 99  xJurkMyCLOCKx    uplay     80          52.355556  117.0    61.0  11.0
#
#     Losses  Abandons  Rank Points  Max Rank Points      Rank   Max Rank  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(parsed_with_seasonal_df['Headshot Rate (%)'], edgecolor='black', bins=20)
# Out:
# (array([ 2.,  0.,  0.,  1.,  1.,  4., 12., 16., 13., 17., 13.,  9.,  8.,
#          1.,  0.,  2.,  0.,  0.,  0.,  1.]),
#  array([17.55952381, 21.29395072, 25.02837763, 28.76280454, 32.49723145,
#         36.23165836, 39.96608527, 43.70051218, 47.43493909, 51.169366  ,
#         54.90379291, 58.63821982, 62.37264673, 66.10707364, 69.84150055,
#         73.57592746, 77.31035437, 81.04478128, 84.77920819, 88.51363511,
#         92.24806202]),
#  <BarContainer object of 20 artists>)

# %%
df = parsed_with_seasonal_df

# %%
usernames = {}

# %%
def add_usernames(df, usernames):
    append_count = len(usernames) + 1
    append_name = f'append{append_count}'
    append_list = [x for x in df['Display Name']]

    usernames[append_name] = append_list

    return usernames

# %%
usernames2 = add_usernames(df, usernames)

# %%
import json

with open('../cheater_usernames_statscc/usernames.txt', 'w') as file:
    json.dump(usernames2, file, indent=4)
