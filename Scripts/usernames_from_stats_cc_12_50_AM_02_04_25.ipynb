# %%
data = {
    "bans": [
        {
            "profile": {
                "userId": "a4ad4e2d-dfe6-4268-93ed-2be907de6ea8",
                "profileId": "448616c5-149f-4b69-995e-549881050c5c",
                "displayName": "trigpeakz",
                "platform": "xbl",
                "level": 110,
                "headshotRate": 53.0516431925,
                "seasonalRecords": {},
                "updatedAt": "2025-03-01T10:04:14.926Z",
                "fetchedAt": "2024-10-04T23:05:37.618Z"
            },
            "createdAt": "2025-04-01T19:06:28.281Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a4ad4e2d-dfe6-4268-93ed-2be907de6ea8",
                "profileId": "a4ad4e2d-dfe6-4268-93ed-2be907de6ea8",
                "displayName": "ttvtragicxty",
                "platform": "uplay",
                "level": 121,
                "headshotRate": 53.3532446375,
                "leaderboardPosition": 3489,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 909,
                            "deaths": 402,
                            "wins": 76,
                            "losses": 32,
                            "abandons": 1,
                            "rankPoints": 4496,
                            "maxRankPoints": 4500,
                            "maxTopRankPosition": 3494,
                            "rank": "diamond-1",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:56:08.966Z",
                "fetchedAt": "2025-04-01T18:56:08.812Z"
            },
            "createdAt": "2025-04-01T19:06:28.281Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "121a5e17-9f1d-4754-9d11-56b534279aee",
                "profileId": "121a5e17-9f1d-4754-9d11-56b534279aee",
                "displayName": "Gonze.--.",
                "platform": "uplay",
                "level": 106,
                "headshotRate": 54.2086186065,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 221,
                            "deaths": 230,
                            "wins": 14,
                            "losses": 30,
                            "abandons": 1,
                            "rankPoints": 2400,
                            "maxRankPoints": 2401,
                            "rank": "silver-1",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-03-24T09:06:29.196Z",
                "fetchedAt": "2025-03-24T09:06:29.117Z"
            },
            "createdAt": "2025-04-01T18:56:28.314Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ef7ddfd4-28ec-4914-ad7c-951249ece23a",
                "profileId": "88e14a37-85fe-4c29-a182-df93d537bc2d",
                "displayName": "tuono_tuonante20",
                "platform": "psn",
                "level": 102,
                "headshotRate": 41.8918918919,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T18:59:42.717Z",
                "fetchedAt": "2025-04-01T18:59:42.636Z"
            },
            "createdAt": "2025-04-01T18:46:28.113Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "43a0b648-1549-47bf-8ab7-0c451a77325b",
                "profileId": "43a0b648-1549-47bf-8ab7-0c451a77325b",
                "displayName": "islamsevers",
                "platform": "uplay",
                "level": 140,
                "headshotRate": 40.2756508423,
                "leaderboardPosition": 9995,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 407,
                            "deaths": 241,
                            "wins": 44,
                            "losses": 16,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 4176,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T19:13:54.693Z",
                "fetchedAt": "2025-04-01T19:13:54.611Z"
            },
            "createdAt": "2025-04-01T18:36:28.220Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b7713280-098f-48ea-8796-5c76e0734470",
                "profileId": "b7713280-098f-48ea-8796-5c76e0734470",
                "displayName": "ExoltGN",
                "platform": "uplay",
                "level": 483,
                "headshotRate": 66.5700588363,
                "leaderboardPosition": 25,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1402,
                            "deaths": 921,
                            "wins": 278,
                            "losses": 25,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 5288,
                            "maxTopRankPosition": 1,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T19:10:37.403Z",
                "fetchedAt": "2025-04-01T19:10:37.215Z"
            },
            "createdAt": "2025-04-01T18:36:28.220Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4e826c23-641b-44bf-985f-59391279abad",
                "profileId": "4e826c23-641b-44bf-985f-59391279abad",
                "displayName": "dewyandbabs",
                "platform": "uplay",
                "level": 148,
                "headshotRate": 36.0673745881,
                "seasonalRecords": {},
                "updatedAt": "2025-03-16T10:27:33.283Z",
                "fetchedAt": "2025-03-16T10:27:33.094Z"
            },
            "createdAt": "2025-04-01T18:26:28.224Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0d406507-0dd5-4b03-aecd-606b526af54f",
                "profileId": "0d406507-0dd5-4b03-aecd-606b526af54f",
                "displayName": "AlIM-_-",
                "platform": "uplay",
                "level": 177,
                "headshotRate": 43.6367179887,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 90,
                            "deaths": 111,
                            "wins": 13,
                            "losses": 11,
                            "abandons": 0,
                            "rankPoints": 2165,
                            "maxRankPoints": 2173,
                            "rank": "silver-4",
                            "maxRank": "silver-4"
                        }
                    }
                },
                "updatedAt": "2025-03-16T12:00:57.212Z",
                "fetchedAt": "2025-03-16T12:00:57.113Z"
            },
            "createdAt": "2025-04-01T18:26:28.224Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2eac6ed4-8d28-4b83-961c-b324d8f1c5cd",
                "profileId": "2eac6ed4-8d28-4b83-961c-b324d8f1c5cd",
                "displayName": "Toast..NVM",
                "platform": "uplay",
                "level": 415,
                "headshotRate": 44.898601839,
                "leaderboardPosition": 4057,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1521,
                            "deaths": 983,
                            "wins": 158,
                            "losses": 95,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4739,
                            "maxTopRankPosition": 313,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:12.939Z",
                "fetchedAt": "2025-04-01T18:40:12.850Z"
            },
            "createdAt": "2025-04-01T18:06:28.732Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8fd0f3b3-914f-4372-999f-b3aa14ecbe3d",
                "profileId": "8fd0f3b3-914f-4372-999f-b3aa14ecbe3d",
                "displayName": "method-r6",
                "platform": "uplay",
                "level": 139,
                "headshotRate": 40.3264522324,
                "leaderboardPosition": 1180,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1050,
                            "deaths": 605,
                            "wins": 106,
                            "losses": 55,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4578,
                            "maxTopRankPosition": 1219,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T19:07:11.894Z",
                "fetchedAt": "2025-04-01T19:07:11.824Z"
            },
            "createdAt": "2025-04-01T17:56:29.656Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d42148ff-ffd4-4308-8068-0460d325d279",
                "profileId": "d42148ff-ffd4-4308-8068-0460d325d279",
                "displayName": "Mabusu",
                "platform": "uplay",
                "level": 279,
                "headshotRate": 58.7429993777,
                "leaderboardPosition": 4468,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 572,
                            "deaths": 503,
                            "wins": 70,
                            "losses": 43,
                            "abandons": 4,
                            "rankPoints": 1000,
                            "maxRankPoints": 4456,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:02:37.397Z",
                "fetchedAt": "2025-04-01T18:02:37.324Z"
            },
            "createdAt": "2025-04-01T17:46:27.918Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c2f0d0bb-7701-42fa-9e01-f39816e99fde",
                "profileId": "c2f0d0bb-7701-42fa-9e01-f39816e99fde",
                "displayName": "RipTvuw",
                "platform": "uplay",
                "level": 176,
                "headshotRate": 50.2074688797,
                "leaderboardPosition": 881,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1452,
                            "deaths": 1110,
                            "wins": 148,
                            "losses": 121,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4644,
                            "maxTopRankPosition": 785,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:14.948Z",
                "fetchedAt": "2025-04-01T18:40:14.845Z"
            },
            "createdAt": "2025-04-01T17:46:27.918Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8b51dc2c-669f-471b-a8d6-19e91da526ab",
                "profileId": "8b51dc2c-669f-471b-a8d6-19e91da526ab",
                "displayName": "Amuro93Ray",
                "platform": "uplay",
                "level": 170,
                "headshotRate": 42.2212741752,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 403,
                            "deaths": 361,
                            "wins": 50,
                            "losses": 36,
                            "abandons": 1,
                            "rankPoints": 3775,
                            "maxRankPoints": 3775,
                            "rank": "emerald-3",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-03-29T13:09:07.685Z",
                "fetchedAt": "2025-03-29T13:09:07.595Z"
            },
            "createdAt": "2025-04-01T17:36:37.817Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d6321673-373f-422c-81b5-19500ae23334",
                "profileId": "d6321673-373f-422c-81b5-19500ae23334",
                "displayName": "KJO187",
                "platform": "uplay",
                "level": 204,
                "headshotRate": 45.04084014,
                "seasonalRecords": {},
                "updatedAt": "2025-02-14T07:52:28.770Z",
                "fetchedAt": "2024-09-10T09:28:01.593Z"
            },
            "createdAt": "2025-04-01T17:26:38.389Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "adc43a16-4232-4d20-be45-162f923479b5",
                "profileId": "4af6d6c2-6342-4d23-a30d-fab1425090e9",
                "displayName": "centoriq",
                "platform": "xbl",
                "level": 250,
                "headshotRate": 56.4896755162,
                "seasonalRecords": {},
                "updatedAt": "2025-03-06T06:53:16.333Z",
                "fetchedAt": "2024-10-19T01:51:59.969Z"
            },
            "createdAt": "2025-04-01T17:16:37.784Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "adc43a16-4232-4d20-be45-162f923479b5",
                "profileId": "e7883683-05a4-465b-a9b1-a60be297eafb",
                "displayName": "slqrio",
                "platform": "psn",
                "level": 250,
                "headshotRate": 56.4682734875,
                "seasonalRecords": {},
                "updatedAt": "2025-02-21T13:23:37.631Z",
                "fetchedAt": "2024-11-07T03:48:58.591Z"
            },
            "createdAt": "2025-04-01T17:16:37.784Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7e80ea49-fc0d-43bd-98e9-d87a10d2543b",
                "profileId": "7e80ea49-fc0d-43bd-98e9-d87a10d2543b",
                "displayName": "Zonix-",
                "platform": "uplay",
                "level": 350,
                "headshotRate": 60.0287735284,
                "leaderboardPosition": 5085,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 630,
                            "deaths": 647,
                            "wins": 82,
                            "losses": 59,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4455,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:34:55.681Z",
                "fetchedAt": "2025-04-01T17:34:55.602Z"
            },
            "createdAt": "2025-04-01T17:16:37.784Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "adc43a16-4232-4d20-be45-162f923479b5",
                "profileId": "adc43a16-4232-4d20-be45-162f923479b5",
                "displayName": "Ababa_",
                "platform": "uplay",
                "level": 252,
                "headshotRate": 56.886640607,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 262,
                            "deaths": 173,
                            "wins": 25,
                            "losses": 12,
                            "abandons": 2,
                            "rankPoints": 3258,
                            "maxRankPoints": 3258,
                            "rank": "platinum-3",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-03-31T21:06:40.852Z",
                "fetchedAt": "2025-03-31T21:06:40.767Z"
            },
            "createdAt": "2025-04-01T17:16:37.784Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fbf3891c-30fc-4a7a-adc7-a5e322c28a89",
                "profileId": "fbf3891c-30fc-4a7a-adc7-a5e322c28a89",
                "displayName": "Klar.User567",
                "platform": "uplay",
                "level": 138,
                "headshotRate": 49.5764600981,
                "leaderboardPosition": 738,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1775,
                            "deaths": 1355,
                            "wins": 182,
                            "losses": 102,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 4647,
                            "maxTopRankPosition": 742,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:19.061Z",
                "fetchedAt": "2025-04-01T18:40:18.965Z"
            },
            "createdAt": "2025-04-01T15:56:38.013Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9d14bbf4-1ad6-4fff-8d4e-e2faf779ea89",
                "profileId": "9d14bbf4-1ad6-4fff-8d4e-e2faf779ea89",
                "displayName": "xanvv.",
                "platform": "uplay",
                "level": 188,
                "headshotRate": 57.8939529342,
                "leaderboardPosition": 1184,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2278,
                            "deaths": 1294,
                            "wins": 193,
                            "losses": 105,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 4720,
                            "maxTopRankPosition": 368,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:19.699Z",
                "fetchedAt": "2025-04-01T18:40:19.611Z"
            },
            "createdAt": "2025-04-01T15:36:36.694Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "06879501-ecfe-427d-8005-ba6a9472138a",
                "profileId": "7894fa8e-722c-48d6-ae7f-33d88f3c3500",
                "displayName": "qaxqe",
                "platform": "psn",
                "level": 240,
                "headshotRate": 54.1368743616,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:09:11.735Z",
                "fetchedAt": "2025-04-01T17:09:11.652Z"
            },
            "createdAt": "2025-04-01T15:26:39.443Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "06879501-ecfe-427d-8005-ba6a9472138a",
                "profileId": "06879501-ecfe-427d-8005-ba6a9472138a",
                "displayName": "byib",
                "platform": "uplay",
                "level": 240,
                "headshotRate": 54.1368743616,
                "leaderboardPosition": 1299,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 323,
                            "deaths": 228,
                            "wins": 67,
                            "losses": 8,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4590,
                            "maxTopRankPosition": 1258,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T19:15:43.573Z",
                "fetchedAt": "2025-04-01T19:15:43.481Z"
            },
            "createdAt": "2025-04-01T15:26:39.443Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d3fefab8-2dd7-4ee8-8cf2-6bb19bb61636",
                "profileId": "d3fefab8-2dd7-4ee8-8cf2-6bb19bb61636",
                "displayName": "sekaa.",
                "platform": "uplay",
                "level": 341,
                "headshotRate": 44.7909841436,
                "leaderboardPosition": 689,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 698,
                            "deaths": 384,
                            "wins": 73,
                            "losses": 38,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4659,
                            "maxTopRankPosition": 709,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:23.571Z",
                "fetchedAt": "2025-04-01T18:40:23.491Z"
            },
            "createdAt": "2025-04-01T15:26:39.443Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c4dbdb8e-f34d-4134-8539-0ba2e676f5b0",
                "profileId": "c4dbdb8e-f34d-4134-8539-0ba2e676f5b0",
                "displayName": "Scythx.",
                "platform": "uplay",
                "level": 200,
                "headshotRate": 54.6485260771,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 364,
                            "deaths": 266,
                            "wins": 50,
                            "losses": 14,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4175,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:18.605Z",
                "fetchedAt": "2025-04-01T17:07:18.529Z"
            },
            "createdAt": "2025-04-01T15:06:36.497Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b66135da-805d-46ae-bf13-b8696049bccf",
                "profileId": "b66135da-805d-46ae-bf13-b8696049bccf",
                "displayName": "Zven.",
                "platform": "uplay",
                "level": 193,
                "headshotRate": 45.7323728444,
                "leaderboardPosition": 1579,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1693,
                            "deaths": 1124,
                            "wins": 174,
                            "losses": 108,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4695,
                            "maxTopRankPosition": 546,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:25.333Z",
                "fetchedAt": "2025-04-01T18:40:25.232Z"
            },
            "createdAt": "2025-04-01T14:46:38.260Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9b8d0898-cfd8-4873-9113-c98946e632db",
                "profileId": "9b8d0898-cfd8-4873-9113-c98946e632db",
                "displayName": "lmJust.Better",
                "platform": "uplay",
                "level": 380,
                "headshotRate": 60.0016359249,
                "leaderboardPosition": 6598,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2170,
                            "deaths": 1313,
                            "wins": 163,
                            "losses": 137,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4575,
                            "maxTopRankPosition": 1154,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:40:27.302Z",
                "fetchedAt": "2025-04-01T18:40:27.214Z"
            },
            "createdAt": "2025-04-01T14:36:41.117Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6ea0456c-aeff-4350-b0b8-47ceee676e07",
                "profileId": "6ea0456c-aeff-4350-b0b8-47ceee676e07",
                "displayName": "Grade-Account",
                "platform": "uplay",
                "level": 297,
                "headshotRate": 51.3177242393,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 151,
                            "deaths": 132,
                            "wins": 25,
                            "losses": 10,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3663,
                            "rank": "unranked",
                            "maxRank": "emerald-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:43.942Z",
                "fetchedAt": "2025-04-01T17:07:43.862Z"
            },
            "createdAt": "2025-04-01T14:26:43.453Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2f532845-44e9-4e5e-89ff-d6a03ce7628a",
                "profileId": "2f532845-44e9-4e5e-89ff-d6a03ce7628a",
                "displayName": "hydco",
                "platform": "uplay",
                "level": 46,
                "headshotRate": 58.1132075472,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:09:10.729Z",
                "fetchedAt": "2025-04-01T17:09:10.647Z"
            },
            "createdAt": "2025-04-01T10:16:34.205Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "838347de-e088-4141-8df7-7acd52195cc6",
                "profileId": "838347de-e088-4141-8df7-7acd52195cc6",
                "displayName": "HBsuperpidh",
                "platform": "uplay",
                "level": 69,
                "headshotRate": 62.7674750357,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:24.386Z",
                "fetchedAt": "2025-04-01T17:14:24.312Z"
            },
            "createdAt": "2025-04-01T10:16:34.205Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "41518b55-7ebf-4179-914a-75c79ddd7a44",
                "profileId": "41518b55-7ebf-4179-914a-75c79ddd7a44",
                "displayName": "AzodinR6",
                "platform": "uplay",
                "level": 58,
                "headshotRate": 55.7993730408,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 11,
                            "deaths": 1,
                            "wins": 1,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1115,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:15:07.527Z",
                "fetchedAt": "2025-04-01T17:15:07.452Z"
            },
            "createdAt": "2025-04-01T10:16:34.205Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "81ad4dc9-fb8b-445a-839c-959f2f166369",
                "profileId": "81ad4dc9-fb8b-445a-839c-959f2f166369",
                "displayName": "Magixs971",
                "platform": "uplay",
                "level": 117,
                "headshotRate": 38.9330682571,
                "leaderboardPosition": 9995,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 380,
                            "deaths": 390,
                            "wins": 43,
                            "losses": 33,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2649,
                            "rank": "unranked",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T18:26:55.146Z",
                "fetchedAt": "2025-04-01T18:26:54.984Z"
            },
            "createdAt": "2025-04-01T10:16:34.111Z",
            "reason": "botting"
        },
        {
            "profile": {
                "userId": "a0e270f8-5e2a-44e8-a668-400978fe50f9",
                "profileId": "cbe6d42c-d9c2-4827-9ca3-40b63107bb00",
                "displayName": "Kopfkjno",
                "platform": "xbl",
                "level": 182,
                "headshotRate": 51.6949152542,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:15:21.594Z",
                "fetchedAt": "2025-04-01T17:15:21.442Z"
            },
            "createdAt": "2025-04-01T10:06:26.383Z",
            "reason": "botting"
        },
        {
            "profile": {
                "userId": "c3be5694-469c-4715-8d58-0f0d86a1a1b4",
                "profileId": "c3be5694-469c-4715-8d58-0f0d86a1a1b4",
                "displayName": "AI_warden",
                "platform": "uplay",
                "level": 107,
                "headshotRate": 51.0699588477,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 754,
                            "deaths": 736,
                            "wins": 88,
                            "losses": 78,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3286,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:12.360Z",
                "fetchedAt": "2025-04-01T17:07:12.186Z"
            },
            "createdAt": "2025-04-01T10:06:26.325Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a888eef4-466a-4133-8db6-691a83254867",
                "profileId": "a888eef4-466a-4133-8db6-691a83254867",
                "displayName": "IIBXDII",
                "platform": "uplay",
                "level": 114,
                "headshotRate": 55.2748885587,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:10:37.219Z",
                "fetchedAt": "2025-04-01T17:10:37.110Z"
            },
            "createdAt": "2025-04-01T10:06:26.325Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4da635dd-8e42-4577-ac39-13c3d612774a",
                "profileId": "4da635dd-8e42-4577-ac39-13c3d612774a",
                "displayName": "Shaiiko.BDG",
                "platform": "uplay",
                "level": 83,
                "headshotRate": 59.7510373444,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:13:16.341Z",
                "fetchedAt": "2025-04-01T17:13:16.240Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1338afc4-1516-459d-b695-dbf6484579d3",
                "profileId": "1338afc4-1516-459d-b695-dbf6484579d3",
                "displayName": "dihnigh",
                "platform": "uplay",
                "level": 73,
                "headshotRate": 51.3601741023,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:17:39.512Z",
                "fetchedAt": "2025-04-01T17:17:39.409Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b3c1cc97-4128-482c-b8f0-457f328a0ee9",
                "profileId": "b3c1cc97-4128-482c-b8f0-457f328a0ee9",
                "displayName": "d.yn",
                "platform": "uplay",
                "level": 148,
                "headshotRate": 65.1136905708,
                "leaderboardPosition": 4235,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 808,
                            "deaths": 398,
                            "wins": 62,
                            "losses": 47,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4455,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:23.739Z",
                "fetchedAt": "2025-04-01T17:07:23.658Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "16e01046-55ba-4459-8118-e58f7740cd21",
                "profileId": "16e01046-55ba-4459-8118-e58f7740cd21",
                "displayName": "ImPengwn",
                "platform": "uplay",
                "level": 48,
                "headshotRate": 48.4693877551,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:09:49.832Z",
                "fetchedAt": "2025-04-01T17:09:49.770Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a9ccd6d7-82f9-4547-9462-060d36fbeabc",
                "profileId": "a9ccd6d7-82f9-4547-9462-060d36fbeabc",
                "displayName": "dadddddy.didddy",
                "platform": "uplay",
                "level": 54,
                "headshotRate": 48.8888888889,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:17:17.174Z",
                "fetchedAt": "2025-04-01T17:17:17.091Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "88209714-27f1-43b6-a018-aceae3ae0bb1",
                "profileId": "88209714-27f1-43b6-a018-aceae3ae0bb1",
                "displayName": "Ciganyvero6969",
                "platform": "uplay",
                "level": 93,
                "headshotRate": 40.2195608782,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 137,
                            "deaths": 190,
                            "wins": 21,
                            "losses": 25,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1554,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:16:44.210Z",
                "fetchedAt": "2025-04-01T17:16:44.139Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6538af38-eae3-456d-a460-afb6ad768f0f",
                "profileId": "6538af38-eae3-456d-a460-afb6ad768f0f",
                "displayName": "YeatFan2093",
                "platform": "uplay",
                "level": 102,
                "headshotRate": 65.6895127993,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 86,
                            "deaths": 30,
                            "wins": 7,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1820,
                            "rank": "unranked",
                            "maxRank": "bronze-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:16:58.448Z",
                "fetchedAt": "2025-04-01T17:16:58.368Z"
            },
            "createdAt": "2025-04-01T09:56:26.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "babbd750-d043-43cc-8599-6a61c8efbd92",
                "profileId": "6aea93da-9ce3-42c1-98a2-d6f677ea09a7",
                "displayName": "Vs Ju1ce",
                "platform": "xbl",
                "level": 120,
                "headshotRate": 46.6990965949,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:12:47.082Z",
                "fetchedAt": "2025-04-01T17:12:46.987Z"
            },
            "createdAt": "2025-04-01T09:46:26.564Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2cf00d4a-78e5-443d-951d-f9f9a8924e0c",
                "profileId": "35caff74-28a6-4af3-90b9-0b351b24ec5c",
                "displayName": "Byan1nKbs4DGr4f4",
                "platform": "psn",
                "level": 115,
                "headshotRate": 54.4973544974,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:16:28.566Z",
                "fetchedAt": "2025-04-01T17:16:28.459Z"
            },
            "createdAt": "2025-04-01T09:46:26.564Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e31a0896-2152-45df-b487-0664335fd62f",
                "profileId": "8f3b3979-0336-44fd-af34-8ffc6de8f4f5",
                "displayName": "nobienoob",
                "platform": "xbl",
                "level": 140,
                "headshotRate": 42.6236378877,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 209,
                            "deaths": 188,
                            "wins": 20,
                            "losses": 20,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2718,
                            "rank": "unranked",
                            "maxRank": "gold-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:13:32.628Z",
                "fetchedAt": "2025-04-01T17:13:32.537Z"
            },
            "createdAt": "2025-04-01T09:46:26.564Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e31a0896-2152-45df-b487-0664335fd62f",
                "profileId": "e31a0896-2152-45df-b487-0664335fd62f",
                "displayName": "nobienoob",
                "platform": "uplay",
                "level": 140,
                "headshotRate": 42.6236378877,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 35,
                            "deaths": 82,
                            "wins": 13,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2426,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:09:15.027Z",
                "fetchedAt": "2025-04-01T17:09:14.945Z"
            },
            "createdAt": "2025-04-01T09:46:26.564Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "af415d81-8de0-4e11-91a2-a421813cb526",
                "profileId": "af415d81-8de0-4e11-91a2-a421813cb526",
                "displayName": "HechtRubrecht69",
                "platform": "uplay",
                "level": 86,
                "headshotRate": 52.9446757882,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:17:23.401Z",
                "fetchedAt": "2025-04-01T17:17:23.322Z"
            },
            "createdAt": "2025-04-01T09:46:26.564Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2cf00d4a-78e5-443d-951d-f9f9a8924e0c",
                "profileId": "2cf00d4a-78e5-443d-951d-f9f9a8924e0c",
                "displayName": "CitroenC4Pallas",
                "platform": "uplay",
                "level": 115,
                "headshotRate": 54.4973544974,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:13:19.292Z",
                "fetchedAt": "2025-04-01T17:13:19.214Z"
            },
            "createdAt": "2025-04-01T09:46:26.564Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d922ff9e-b06f-4f94-9541-6b2a42959adf",
                "profileId": "d922ff9e-b06f-4f94-9541-6b2a42959adf",
                "displayName": "Sleezy.jr",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 62.7157652474,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:07:03.947Z",
                "fetchedAt": "2025-04-01T17:07:03.854Z"
            },
            "createdAt": "2025-04-01T09:36:25.724Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "dd251dab-7060-4c05-b915-fbba456a05af",
                "profileId": "09b436f4-a31e-4523-b656-479d33a1e14e",
                "displayName": "Resist Slice",
                "platform": "xbl",
                "level": 124,
                "headshotRate": 43.5383747178,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:12:50.385Z",
                "fetchedAt": "2025-04-01T17:12:50.317Z"
            },
            "createdAt": "2025-04-01T09:36:25.724Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "743a3e85-7933-44f8-bd88-7739210c3b8e",
                "profileId": "743a3e85-7933-44f8-bd88-7739210c3b8e",
                "displayName": "autizim",
                "platform": "uplay",
                "level": 47,
                "headshotRate": 68.3333333333,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:10:32.317Z",
                "fetchedAt": "2025-04-01T17:10:32.249Z"
            },
            "createdAt": "2025-04-01T09:36:25.724Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a5ab2242-95db-4d17-9dcf-fec85ccea36e",
                "profileId": "a5ab2242-95db-4d17-9dcf-fec85ccea36e",
                "displayName": "MrOzempic_",
                "platform": "uplay",
                "level": 72,
                "headshotRate": 49.9339498018,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:30.479Z",
                "fetchedAt": "2025-04-01T17:14:30.368Z"
            },
            "createdAt": "2025-04-01T09:36:25.724Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b5a4e3df-cbdd-4315-b4c3-9ecff42d76f5",
                "profileId": "b5a4e3df-cbdd-4315-b4c3-9ecff42d76f5",
                "displayName": "YOU2103",
                "platform": "uplay",
                "level": 75,
                "headshotRate": 48.9130434783,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 285,
                            "deaths": 213,
                            "wins": 38,
                            "losses": 17,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3606,
                            "rank": "unranked",
                            "maxRank": "emerald-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:14:53.786Z",
                "fetchedAt": "2025-04-01T17:14:53.721Z"
            },
            "createdAt": "2025-04-01T09:26:28.080Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d261e90a-1885-4273-8cd6-e877ce216ee1",
                "profileId": "d261e90a-1885-4273-8cd6-e877ce216ee1",
                "displayName": "fentfoIdin",
                "platform": "uplay",
                "level": 105,
                "headshotRate": 48.864628821,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 910,
                            "deaths": 615,
                            "wins": 86,
                            "losses": 66,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2919,
                            "rank": "unranked",
                            "maxRank": "gold-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:13:59.252Z",
                "fetchedAt": "2025-04-01T17:13:59.053Z"
            },
            "createdAt": "2025-04-01T09:26:28.080Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f5a3b495-d1b5-4131-a9a7-6451c5259aa2",
                "profileId": "f5a3b495-d1b5-4131-a9a7-6451c5259aa2",
                "displayName": "lamepranks",
                "platform": "uplay",
                "level": 88,
                "headshotRate": 46.7910038398,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 35,
                            "deaths": 7,
                            "wins": 3,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1303,
                            "rank": "unranked",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:15:22.542Z",
                "fetchedAt": "2025-04-01T17:15:22.438Z"
            },
            "createdAt": "2025-04-01T09:26:28.080Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "df70612c-5c16-4f43-877c-f949aa34a632",
                "profileId": "df70612c-5c16-4f43-877c-f949aa34a632",
                "displayName": "JollyJ0rdan",
                "platform": "uplay",
                "level": 117,
                "headshotRate": 52.7777777778,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:16:06.493Z",
                "fetchedAt": "2025-04-01T17:16:06.409Z"
            },
            "createdAt": "2025-04-01T09:26:28.080Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "86c4a0de-aa60-467c-9fd7-5044ed666de1",
                "profileId": "86c4a0de-aa60-467c-9fd7-5044ed666de1",
                "displayName": "qlizxq",
                "platform": "uplay",
                "level": 110,
                "headshotRate": 53.164556962,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 250,
                            "deaths": 206,
                            "wins": 26,
                            "losses": 20,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2956,
                            "rank": "unranked",
                            "maxRank": "gold-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:09:44.005Z",
                "fetchedAt": "2025-04-01T17:09:43.933Z"
            },
            "createdAt": "2025-04-01T09:26:28.080Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "91392bbf-c116-42d2-bc25-ade4ddc360c9",
                "profileId": "91392bbf-c116-42d2-bc25-ade4ddc360c9",
                "displayName": "C8TV.JLee_115",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 46.9565217391,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 811,
                            "deaths": 478,
                            "wins": 71,
                            "losses": 45,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3948,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:09:54.587Z",
                "fetchedAt": "2025-04-01T17:09:54.423Z"
            },
            "createdAt": "2025-04-01T09:16:27.562Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "72659651-ecba-4559-ba02-36fce3176885",
                "profileId": "72659651-ecba-4559-ba02-36fce3176885",
                "displayName": "Chrlie.rage",
                "platform": "uplay",
                "level": 63,
                "headshotRate": 46.7463479416,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 145,
                            "deaths": 18,
                            "wins": 13,
                            "losses": 1,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2025,
                            "rank": "unranked",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:34.543Z",
                "fetchedAt": "2025-04-01T17:07:34.464Z"
            },
            "createdAt": "2025-04-01T09:16:27.562Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "24f35839-86b0-40e4-8724-8768c9650a9e",
                "profileId": "24f35839-86b0-40e4-8724-8768c9650a9e",
                "displayName": "Flaws.PDucks",
                "platform": "uplay",
                "level": 223,
                "headshotRate": 72.1784776903,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:20:01.489Z",
                "fetchedAt": "2025-04-01T17:20:01.392Z"
            },
            "createdAt": "2025-04-01T08:56:33.368Z",
            "reason": "toxic-behavior"
        },
        {
            "profile": {
                "userId": "e8f57f96-2553-4bae-975e-d4d188ea26d4",
                "profileId": "e8f57f96-2553-4bae-975e-d4d188ea26d4",
                "displayName": "Arune.",
                "platform": "uplay",
                "level": 229,
                "headshotRate": 72.4692526017,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:16:35.760Z",
                "fetchedAt": "2025-04-01T17:16:35.668Z"
            },
            "createdAt": "2025-04-01T07:16:32.581Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "774af0cf-f667-43d6-86f5-722be1e561a9",
                "profileId": "774af0cf-f667-43d6-86f5-722be1e561a9",
                "displayName": "gunkyfunk34",
                "platform": "uplay",
                "level": 74,
                "headshotRate": 65.1877133106,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:15:24.670Z",
                "fetchedAt": "2025-04-01T17:15:24.576Z"
            },
            "createdAt": "2025-04-01T04:26:21.976Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4c8c848f-c720-4631-89ce-e9eafb8d62d1",
                "profileId": "3bfa29f0-fd46-4683-bcf3-0696932402f6",
                "displayName": "PremeLuvz",
                "platform": "xbl",
                "level": 140,
                "headshotRate": 43.577700633,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:13:40.167Z",
                "fetchedAt": "2025-04-01T17:13:40.084Z"
            },
            "createdAt": "2025-04-01T03:16:37.735Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "57bf854a-8da0-4cdb-9496-9121c1638529",
                "profileId": "57bf854a-8da0-4cdb-9496-9121c1638529",
                "displayName": "ahdapter.",
                "platform": "uplay",
                "level": 202,
                "headshotRate": 40.5474491426,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 574,
                            "deaths": 313,
                            "wins": 67,
                            "losses": 15,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3951,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:37:59.418Z",
                "fetchedAt": "2025-04-01T17:37:59.341Z"
            },
            "createdAt": "2025-04-01T02:06:38.806Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "35b7a692-a359-4531-9fe7-a775c1b08233",
                "profileId": "35b7a692-a359-4531-9fe7-a775c1b08233",
                "displayName": "Edz1994",
                "platform": "uplay",
                "level": 42,
                "headshotRate": 59.3959731544,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:11:10.721Z",
                "fetchedAt": "2025-04-01T17:11:10.603Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b7e1069d-3095-4a88-bce7-c48cd039a1db",
                "profileId": "b7e1069d-3095-4a88-bce7-c48cd039a1db",
                "displayName": "mazoquismo",
                "platform": "uplay",
                "level": 60,
                "headshotRate": 60.3066439523,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:17:25.653Z",
                "fetchedAt": "2025-04-01T17:17:25.564Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "565808ee-7b86-441e-b5c1-9c237181b872",
                "profileId": "9c73ea77-1744-41b5-abff-9ed5d74b8e46",
                "displayName": "Thibeau202012",
                "platform": "psn",
                "level": 77,
                "headshotRate": 55.3078556263,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:13:38.878Z",
                "fetchedAt": "2025-04-01T17:13:38.774Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "565808ee-7b86-441e-b5c1-9c237181b872",
                "profileId": "565808ee-7b86-441e-b5c1-9c237181b872",
                "displayName": "TDF.SWINGSS",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 55.3078556263,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 59,
                            "deaths": 64,
                            "wins": 9,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1364,
                            "rank": "unranked",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:44.951Z",
                "fetchedAt": "2025-04-01T17:07:44.881Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f60bc4c0-da00-4707-9c41-9acae8af2dae",
                "profileId": "f60bc4c0-da00-4707-9c41-9acae8af2dae",
                "displayName": "ilyjahh",
                "platform": "uplay",
                "level": 76,
                "headshotRate": 59.9385245902,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 95,
                            "deaths": 35,
                            "wins": 12,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2280,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:14:22.254Z",
                "fetchedAt": "2025-04-01T17:14:22.172Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ef10f532-3106-44b0-9116-9edd16c8289e",
                "profileId": "ef10f532-3106-44b0-9116-9edd16c8289e",
                "displayName": "sluuhn.",
                "platform": "uplay",
                "level": 93,
                "headshotRate": 58.88177053,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:32.669Z",
                "fetchedAt": "2025-04-01T17:14:32.576Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e092b65d-cfea-4f21-bca4-6faf4f6147c3",
                "profileId": "e092b65d-cfea-4f21-bca4-6faf4f6147c3",
                "displayName": "Schlumpfprofil.",
                "platform": "uplay",
                "level": 93,
                "headshotRate": 45.5477855478,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 469,
                            "deaths": 329,
                            "wins": 52,
                            "losses": 28,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3536,
                            "rank": "unranked",
                            "maxRank": "emerald-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:15:52.692Z",
                "fetchedAt": "2025-04-01T17:15:52.503Z"
            },
            "createdAt": "2025-04-01T01:56:32.071Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ed840d22-9d04-4e6d-a5de-91b5a0df9171",
                "profileId": "ed840d22-9d04-4e6d-a5de-91b5a0df9171",
                "displayName": "Obidum",
                "platform": "uplay",
                "level": 104,
                "headshotRate": 53.431372549,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 131,
                            "deaths": 92,
                            "wins": 10,
                            "losses": 11,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2036,
                            "rank": "unranked",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:14:14.090Z",
                "fetchedAt": "2025-04-01T17:14:14.009Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "19aa58bc-4cf4-4ca0-9756-c2641e6f07df",
                "profileId": "19aa58bc-4cf4-4ca0-9756-c2641e6f07df",
                "displayName": "namatorerom",
                "platform": "uplay",
                "level": 81,
                "headshotRate": 54.9160671463,
                "leaderboardPosition": 9996,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 293,
                            "deaths": 258,
                            "wins": 31,
                            "losses": 27,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3378,
                            "rank": "unranked",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:15:23.611Z",
                "fetchedAt": "2025-04-01T17:15:23.523Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e9e80879-09fc-4055-956e-82ed80d9bf88",
                "profileId": "e9e80879-09fc-4055-956e-82ed80d9bf88",
                "displayName": "A__DOG",
                "platform": "uplay",
                "level": 45,
                "headshotRate": 52.6011560694,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:07:21.776Z",
                "fetchedAt": "2025-04-01T17:07:21.644Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bef586f3-e9f1-4b4b-a1a6-04106bf1a30d",
                "profileId": "bef586f3-e9f1-4b4b-a1a6-04106bf1a30d",
                "displayName": "k5da.",
                "platform": "uplay",
                "level": 68,
                "headshotRate": 41.4798206278,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:07:15.740Z",
                "fetchedAt": "2025-04-01T17:07:15.646Z"
            },
            "createdAt": "2025-04-01T01:46:31.362Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7c2f5f9e-8cd7-4c49-81c1-b99c293443fa",
                "profileId": "7c2f5f9e-8cd7-4c49-81c1-b99c293443fa",
                "displayName": "Shor3tyyyy",
                "platform": "uplay",
                "level": 17,
                "headshotRate": 56.25,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:15:45.245Z",
                "fetchedAt": "2025-04-01T17:15:45.165Z"
            },
            "createdAt": "2025-04-01T01:36:31.413Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fa19bac4-385f-489f-b293-ed7159ea8569",
                "profileId": "fa19bac4-385f-489f-b293-ed7159ea8569",
                "displayName": "shaw____08",
                "platform": "uplay",
                "level": 90,
                "headshotRate": 51.9454269833,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:11:43.303Z",
                "fetchedAt": "2025-04-01T17:11:43.217Z"
            },
            "createdAt": "2025-04-01T01:36:31.413Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "62c9120a-2848-4a70-80be-ec71a355eb57",
                "profileId": "62c9120a-2848-4a70-80be-ec71a355eb57",
                "displayName": "FUMEZ.K",
                "platform": "uplay",
                "level": 57,
                "headshotRate": 92.2480620155,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 43,
                            "deaths": 24,
                            "wins": 4,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1433,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:14.236Z",
                "fetchedAt": "2025-04-01T17:07:14.105Z"
            },
            "createdAt": "2025-04-01T01:26:31.967Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0f00caba-46cd-4b0f-97ee-0dd226a31e4f",
                "profileId": "0f00caba-46cd-4b0f-97ee-0dd226a31e4f",
                "displayName": "BruchTouPUissan",
                "platform": "uplay",
                "level": 130,
                "headshotRate": 45.4467903604,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 569,
                            "deaths": 302,
                            "wins": 67,
                            "losses": 25,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 4076,
                            "rank": "unranked",
                            "maxRank": "diamond-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:13:21.071Z",
                "fetchedAt": "2025-04-01T17:13:20.955Z"
            },
            "createdAt": "2025-04-01T01:26:31.967Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "ee3519c0-e242-4424-84e0-e9b152c4e228",
                "profileId": "ee3519c0-e242-4424-84e0-e9b152c4e228",
                "displayName": "MAF7565",
                "platform": "uplay",
                "level": 61,
                "headshotRate": 53.3577533578,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 203,
                            "deaths": 165,
                            "wins": 28,
                            "losses": 7,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3663,
                            "rank": "unranked",
                            "maxRank": "emerald-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:11:52.651Z",
                "fetchedAt": "2025-04-01T17:11:52.565Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8cad4584-9a44-4b24-a91f-e64b7b19f595",
                "profileId": "8cad4584-9a44-4b24-a91f-e64b7b19f595",
                "displayName": "Slit.exe",
                "platform": "uplay",
                "level": 40,
                "headshotRate": 56.4485981308,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:07:01.066Z",
                "fetchedAt": "2025-04-01T17:07:00.971Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bdea2d15-056e-4cc5-a2e8-25213341a868",
                "profileId": "bdea2d15-056e-4cc5-a2e8-25213341a868",
                "displayName": "uiatxnfdd3",
                "platform": "uplay",
                "level": 58,
                "headshotRate": 62.0111731844,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:43.838Z",
                "fetchedAt": "2025-04-01T17:14:43.761Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7c95a8c1-0b09-44dc-941e-2a2a11d365f7",
                "profileId": "7c95a8c1-0b09-44dc-941e-2a2a11d365f7",
                "displayName": "Hugepanda34",
                "platform": "uplay",
                "level": 87,
                "headshotRate": 53.2214401733,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 120,
                            "deaths": 72,
                            "wins": 16,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2658,
                            "rank": "unranked",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:12:51.189Z",
                "fetchedAt": "2025-04-01T17:12:51.091Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6b916bd1-4dd5-4bcb-bae8-d19046bd58d5",
                "profileId": "6b916bd1-4dd5-4bcb-bae8-d19046bd58d5",
                "displayName": "Bl4ckD34th_47",
                "platform": "uplay",
                "level": 145,
                "headshotRate": 50.1869857891,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 155,
                            "deaths": 140,
                            "wins": 21,
                            "losses": 9,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1817,
                            "rank": "unranked",
                            "maxRank": "bronze-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:33.476Z",
                "fetchedAt": "2025-04-01T17:07:33.361Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8d773571-74a1-49d8-8b00-ce5807e55e2b",
                "profileId": "8d773571-74a1-49d8-8b00-ce5807e55e2b",
                "displayName": "llIllIlIlIIlIII",
                "platform": "uplay",
                "level": 114,
                "headshotRate": 53.2340862423,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2,
                            "deaths": 9,
                            "wins": 0,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:14:11.790Z",
                "fetchedAt": "2025-04-01T17:14:11.701Z"
            },
            "createdAt": "2025-04-01T01:16:31.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3c68bb5e-ae30-4568-9382-412205332ba5",
                "profileId": "3c68bb5e-ae30-4568-9382-412205332ba5",
                "displayName": "Crayon-Eater2",
                "platform": "uplay",
                "level": 148,
                "headshotRate": 40.0131984162,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 116,
                            "deaths": 88,
                            "wins": 14,
                            "losses": 7,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2288,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:32.518Z",
                "fetchedAt": "2025-04-01T17:07:32.422Z"
            },
            "createdAt": "2025-04-01T00:56:29.983Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "11826378-73bf-4b08-aadd-45c2f201be9c",
                "profileId": "b94b348d-6105-4ec6-8fbd-6f675c4ace02",
                "displayName": "My kd fears",
                "platform": "xbl",
                "level": 121,
                "headshotRate": 43.2898967676,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 43,
                            "deaths": 144,
                            "wins": 7,
                            "losses": 23,
                            "abandons": 0,
                            "rankPoints": 1274,
                            "maxRankPoints": 1316,
                            "rank": "copper-3",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:12:59.769Z",
                "fetchedAt": "2025-04-01T17:12:59.680Z"
            },
            "createdAt": "2025-03-31T23:46:33.271Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "09eaff98-46ff-46fc-8d1a-e5a732b09ca6",
                "profileId": "8e99179e-228c-45b4-ad92-e67d743b0cc7",
                "displayName": "Seqxnce",
                "platform": "xbl",
                "level": 191,
                "headshotRate": 45.6117021277,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:13:06.160Z",
                "fetchedAt": "2025-04-01T17:13:06.066Z"
            },
            "createdAt": "2025-03-31T22:56:29.811Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "98bb7d5b-1160-4a00-bcbf-545bad76129f",
                "profileId": "98bb7d5b-1160-4a00-bcbf-545bad76129f",
                "displayName": "alvatoss.NRV",
                "platform": "uplay",
                "level": 208,
                "headshotRate": 51.9621109608,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 20,
                            "deaths": 28,
                            "wins": 2,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1213,
                            "rank": "unranked",
                            "maxRank": "copper-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:13:26.338Z",
                "fetchedAt": "2025-04-01T17:13:26.248Z"
            },
            "createdAt": "2025-03-31T21:56:32.941Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "76a80eb1-2cd8-41b7-ad2e-53dcb2446203",
                "profileId": "76a80eb1-2cd8-41b7-ad2e-53dcb2446203",
                "displayName": "STOMPNSTEPBRO",
                "platform": "uplay",
                "level": 41,
                "headshotRate": 40.6367041199,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:49.253Z",
                "fetchedAt": "2025-04-01T17:14:49.186Z"
            },
            "createdAt": "2025-03-31T21:36:27.633Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f2f67ca9-2151-4a7b-a35a-9d513d374c32",
                "profileId": "843322c9-fa4b-4e18-93f7-b0eecdcfc64d",
                "displayName": "Netrunnings",
                "platform": "xbl",
                "level": 90,
                "headshotRate": 47.6462196862,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:13:12.895Z",
                "fetchedAt": "2025-04-01T17:13:12.806Z"
            },
            "createdAt": "2025-03-31T21:36:27.633Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "911227a9-1e99-41c6-997b-db53cd153ed1",
                "profileId": "911227a9-1e99-41c6-997b-db53cd153ed1",
                "displayName": "YouTbeNBAFan",
                "platform": "uplay",
                "level": 32,
                "headshotRate": 64.6288209607,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:12:53.140Z",
                "fetchedAt": "2025-04-01T17:12:53.060Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6a6bb210-10c5-43d4-8c5d-2fdb1a19f501",
                "profileId": "6a6bb210-10c5-43d4-8c5d-2fdb1a19f501",
                "displayName": "phil-76",
                "platform": "uplay",
                "level": 55,
                "headshotRate": 48.4486873508,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 90,
                            "deaths": 71,
                            "wins": 10,
                            "losses": 7,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1458,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:20.608Z",
                "fetchedAt": "2025-04-01T17:07:20.518Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d3a74085-adf0-4f1f-bbfd-0860af7bb5e3",
                "profileId": "d3a74085-adf0-4f1f-bbfd-0860af7bb5e3",
                "displayName": "WashedOTV",
                "platform": "uplay",
                "level": 61,
                "headshotRate": 68.6070686071,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 190,
                            "deaths": 112,
                            "wins": 23,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3199,
                            "rank": "unranked",
                            "maxRank": "platinum-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:15:30.853Z",
                "fetchedAt": "2025-04-01T17:15:30.693Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d9e2b6f0-c219-4c25-91bf-ef8d3e487cb2",
                "profileId": "fcea4186-aa80-485b-ae1d-c70ad773f34e",
                "displayName": "Trashlikeurkid",
                "platform": "psn",
                "level": 97,
                "headshotRate": 50.6973500697,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:08.631Z",
                "fetchedAt": "2025-04-01T17:14:08.552Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "481822bb-a228-406c-aed9-353bf72cd83f",
                "profileId": "481822bb-a228-406c-aed9-353bf72cd83f",
                "displayName": "your_not_him...",
                "platform": "uplay",
                "level": 96,
                "headshotRate": 49.5647442873,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 17,
                            "deaths": 15,
                            "wins": 3,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1156,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:11:14.344Z",
                "fetchedAt": "2025-04-01T17:11:14.192Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fe170d0d-8db2-435b-94a1-0c39726b0761",
                "profileId": "fe170d0d-8db2-435b-94a1-0c39726b0761",
                "displayName": "LikoPasOuf",
                "platform": "uplay",
                "level": 154,
                "headshotRate": 60.4252144722,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2,
                            "deaths": 4,
                            "wins": 0,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:27:01.978Z",
                "fetchedAt": "2025-04-01T17:27:01.835Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d9e2b6f0-c219-4c25-91bf-ef8d3e487cb2",
                "profileId": "d9e2b6f0-c219-4c25-91bf-ef8d3e487cb2",
                "displayName": "ShaiikosDaddy",
                "platform": "uplay",
                "level": 97,
                "headshotRate": 50.6973500697,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 189,
                            "deaths": 71,
                            "wins": 27,
                            "losses": 4,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3783,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:14:47.640Z",
                "fetchedAt": "2025-04-01T17:14:47.545Z"
            },
            "createdAt": "2025-03-31T21:26:26.370Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "13240d14-e79e-4f02-bac0-b9b8256e294b",
                "profileId": "13240d14-e79e-4f02-bac0-b9b8256e294b",
                "displayName": "LethalCatboy",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 54.6546546547,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 211,
                            "deaths": 84,
                            "wins": 30,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3848,
                            "rank": "unranked",
                            "maxRank": "emerald-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:07:40.246Z",
                "fetchedAt": "2025-04-01T17:07:40.168Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "efa88109-d6d5-408b-bd93-fb2668139b8d",
                "profileId": "0be55570-478b-4aeb-83b2-904901a2f299",
                "displayName": "MainMontagn",
                "platform": "psn",
                "level": 59,
                "headshotRate": 46.1756373938,
                "seasonalRecords": {},
                "updatedAt": "2025-04-01T17:14:21.150Z",
                "fetchedAt": "2025-04-01T17:14:21.067Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "efa88109-d6d5-408b-bd93-fb2668139b8d",
                "profileId": "efa88109-d6d5-408b-bd93-fb2668139b8d",
                "displayName": "Z1Kago",
                "platform": "uplay",
                "level": 59,
                "headshotRate": 46.1756373938,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 89,
                            "deaths": 40,
                            "wins": 9,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1903,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-01T17:14:15.361Z",
                "fetchedAt": "2025-04-01T17:14:15.258Z"
            },
            "createdAt": "2025-03-31T21:16:28.921Z",
            "reason": "cheating"
        }
    ]
}

# %%
import pandas as pd
import numpy as np

# %%
# Extract relevant fields into a list of dictionaries
records = [
    {
        "Display Name": ban["profile"]["displayName"],
        "Platform": ban["profile"]["platform"],
        "Level": ban["profile"]["level"],
        "Headshot Rate (%)": ban["profile"]["headshotRate"],
        "Reason": ban["reason"]
    }
    for ban in data["bans"]
]

# Convert to DataFrame
df = pd.DataFrame(records)

# Display basic statistics
summary = {
    "Total Bans": len(df),
    "Average Level": df["Level"].mean(),
    "Average Headshot Rate (%)": df["Headshot Rate (%)"].mean(),
    "Max Headshot Rate (%)": df["Headshot Rate (%)"].max(),
    "Min Headshot Rate (%)": df["Headshot Rate (%)"].min(),
    "Most Common Platform": df["Platform"].mode()[0]
}

summary_df = pd.DataFrame([summary])

# %%
summary_df
# Out:
#    Total Bans  Average Level  Average Headshot Rate (%)  \
# 0         100         131.12                  52.630285
#
#    Max Headshot Rate (%)  Min Headshot Rate (%) Most Common Platform
# 0              92.248062              36.067375                uplay

# %%
# Updated parsing to include seasonal records if present
parsed_with_seasonal_df = pd.DataFrame([
    {
        "Display Name": entry["profile"].get("displayName"),
        "Platform": entry["profile"].get("platform"),
        "Level": entry["profile"].get("level"),
        "Headshot Rate (%)": entry["profile"].get("headshotRate"),
        "Kills": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("kills", np.nan),
        "Deaths": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("deaths", np.nan),
        "Wins": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("wins", np.nan),
        "Losses": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("losses", np.nan),
        "Abandons": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("abandons", np.nan),
        "Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rankPoints", np.nan),
        "Max Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRankPoints", np.nan),
        "Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rank", np.nan),
        "Max Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRank", np.nan),
        "Reason": entry.get("reason", "N/A")
    }
    for entry in data['bans']
])

# %%
parsed_with_seasonal_df
# Out:
#         Display Name Platform  Level  Headshot Rate (%)  Kills  Deaths  Wins  \
# 0          trigpeakz      xbl    110          53.051643    NaN     NaN   NaN
# 1       ttvtragicxty    uplay    121          53.353245  909.0   402.0  76.0
# 2          Gonze.--.    uplay    106          54.208619  221.0   230.0  14.0
# 3   tuono_tuonante20      psn    102          41.891892    NaN     NaN   NaN
# 4        islamsevers    uplay    140          40.275651  407.0   241.0  44.0
# ..               ...      ...    ...                ...    ...     ...   ...
# 95        LikoPasOuf    uplay    154          60.425214    2.0     4.0   0.0
# 96     ShaiikosDaddy    uplay     97          50.697350  189.0    71.0  27.0
# 97      LethalCatboy    uplay     77          54.654655  211.0    84.0  30.0
# 98       MainMontagn      psn     59          46.175637    NaN     NaN   NaN
# 99            Z1Kago    uplay     59          46.175637   89.0    40.0   9.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(parsed_with_seasonal_df['Headshot Rate (%)'], edgecolor='black', bins=20)
# Out:
# (array([ 1.,  8.,  8., 13.,  9., 12., 19.,  8.,  9.,  3.,  5.,  2.,  2.,
#          0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([36.06737459, 38.87640896, 41.68544333, 44.4944777 , 47.30351207,
#         50.11254644, 52.92158082, 55.73061519, 58.53964956, 61.34868393,
#         64.1577183 , 66.96675267, 69.77578704, 72.58482142, 75.39385579,
#         78.20289016, 81.01192453, 83.8209589 , 86.62999327, 89.43902764,
#         92.24806202]),
#  <BarContainer object of 20 artists>)

# %%
df = parsed_with_seasonal_df

# %%
import json

# %%
with open('../cheater_usernames_statscc/usernames.txt', 'r') as file:
    usernames = json.load(file)

# %%
def add_usernames(df, usernames):
    append_count = len(usernames) + 1
    append_name = f'append{append_count}'
    append_list = [x for x in df['Display Name']]

    usernames[append_name] = append_list

    return usernames

# %%
usernames2 = add_usernames(df, usernames)

# %%
import json

with open('../cheater_usernames_statscc/usernames.txt', 'w') as file:
    json.dump(usernames2, file, indent=4)
