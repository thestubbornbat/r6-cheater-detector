# %%
data = """
{
    "bans": [
        {
            "profile": {
                "userId": "6db21bcf-51db-46cd-9f4e-310ce07f1cb2",
                "profileId": "6db21bcf-51db-46cd-9f4e-310ce07f1cb2",
                "displayName": "netaneyuzu",
                "platform": "uplay",
                "level": 62,
                "headshotRate": 36.9205298013,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 336,
                            "deaths": 233,
                            "wins": 35,
                            "losses": 17,
                            "abandons": 1,
                            "rankPoints": 3502,
                            "maxRankPoints": 3517,
                            "rank": "emerald-5",
                            "maxRank": "emerald-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T23:37:08.180Z",
                "fetchedAt": "2025-04-03T23:37:08.085Z"
            },
            "createdAt": "2025-04-04T02:26:33.468Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "eecef726-9354-4535-a9a0-7f6dccb57a39",
                "profileId": "eecef726-9354-4535-a9a0-7f6dccb57a39",
                "displayName": "Depzaivcl2k",
                "platform": "uplay",
                "level": 77,
                "headshotRate": 54.4729849424,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:36:27.969Z",
                "fetchedAt": "2025-04-04T02:36:27.893Z"
            },
            "createdAt": "2025-04-04T02:26:33.468Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "dab5c5fe-0d4e-4d21-ad51-84ee003710bd",
                "profileId": "768826ae-0cb8-4324-aa40-ddb54156ee77",
                "displayName": "Tristin9412",
                "platform": "xbl",
                "level": 93,
                "headshotRate": 39.4562821455,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:32:24.850Z",
                "fetchedAt": "2025-04-04T02:32:24.774Z"
            },
            "createdAt": "2025-04-04T02:26:33.468Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d14065dd-8705-4b9d-b0d0-038323382d58",
                "profileId": "d14065dd-8705-4b9d-b0d0-038323382d58",
                "displayName": "FloppaTheBeast",
                "platform": "uplay",
                "level": 53,
                "headshotRate": 37.8548895899,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 99,
                            "deaths": 60,
                            "wins": 9,
                            "losses": 6,
                            "abandons": 0,
                            "rankPoints": 1875,
                            "maxRankPoints": 1875,
                            "rank": "bronze-2",
                            "maxRank": "bronze-2"
                        }
                    }
                },
                "updatedAt": "2025-04-01T00:00:53.826Z",
                "fetchedAt": "2025-04-01T00:00:53.729Z"
            },
            "createdAt": "2025-04-04T02:16:26.513Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4adc42bc-288d-4e24-867a-844013fa80a7",
                "profileId": "4adc42bc-288d-4e24-867a-844013fa80a7",
                "displayName": "Fasik.",
                "platform": "uplay",
                "level": 55,
                "headshotRate": 58.1151832461,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 103,
                            "deaths": 62,
                            "wins": 12,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 2183,
                            "maxRankPoints": 2183,
                            "rank": "silver-4",
                            "maxRank": "silver-4"
                        }
                    }
                },
                "updatedAt": "2025-03-31T10:37:24.579Z",
                "fetchedAt": "2025-03-31T10:37:24.465Z"
            },
            "createdAt": "2025-04-04T02:16:26.513Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8d9d208c-bb64-4feb-a195-180eb8330d27",
                "profileId": "8d9d208c-bb64-4feb-a195-180eb8330d27",
                "displayName": "Pero87v",
                "platform": "uplay",
                "level": 94,
                "headshotRate": 54.3545878694,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 57,
                            "deaths": 29,
                            "wins": 3,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1350,
                            "maxRankPoints": 1350,
                            "rank": "copper-2",
                            "maxRank": "copper-2"
                        }
                    }
                },
                "updatedAt": "2025-03-27T17:05:34.607Z",
                "fetchedAt": "2025-03-27T17:05:34.518Z"
            },
            "createdAt": "2025-04-04T02:16:26.513Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3c7f06b3-d219-4f8d-a20a-412febd51f61",
                "profileId": "3c7f06b3-d219-4f8d-a20a-412febd51f61",
                "displayName": "RANKUEN-MARKET",
                "platform": "uplay",
                "level": 58,
                "headshotRate": 87.7944325482,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:35:21.195Z",
                "fetchedAt": "2025-04-04T02:35:21.088Z"
            },
            "createdAt": "2025-04-04T02:06:26.406Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "da9eb826-7ff1-48a3-9918-9f45175541ad",
                "profileId": "da9eb826-7ff1-48a3-9918-9f45175541ad",
                "displayName": "ItrxIy.UNC",
                "platform": "uplay",
                "level": 109,
                "headshotRate": 58.2594681708,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 617,
                            "deaths": 483,
                            "wins": 58,
                            "losses": 51,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3790,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T04:28:29.713Z",
                "fetchedAt": "2025-04-04T04:28:29.595Z"
            },
            "createdAt": "2025-04-04T02:06:26.406Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "59c53d61-45b2-49be-8c1a-6b37d9c98d4a",
                "profileId": "c68e41a3-2e4e-4d04-b639-c2f3a151f96f",
                "displayName": "YayoBlunt",
                "platform": "psn",
                "level": 318,
                "headshotRate": 51.1048210373,
                "leaderboardPosition": 9987,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 144,
                            "deaths": 98,
                            "wins": 15,
                            "losses": 11,
                            "abandons": 3,
                            "rankPoints": 2676,
                            "maxRankPoints": 2684,
                            "rank": "gold-4",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-03-31T17:28:44.157Z",
                "fetchedAt": "2025-03-31T17:28:44.078Z"
            },
            "createdAt": "2025-04-04T02:06:26.406Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "59c53d61-45b2-49be-8c1a-6b37d9c98d4a",
                "profileId": "b7cd3f2a-34ad-4737-a9a7-be20aa8df841",
                "displayName": "soclosetocod2ra",
                "platform": "xbl",
                "level": 1000000,
                "headshotRate": 51.1450381679,
                "leaderboardPosition": 9988,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T04:32:23.281Z",
                "fetchedAt": "2025-04-04T04:32:23.199Z"
            },
            "createdAt": "2025-04-04T02:06:26.406Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "04ee0b7e-aec4-44f1-aac3-34d7bd5bf6a9",
                "profileId": "e4c3fa21-9d58-49b2-bf57-e0f249da0bb1",
                "displayName": "Cyper y7149",
                "platform": "xbl",
                "level": 88,
                "headshotRate": 41.5549597855,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:31:56.691Z",
                "fetchedAt": "2025-04-04T02:31:56.594Z"
            },
            "createdAt": "2025-04-04T02:06:26.406Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "2d246020-5d46-4915-a389-3da157303858",
                "profileId": "2d246020-5d46-4915-a389-3da157303858",
                "displayName": "yKirqs-",
                "platform": "uplay",
                "level": 110,
                "headshotRate": 55.8201058201,
                "seasonalRecords": {},
                "updatedAt": "2025-03-25T15:37:27.360Z",
                "fetchedAt": "2025-03-25T15:37:27.177Z"
            },
            "createdAt": "2025-04-04T02:06:26.406Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "89e025a7-3676-4eda-beff-04e6669be093",
                "profileId": "89e025a7-3676-4eda-beff-04e6669be093",
                "displayName": "ViewableSmurf00",
                "platform": "uplay",
                "level": 141,
                "headshotRate": 47.5409836066,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 132,
                            "deaths": 47,
                            "wins": 9,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 2011,
                            "maxRankPoints": 2011,
                            "rank": "silver-5",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T05:16:43.421Z",
                "fetchedAt": "2025-04-03T05:16:43.250Z"
            },
            "createdAt": "2025-04-04T01:56:26.642Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c065ae63-c30e-44f8-9f99-8e52029052c9",
                "profileId": "c065ae63-c30e-44f8-9f99-8e52029052c9",
                "displayName": "O42151q25",
                "platform": "uplay",
                "level": 67,
                "headshotRate": 48.0164158687,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 158,
                            "deaths": 86,
                            "wins": 17,
                            "losses": 7,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2629,
                            "rank": "unranked",
                            "maxRank": "gold-4"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:30:43.883Z",
                "fetchedAt": "2025-04-04T02:30:43.791Z"
            },
            "createdAt": "2025-04-04T01:56:26.642Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "89e025a7-3676-4eda-beff-04e6669be093",
                "profileId": "f7b51e16-e17f-44cf-a5a5-deea05f8f49c",
                "displayName": "DsM Triix",
                "platform": "xbl",
                "level": 142,
                "headshotRate": 46.4516129032,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 66,
                            "deaths": 75,
                            "wins": 7,
                            "losses": 8,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1727,
                            "rank": "unranked",
                            "maxRank": "bronze-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:32:53.083Z",
                "fetchedAt": "2025-04-04T02:32:52.992Z"
            },
            "createdAt": "2025-04-04T01:56:26.642Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9f0f43da-49c6-462c-a153-3b89925a5dd8",
                "profileId": "9f0f43da-49c6-462c-a153-3b89925a5dd8",
                "displayName": "champsmurfx1",
                "platform": "uplay",
                "level": 57,
                "headshotRate": 48.544973545,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 192,
                            "deaths": 57,
                            "wins": 14,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2261,
                            "rank": "unranked",
                            "maxRank": "silver-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:46:12.039Z",
                "fetchedAt": "2025-04-04T02:46:11.953Z"
            },
            "createdAt": "2025-04-04T01:56:26.642Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1a235d34-7e13-440c-a43f-76e428a5e071",
                "profileId": "1a235d34-7e13-440c-a43f-76e428a5e071",
                "displayName": "coolerboss",
                "platform": "uplay",
                "level": 105,
                "headshotRate": 69.6103896104,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:43.506Z",
                "fetchedAt": "2025-04-04T02:30:43.408Z"
            },
            "createdAt": "2025-04-04T01:46:28.051Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e7e6a34f-badc-4011-98dd-702e26101188",
                "profileId": "e7e6a34f-badc-4011-98dd-702e26101188",
                "displayName": "angled-grip",
                "platform": "uplay",
                "level": 91,
                "headshotRate": 50.8568269762,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 350,
                            "deaths": 357,
                            "wins": 31,
                            "losses": 45,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2752,
                            "rank": "unranked",
                            "maxRank": "gold-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:30:42.012Z",
                "fetchedAt": "2025-04-04T02:30:41.920Z"
            },
            "createdAt": "2025-04-04T01:46:28.051Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c0e13d81-abe0-4679-aab1-6a6572ffd735",
                "profileId": "c0e13d81-abe0-4679-aab1-6a6572ffd735",
                "displayName": "ItzYamo",
                "platform": "uplay",
                "level": 97,
                "headshotRate": 56.3776493256,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1425,
                            "deaths": 914,
                            "wins": 121,
                            "losses": 98,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4030,
                            "rank": "unranked",
                            "maxRank": "diamond-5"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:30:43.506Z",
                "fetchedAt": "2025-04-04T02:30:43.408Z"
            },
            "createdAt": "2025-04-04T01:46:28.051Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "3c712948-8b99-4444-910a-c3f63dcbc103",
                "profileId": "3c712948-8b99-4444-910a-c3f63dcbc103",
                "displayName": "ewxn77",
                "platform": "uplay",
                "level": 117,
                "headshotRate": 57.525083612,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 5,
                            "deaths": 4,
                            "wins": 1,
                            "losses": 0,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1122,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:01.082Z",
                "fetchedAt": "2025-04-04T01:48:00.990Z"
            },
            "createdAt": "2025-04-04T01:46:28.051Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "113cc566-6e30-48f7-bc7d-26d4c5fa0dd4",
                "profileId": "113cc566-6e30-48f7-bc7d-26d4c5fa0dd4",
                "displayName": "Jagers_ACOG_g",
                "platform": "uplay",
                "level": 34,
                "headshotRate": 42.0664206642,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:40.407Z",
                "fetchedAt": "2025-04-04T02:30:40.328Z"
            },
            "createdAt": "2025-04-04T01:36:27.098Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "02357d93-6ed0-4535-b395-cac6226762aa",
                "profileId": "02357d93-6ed0-4535-b395-cac6226762aa",
                "displayName": "TTV_NIGHT33",
                "platform": "uplay",
                "level": 20,
                "headshotRate": 71.7391304348,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:34:40.101Z",
                "fetchedAt": "2025-04-04T02:34:40.024Z"
            },
            "createdAt": "2025-04-04T01:36:27.098Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b9a9f834-77af-4578-a43a-978f05b62f87",
                "profileId": "b9a9f834-77af-4578-a43a-978f05b62f87",
                "displayName": "Bolu098",
                "platform": "uplay",
                "level": 83,
                "headshotRate": 43.0292598967,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:42.159Z",
                "fetchedAt": "2025-04-04T02:30:42.080Z"
            },
            "createdAt": "2025-04-04T01:36:27.098Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "295c7d7f-231b-460b-8458-bff39fc87517",
                "profileId": "295c7d7f-231b-460b-8458-bff39fc87517",
                "displayName": "yurr-AF",
                "platform": "uplay",
                "level": 76,
                "headshotRate": 52.4891774892,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 86,
                            "deaths": 36,
                            "wins": 4,
                            "losses": 4,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1439,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:12.598Z",
                "fetchedAt": "2025-04-04T01:48:12.522Z"
            },
            "createdAt": "2025-04-04T01:36:27.098Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "158a9db1-fc4b-4945-8ddc-ab26ba06438e",
                "profileId": "6ad4765d-2ad2-4780-9866-21f0bfba7a77",
                "displayName": "IIIIII5368",
                "platform": "xbl",
                "level": 143,
                "headshotRate": 49.1042944785,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 6,
                            "deaths": 5,
                            "wins": 1,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1055,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-03-31T16:21:25.401Z",
                "fetchedAt": "2025-03-31T16:21:25.298Z"
            },
            "createdAt": "2025-04-04T01:36:27.098Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f6f3fb73-0ec9-41f9-8ab0-2bab6a7a2272",
                "profileId": "f6f3fb73-0ec9-41f9-8ab0-2bab6a7a2272",
                "displayName": "hohepues",
                "platform": "uplay",
                "level": 59,
                "headshotRate": 89.2561983471,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 266,
                            "deaths": 53,
                            "wins": 21,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3286,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:35:45.899Z",
                "fetchedAt": "2025-04-04T02:35:45.752Z"
            },
            "createdAt": "2025-04-04T01:26:26.426Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "5f1a3c5b-adc1-49a5-83b7-0c1d11f987f2",
                "profileId": "5f1a3c5b-adc1-49a5-83b7-0c1d11f987f2",
                "displayName": "MiniFranky.",
                "platform": "uplay",
                "level": 70,
                "headshotRate": 59.3360995851,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 72,
                            "deaths": 37,
                            "wins": 7,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1676,
                            "rank": "unranked",
                            "maxRank": "bronze-4"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:33:34.772Z",
                "fetchedAt": "2025-04-04T02:33:34.610Z"
            },
            "createdAt": "2025-04-04T01:16:26.619Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bd44fe1d-e4d0-47f6-ba15-90976a3539b4",
                "profileId": "8fa19f33-42c5-451e-8051-aa8f740f50a1",
                "displayName": "BOT 1 BOT",
                "platform": "xbl",
                "level": 95,
                "headshotRate": 54.4155844156,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 0,
                            "deaths": 0,
                            "wins": 0,
                            "losses": 0,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-04T04:01:47.820Z",
                "fetchedAt": "2025-04-04T04:01:47.726Z"
            },
            "createdAt": "2025-04-04T01:16:26.619Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "91314c1a-5f13-4101-9de6-8fb8d034f95e",
                "profileId": "91314c1a-5f13-4101-9de6-8fb8d034f95e",
                "displayName": "Fxwn.",
                "platform": "uplay",
                "level": 104,
                "headshotRate": 54.0476990259,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 136,
                            "deaths": 87,
                            "wins": 9,
                            "losses": 10,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2032,
                            "rank": "unranked",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:04.915Z",
                "fetchedAt": "2025-04-04T01:48:04.795Z"
            },
            "createdAt": "2025-04-04T01:16:26.619Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b1197360-aacb-447a-b2b5-d67a0a1f7871",
                "profileId": "b1197360-aacb-447a-b2b5-d67a0a1f7871",
                "displayName": "Xel.Controller",
                "platform": "uplay",
                "level": 128,
                "headshotRate": 58.9270919635,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 417,
                            "deaths": 286,
                            "wins": 42,
                            "losses": 31,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4203,
                            "rank": "unranked",
                            "maxRank": "diamond-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:12.289Z",
                "fetchedAt": "2025-04-04T01:48:12.173Z"
            },
            "createdAt": "2025-04-04T01:16:26.619Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6ce3ac88-c005-4819-b2dc-f885775b0764",
                "profileId": "803aa5f7-0f58-424a-9555-771e7902a434",
                "displayName": "TRAPxWOODZ",
                "platform": "psn",
                "level": 105,
                "headshotRate": 36.9072164948,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:44.251Z",
                "fetchedAt": "2025-04-04T02:30:44.181Z"
            },
            "createdAt": "2025-04-04T00:06:41.773Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "30f877f8-b7d3-4da4-847f-90c5cd69cab0",
                "profileId": "30f877f8-b7d3-4da4-847f-90c5cd69cab0",
                "displayName": "crazylad002",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 55.5555555556,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T01:48:08.620Z",
                "fetchedAt": "2025-04-04T01:48:08.513Z"
            },
            "createdAt": "2025-04-03T23:56:40.936Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8b5e16bc-199f-4902-a2d3-b32ebd8f5cbe",
                "profileId": "8b5e16bc-199f-4902-a2d3-b32ebd8f5cbe",
                "displayName": "muuras16",
                "platform": "uplay",
                "level": 1000000,
                "headshotRate": 64.1414141414,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 6,
                            "deaths": 3,
                            "wins": 1,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1114,
                            "rank": "unranked",
                            "maxRank": "copper-4"
                        }
                    }
                },
                "updatedAt": "2025-04-04T04:19:14.159Z",
                "fetchedAt": "2025-04-04T04:19:14.063Z"
            },
            "createdAt": "2025-04-03T22:56:40.876Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "f8e20f59-3a58-401d-846d-c4b0cfaee653",
                "profileId": "f8e20f59-3a58-401d-846d-c4b0cfaee653",
                "displayName": "rthjo",
                "platform": "uplay",
                "level": 47,
                "headshotRate": 58.8764044944,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:43.506Z",
                "fetchedAt": "2025-04-04T02:30:43.408Z"
            },
            "createdAt": "2025-04-03T22:46:42.430Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "557135a0-8433-48f2-975c-591542ae35ee",
                "profileId": "557135a0-8433-48f2-975c-591542ae35ee",
                "displayName": "Bissssou",
                "platform": "uplay",
                "level": 142,
                "headshotRate": 41.3065326633,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T03:35:35.659Z",
                "fetchedAt": "2025-04-04T03:35:35.591Z"
            },
            "createdAt": "2025-04-03T21:56:39.343Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9edc086b-1306-46f8-9b20-96718e8aa6fb",
                "profileId": "9edc086b-1306-46f8-9b20-96718e8aa6fb",
                "displayName": "llIumi",
                "platform": "uplay",
                "level": 189,
                "headshotRate": 50.2183406114,
                "leaderboardPosition": 923,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1295,
                            "deaths": 608,
                            "wins": 137,
                            "losses": 37,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 4816,
                            "maxTopRankPosition": 199,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T05:08:07.255Z",
                "fetchedAt": "2025-04-04T05:08:07.155Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c8414cab-68b0-4354-8d25-e1692a816bf8",
                "profileId": "86441efb-4ef0-437c-9196-b68e2e0cdfc7",
                "displayName": "OOFITZTRAVIS",
                "platform": "xbl",
                "level": 155,
                "headshotRate": 59.2952612394,
                "leaderboardPosition": 9984,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:44.063Z",
                "fetchedAt": "2025-04-04T02:30:43.944Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "a0255551-92f2-4b46-b1ef-786a45c9da6d",
                "profileId": "a0255551-92f2-4b46-b1ef-786a45c9da6d",
                "displayName": "G-vz",
                "platform": "uplay",
                "level": 230,
                "headshotRate": 50.936967632,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 220,
                            "deaths": 102,
                            "wins": 34,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3529,
                            "rank": "unranked",
                            "maxRank": "emerald-5"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:30:40.407Z",
                "fetchedAt": "2025-04-04T02:30:40.328Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bc81edcf-0141-48ae-905c-fdc06f6a3fb8",
                "profileId": "3283759d-1981-4f5e-b9cc-325c57c92045",
                "displayName": "Restartedl",
                "platform": "psn",
                "level": 170,
                "headshotRate": 45.4266666667,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2,
                            "deaths": 9,
                            "wins": 0,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:04.915Z",
                "fetchedAt": "2025-04-04T01:48:04.795Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d9913542-e27d-4a48-a28d-323ab2b7b8c4",
                "profileId": "d9913542-e27d-4a48-a28d-323ab2b7b8c4",
                "displayName": "L4gion",
                "platform": "uplay",
                "level": 319,
                "headshotRate": 54.3776869036,
                "leaderboardPosition": 44,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 157,
                            "deaths": 84,
                            "wins": 30,
                            "losses": 1,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3212,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T04:16:00.384Z",
                "fetchedAt": "2025-04-04T04:16:00.225Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "77bd3f00-4236-4d05-a992-8eed35c77952",
                "profileId": "77bd3f00-4236-4d05-a992-8eed35c77952",
                "displayName": "Raymeud",
                "platform": "uplay",
                "level": 170,
                "headshotRate": 42.6308139535,
                "leaderboardPosition": 702,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 2237,
                            "deaths": 2014,
                            "wins": 254,
                            "losses": 184,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 4662,
                            "maxTopRankPosition": 668,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:12.315Z",
                "fetchedAt": "2025-04-04T01:48:12.244Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "23a5aaae-c0d8-469a-8ff8-75353d3a2da4",
                "profileId": "23a5aaae-c0d8-469a-8ff8-75353d3a2da4",
                "displayName": "SigmaGooner2006",
                "platform": "uplay",
                "level": 241,
                "headshotRate": 60.7065385807,
                "overlayUser": true,
                "overlayOnline": false,
                "leaderboardPosition": 2617,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 575,
                            "deaths": 338,
                            "wins": 84,
                            "losses": 25,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4559,
                            "maxTopRankPosition": 1457,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T05:15:28.701Z",
                "fetchedAt": "2025-04-04T05:15:28.610Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c8414cab-68b0-4354-8d25-e1692a816bf8",
                "profileId": "c8414cab-68b0-4354-8d25-e1692a816bf8",
                "displayName": "TeckyTravis",
                "platform": "uplay",
                "level": 155,
                "headshotRate": 59.2952612394,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 409,
                            "deaths": 327,
                            "wins": 48,
                            "losses": 28,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 2456,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:32:24.263Z",
                "fetchedAt": "2025-04-04T02:32:24.161Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bc81edcf-0141-48ae-905c-fdc06f6a3fb8",
                "profileId": "bc81edcf-0141-48ae-905c-fdc06f6a3fb8",
                "displayName": "Doc__.",
                "platform": "uplay",
                "level": 170,
                "headshotRate": 45.4266666667,
                "leaderboardPosition": 4783,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 674,
                            "deaths": 512,
                            "wins": 69,
                            "losses": 49,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4487,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:12.459Z",
                "fetchedAt": "2025-04-04T01:48:12.341Z"
            },
            "createdAt": "2025-04-03T21:46:32.637Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "117255c3-4e8a-488c-9a0c-3d64c8e20ebd",
                "profileId": "117255c3-4e8a-488c-9a0c-3d64c8e20ebd",
                "displayName": "tmxtrr..",
                "platform": "uplay",
                "level": 115,
                "headshotRate": 46.3782366437,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1085,
                            "deaths": 944,
                            "wins": 122,
                            "losses": 88,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 3714,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T02:30:42.159Z",
                "fetchedAt": "2025-04-04T02:30:42.080Z"
            },
            "createdAt": "2025-04-03T21:26:31.829Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "55a5e72e-420c-42b5-9d1a-b7f360201805",
                "profileId": "178a3bf6-d6db-4f2a-8ec2-bf0f5044c495",
                "displayName": "s_a_m_u_u_u",
                "platform": "psn",
                "level": 259,
                "headshotRate": 51.3265306122,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:33:23.359Z",
                "fetchedAt": "2025-04-04T02:33:23.277Z"
            },
            "createdAt": "2025-04-03T21:26:31.829Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "55a5e72e-420c-42b5-9d1a-b7f360201805",
                "profileId": "55a5e72e-420c-42b5-9d1a-b7f360201805",
                "displayName": "sa.mu",
                "platform": "uplay",
                "level": 259,
                "headshotRate": 51.3265306122,
                "leaderboardPosition": 9516,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1213,
                            "deaths": 806,
                            "wins": 113,
                            "losses": 65,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4595,
                            "maxTopRankPosition": 854,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:14.413Z",
                "fetchedAt": "2025-04-04T01:48:14.331Z"
            },
            "createdAt": "2025-04-03T21:26:31.829Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "422c1d4f-a4ff-4bc5-8b7d-b730c3b35da1",
                "profileId": "c996ac01-b73e-445a-9b4e-0bfddb687438",
                "displayName": "Cuqxd",
                "platform": "xbl",
                "level": 136,
                "headshotRate": 46.7393826874,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T02:30:41.860Z",
                "fetchedAt": "2025-04-04T02:30:41.759Z"
            },
            "createdAt": "2025-04-03T20:56:32.040Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "422c1d4f-a4ff-4bc5-8b7d-b730c3b35da1",
                "profileId": "422c1d4f-a4ff-4bc5-8b7d-b730c3b35da1",
                "displayName": "Goldsnake778",
                "platform": "uplay",
                "level": 136,
                "headshotRate": 46.7393826874,
                "leaderboardPosition": 2657,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1386,
                            "deaths": 819,
                            "wins": 135,
                            "losses": 70,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 4587,
                            "maxTopRankPosition": 1148,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:48:22.707Z",
                "fetchedAt": "2025-04-04T01:48:22.591Z"
            },
            "createdAt": "2025-04-03T20:56:32.040Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4f6ac95b-78cf-4219-beb4-520293a7c9d4",
                "profileId": "4f6ac95b-78cf-4219-beb4-520293a7c9d4",
                "displayName": "Monologue_me",
                "platform": "uplay",
                "level": 112,
                "headshotRate": 46.8091697646,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T18:59:15.753Z",
                "fetchedAt": "2025-04-03T18:59:15.677Z"
            },
            "createdAt": "2025-04-03T17:36:49.349Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "dc2a471e-d157-4f99-bf33-26a1e57adf1d",
                "profileId": "dc2a471e-d157-4f99-bf33-26a1e57adf1d",
                "displayName": "LIGHT_555",
                "platform": "uplay",
                "level": 117,
                "headshotRate": 45.1935624184,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T18:59:15.885Z",
                "fetchedAt": "2025-04-03T18:59:15.815Z"
            },
            "createdAt": "2025-04-03T17:26:41.626Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "af6b869e-3dbb-4176-a4c1-c0ef1c9b2ce9",
                "profileId": "af6b869e-3dbb-4176-a4c1-c0ef1c9b2ce9",
                "displayName": "SgtRape",
                "platform": "uplay",
                "level": 125,
                "headshotRate": 67.6337846551,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 243,
                            "deaths": 189,
                            "wins": 30,
                            "losses": 13,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3668,
                            "rank": "unranked",
                            "maxRank": "emerald-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T22:06:14.128Z",
                "fetchedAt": "2025-04-03T22:06:13.972Z"
            },
            "createdAt": "2025-04-03T17:16:40.987Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7594131a-5317-4d8d-a6f7-a5ca622d9c85",
                "profileId": "7594131a-5317-4d8d-a6f7-a5ca622d9c85",
                "displayName": "Awak3.",
                "platform": "uplay",
                "level": 173,
                "headshotRate": 56.1082024433,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 470,
                            "deaths": 330,
                            "wins": 53,
                            "losses": 26,
                            "abandons": 1,
                            "rankPoints": 4169,
                            "maxRankPoints": 4183,
                            "rank": "diamond-4",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-02T19:15:50.006Z",
                "fetchedAt": "2025-04-02T19:15:49.911Z"
            },
            "createdAt": "2025-04-03T17:16:40.987Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "403dcf54-634c-4a47-8fa3-8a5770c64c05",
                "profileId": "403dcf54-634c-4a47-8fa3-8a5770c64c05",
                "displayName": "DocMyAsh.",
                "platform": "uplay",
                "level": 244,
                "headshotRate": 48.6216150281,
                "leaderboardPosition": 3547,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 498,
                            "deaths": 288,
                            "wins": 84,
                            "losses": 12,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4586,
                            "maxTopRankPosition": 1176,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:02:31.048Z",
                "fetchedAt": "2025-04-04T01:02:30.933Z"
            },
            "createdAt": "2025-04-03T16:07:07.184Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b92f98da-3e11-468c-9253-7a1503f5372d",
                "profileId": "b92f98da-3e11-468c-9253-7a1503f5372d",
                "displayName": "rrm7dpda",
                "platform": "uplay",
                "level": 73,
                "headshotRate": 63.6904761905,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 199,
                            "deaths": 175,
                            "wins": 15,
                            "losses": 22,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2190,
                            "rank": "unranked",
                            "maxRank": "silver-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:07.588Z",
                "fetchedAt": "2025-04-03T16:46:07.462Z"
            },
            "createdAt": "2025-04-03T15:57:11.417Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "6dea6c3d-4dde-4abb-968b-4bf9672f3a70",
                "profileId": "6dea6c3d-4dde-4abb-968b-4bf9672f3a70",
                "displayName": "GothboyTristan",
                "platform": "uplay",
                "level": 123,
                "headshotRate": 54.1514041514,
                "leaderboardPosition": 5054,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 583,
                            "deaths": 409,
                            "wins": 58,
                            "losses": 34,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 4438,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-04T05:02:48.312Z",
                "fetchedAt": "2025-04-04T05:02:48.233Z"
            },
            "createdAt": "2025-04-03T15:47:11.773Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "39c0a64d-a83f-4927-b98b-39f55dfe6969",
                "profileId": "39c0a64d-a83f-4927-b98b-39f55dfe6969",
                "displayName": "XxStitch_19xX",
                "platform": "uplay",
                "level": 115,
                "headshotRate": 49.1459877538,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 165,
                            "deaths": 255,
                            "wins": 43,
                            "losses": 8,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4163,
                            "rank": "unranked",
                            "maxRank": "diamond-4"
                        }
                    }
                },
                "updatedAt": "2025-04-03T17:00:01.625Z",
                "fetchedAt": "2025-04-03T17:00:01.539Z"
            },
            "createdAt": "2025-04-03T15:47:11.773Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9cc23aab-8cbb-429f-be68-11a921b4d12b",
                "profileId": "bf9ab6e9-e5f0-4b17-9ada-209aa3cd7750",
                "displayName": "Letsgotop3__YT",
                "platform": "psn",
                "level": 294,
                "headshotRate": 50,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 199,
                            "deaths": 151,
                            "wins": 17,
                            "losses": 18,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2856,
                            "rank": "unranked",
                            "maxRank": "gold-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:47:47.439Z",
                "fetchedAt": "2025-04-03T16:47:47.368Z"
            },
            "createdAt": "2025-04-03T15:37:26.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9cc23aab-8cbb-429f-be68-11a921b4d12b",
                "profileId": "9cc23aab-8cbb-429f-be68-11a921b4d12b",
                "displayName": "novall87",
                "platform": "uplay",
                "level": 294,
                "headshotRate": 50,
                "leaderboardPosition": 6588,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 799,
                            "deaths": 273,
                            "wins": 85,
                            "losses": 20,
                            "abandons": 7,
                            "rankPoints": 1000,
                            "maxRankPoints": 4403,
                            "rank": "unranked",
                            "maxRank": "diamond-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:10.653Z",
                "fetchedAt": "2025-04-03T16:46:10.542Z"
            },
            "createdAt": "2025-04-03T15:37:26.542Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d4b7e4f1-8fb5-457f-a69c-20e4518d33a5",
                "profileId": "d4b7e4f1-8fb5-457f-a69c-20e4518d33a5",
                "displayName": "stolenaccee",
                "platform": "uplay",
                "level": 343,
                "headshotRate": 53.9530395626,
                "leaderboardPosition": 155,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 781,
                            "deaths": 591,
                            "wins": 140,
                            "losses": 19,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 4876,
                            "maxTopRankPosition": 81,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-04T04:21:46.710Z",
                "fetchedAt": "2025-04-04T04:21:46.579Z"
            },
            "createdAt": "2025-04-03T15:17:09.991Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "5790d998-2094-4b70-a52f-e0af845e30af",
                "profileId": "5790d998-2094-4b70-a52f-e0af845e30af",
                "displayName": "q1ny.",
                "platform": "uplay",
                "level": 282,
                "headshotRate": 53.2446661125,
                "leaderboardPosition": 4104,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 266,
                            "deaths": 296,
                            "wins": 25,
                            "losses": 39,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3315,
                            "rank": "unranked",
                            "maxRank": "platinum-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T17:00:05.349Z",
                "fetchedAt": "2025-04-03T17:00:05.266Z"
            },
            "createdAt": "2025-04-03T14:47:06.432Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1cc06b1d-ea69-432b-a4dc-c633beea4220",
                "profileId": "1cc06b1d-ea69-432b-a4dc-c633beea4220",
                "displayName": "tetoanefan",
                "platform": "uplay",
                "level": 54,
                "headshotRate": 37.9609544469,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 122,
                            "deaths": 58,
                            "wins": 13,
                            "losses": 1,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2311,
                            "rank": "unranked",
                            "maxRank": "silver-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T18:59:14.167Z",
                "fetchedAt": "2025-04-03T18:59:14.068Z"
            },
            "createdAt": "2025-04-03T13:47:08.131Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "acbfb5c1-1ed4-45fc-9f9c-83fd4f4b5ebb",
                "profileId": "acbfb5c1-1ed4-45fc-9f9c-83fd4f4b5ebb",
                "displayName": "spstchntrj",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 34.8171701113,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T19:13:39.305Z",
                "fetchedAt": "2025-04-03T19:13:39.205Z"
            },
            "createdAt": "2025-04-03T13:47:08.131Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9f9e52b7-8bba-405f-a558-ee4e86158f79",
                "profileId": "9f9e52b7-8bba-405f-a558-ee4e86158f79",
                "displayName": "Unfairlife",
                "platform": "uplay",
                "level": 128,
                "headshotRate": 57.6408787011,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 447,
                            "deaths": 301,
                            "wins": 60,
                            "losses": 17,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3986,
                            "rank": "unranked",
                            "maxRank": "emerald-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:46.729Z",
                "fetchedAt": "2025-04-03T16:46:46.600Z"
            },
            "createdAt": "2025-04-03T13:47:08.131Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4621d90e-2423-4917-8303-ca14d8a3467c",
                "profileId": "4621d90e-2423-4917-8303-ca14d8a3467c",
                "displayName": "Eqlypsy.R6",
                "platform": "uplay",
                "level": 60,
                "headshotRate": 51.6169154229,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 122,
                            "deaths": 107,
                            "wins": 15,
                            "losses": 9,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2495,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:50.721Z",
                "fetchedAt": "2025-04-03T16:46:50.545Z"
            },
            "createdAt": "2025-04-03T13:36:40.764Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8563ae51-7436-460f-a90d-dd1cab2d38ff",
                "profileId": "8563ae51-7436-460f-a90d-dd1cab2d38ff",
                "displayName": "Pvrx.",
                "platform": "uplay",
                "level": 140,
                "headshotRate": 52.4840764331,
                "seasonalRecords": {},
                "updatedAt": "2025-04-04T01:06:39.205Z",
                "fetchedAt": "2025-04-04T01:06:39.127Z"
            },
            "createdAt": "2025-04-03T13:36:40.764Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8563ae51-7436-460f-a90d-dd1cab2d38ff",
                "profileId": "4699fe44-15cf-4f48-9d91-ce4667e2f417",
                "displayName": "Mxely-",
                "platform": "psn",
                "level": 140,
                "headshotRate": 52.4840764331,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:47:03.209Z",
                "fetchedAt": "2025-04-03T16:47:03.113Z"
            },
            "createdAt": "2025-04-03T13:36:40.764Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "212acc8e-f05e-4f00-9b4e-cc55bd730be5",
                "profileId": "212acc8e-f05e-4f00-9b4e-cc55bd730be5",
                "displayName": "matix._",
                "platform": "uplay",
                "level": 125,
                "headshotRate": 63.1991449947,
                "leaderboardPosition": 100,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 164,
                            "deaths": 83,
                            "wins": 13,
                            "losses": 10,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2482,
                            "rank": "unranked",
                            "maxRank": "silver-1"
                        }
                    }
                },
                "updatedAt": "2025-04-04T05:00:55.139Z",
                "fetchedAt": "2025-04-04T05:00:55.053Z"
            },
            "createdAt": "2025-04-03T13:36:40.764Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "16a6026f-3346-4419-8929-5d267e8f64ac",
                "profileId": "16a6026f-3346-4419-8929-5d267e8f64ac",
                "displayName": "Justynewell21",
                "platform": "uplay",
                "level": 73,
                "headshotRate": 33.1152902698,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 791,
                            "deaths": 363,
                            "wins": 63,
                            "losses": 29,
                            "abandons": 4,
                            "rankPoints": 1000,
                            "maxRankPoints": 4004,
                            "rank": "unranked",
                            "maxRank": "diamond-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:03.736Z",
                "fetchedAt": "2025-04-03T16:46:03.611Z"
            },
            "createdAt": "2025-04-03T13:26:35.528Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "1d6f1b2d-7809-4d8b-b83d-d735e5736a69",
                "profileId": "1d6f1b2d-7809-4d8b-b83d-d735e5736a69",
                "displayName": "R4re.BD",
                "platform": "uplay",
                "level": 87,
                "headshotRate": 62.2244488978,
                "leaderboardPosition": 9999,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 12,
                            "deaths": 10,
                            "wins": 2,
                            "losses": 0,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1244,
                            "rank": "unranked",
                            "maxRank": "copper-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:49:11.831Z",
                "fetchedAt": "2025-04-03T16:49:11.734Z"
            },
            "createdAt": "2025-04-03T13:26:35.528Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "e1771962-1a2e-4049-b8fa-d301e9e40bae",
                "profileId": "69fdf723-b80a-48d5-b6e8-97523b90ea61",
                "displayName": "StJudeBarber",
                "platform": "xbl",
                "level": 94,
                "headshotRate": 55.0121065375,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:46:46.839Z",
                "fetchedAt": "2025-04-03T16:46:46.602Z"
            },
            "createdAt": "2025-04-03T13:26:35.528Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "8c8f80a3-f2f0-4c72-b076-4d36d36e95ed",
                "profileId": "c5159687-fb72-481e-b4dd-c5849319c688",
                "displayName": "BouncybooUwU",
                "platform": "psn",
                "level": 171,
                "headshotRate": 61.5175044272,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 46,
                            "deaths": 37,
                            "wins": 5,
                            "losses": 2,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1591,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:48:22.803Z",
                "fetchedAt": "2025-04-03T16:48:22.703Z"
            },
            "createdAt": "2025-04-03T13:26:35.528Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "b7305d5e-1e6b-4c2b-98bb-a15033f1992d",
                "profileId": "b7305d5e-1e6b-4c2b-98bb-a15033f1992d",
                "displayName": "random.m69",
                "platform": "uplay",
                "level": 23,
                "headshotRate": 97.1608832808,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T19:23:05.334Z",
                "fetchedAt": "2025-04-03T19:23:05.243Z"
            },
            "createdAt": "2025-04-03T13:16:35.226Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "0e783fc7-54e3-4aef-9e00-cbc6eeb6dd62",
                "profileId": "0e783fc7-54e3-4aef-9e00-cbc6eeb6dd62",
                "displayName": "Xekziana..",
                "platform": "uplay",
                "level": 66,
                "headshotRate": 62.1392190153,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 3,
                            "deaths": 9,
                            "wins": 0,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1000,
                            "rank": "unranked",
                            "maxRank": "copper-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T21:39:26.725Z",
                "fetchedAt": "2025-04-03T21:39:26.624Z"
            },
            "createdAt": "2025-04-03T13:16:35.226Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "719b03a7-30cd-40c4-a4bc-b433f7cbb235",
                "profileId": "719b03a7-30cd-40c4-a4bc-b433f7cbb235",
                "displayName": "wonderfultalent",
                "platform": "uplay",
                "level": 91,
                "headshotRate": 62.4100719424,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 43,
                            "deaths": 63,
                            "wins": 5,
                            "losses": 5,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1543,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:48:25.514Z",
                "fetchedAt": "2025-04-03T16:48:25.441Z"
            },
            "createdAt": "2025-04-03T13:16:35.226Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c3b15c94-9ab1-4959-b929-130123455aac",
                "profileId": "c3b15c94-9ab1-4959-b929-130123455aac",
                "displayName": "hugyember",
                "platform": "uplay",
                "level": 134,
                "headshotRate": 44.9511400651,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 114,
                            "deaths": 145,
                            "wins": 15,
                            "losses": 15,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 2037,
                            "rank": "unranked",
                            "maxRank": "silver-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:48:59.863Z",
                "fetchedAt": "2025-04-03T16:48:59.770Z"
            },
            "createdAt": "2025-04-03T13:16:35.226Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "20ad1b54-61db-4048-b6d5-a9d862ddf3f7",
                "profileId": "20ad1b54-61db-4048-b6d5-a9d862ddf3f7",
                "displayName": "creedxr",
                "platform": "uplay",
                "level": 140,
                "headshotRate": 51.6782099094,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 247,
                            "deaths": 77,
                            "wins": 25,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3700,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-04T01:50:42.492Z",
                "fetchedAt": "2025-04-04T01:50:42.383Z"
            },
            "createdAt": "2025-04-03T13:16:35.226Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "127a1a20-ec21-41f4-bb0f-fd83bf1ad823",
                "profileId": "127a1a20-ec21-41f4-bb0f-fd83bf1ad823",
                "displayName": "Domophn",
                "platform": "uplay",
                "level": 136,
                "headshotRate": 46.1038961039,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 182,
                            "deaths": 157,
                            "wins": 20,
                            "losses": 18,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1904,
                            "rank": "unranked",
                            "maxRank": "bronze-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:55.049Z",
                "fetchedAt": "2025-04-03T16:46:54.937Z"
            },
            "createdAt": "2025-04-03T13:16:35.226Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "796dc966-bab7-418c-9161-9ab2656e8a3e",
                "profileId": "796dc966-bab7-418c-9161-9ab2656e8a3e",
                "displayName": "edgawR",
                "platform": "uplay",
                "level": 59,
                "headshotRate": 58.4507042254,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:48:25.404Z",
                "fetchedAt": "2025-04-03T16:48:25.317Z"
            },
            "createdAt": "2025-04-03T10:06:57.313Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "da9fbc5e-00e6-4eef-ac6d-330d81dce234",
                "profileId": "da9fbc5e-00e6-4eef-ac6d-330d81dce234",
                "displayName": "Thmss.",
                "platform": "uplay",
                "level": 88,
                "headshotRate": 56.1301568855,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 260,
                            "deaths": 150,
                            "wins": 22,
                            "losses": 17,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1453,
                            "rank": "unranked",
                            "maxRank": "copper-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:48:29.739Z",
                "fetchedAt": "2025-04-03T16:48:29.590Z"
            },
            "createdAt": "2025-04-03T10:06:57.313Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "c45af674-60ae-40f1-b610-c0d7315e94d4",
                "profileId": "c45af674-60ae-40f1-b610-c0d7315e94d4",
                "displayName": "ZzCoringaZz6656",
                "platform": "uplay",
                "level": 71,
                "headshotRate": 52.6479750779,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:46:10.653Z",
                "fetchedAt": "2025-04-03T16:46:10.542Z"
            },
            "createdAt": "2025-04-03T10:06:57.313Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bcb7ff1c-7698-414b-b64f-67ee7b486f9c",
                "profileId": "bcb7ff1c-7698-414b-b64f-67ee7b486f9c",
                "displayName": "SlammedByWhy",
                "platform": "uplay",
                "level": 163,
                "headshotRate": 43.839093927,
                "leaderboardPosition": 8605,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 1274,
                            "deaths": 1109,
                            "wins": 151,
                            "losses": 105,
                            "abandons": 4,
                            "rankPoints": 1000,
                            "maxRankPoints": 4363,
                            "rank": "unranked",
                            "maxRank": "diamond-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T23:17:58.990Z",
                "fetchedAt": "2025-04-03T23:17:58.882Z"
            },
            "createdAt": "2025-04-03T10:06:57.313Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "34aa4eca-44ff-4b1f-8f49-e00ca6283929",
                "profileId": "34aa4eca-44ff-4b1f-8f49-e00ca6283929",
                "displayName": "OhVanny",
                "platform": "uplay",
                "level": 129,
                "headshotRate": 50.6944444444,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 25,
                            "deaths": 30,
                            "wins": 5,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 1509,
                            "rank": "unranked",
                            "maxRank": "bronze-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:51.050Z",
                "fetchedAt": "2025-04-03T16:46:50.868Z"
            },
            "createdAt": "2025-04-03T10:06:57.313Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "86e71bc2-61d4-430e-ac96-3c004dc9e6f9",
                "profileId": "86e71bc2-61d4-430e-ac96-3c004dc9e6f9",
                "displayName": "FlecksDaddy",
                "platform": "uplay",
                "level": 55,
                "headshotRate": 28.6458333333,
                "overlayUser": true,
                "overlayOnline": false,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 148,
                            "deaths": 51,
                            "wins": 14,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2349,
                            "rank": "unranked",
                            "maxRank": "silver-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T19:26:24.465Z",
                "fetchedAt": "2025-04-03T19:26:24.273Z"
            },
            "createdAt": "2025-04-03T09:56:58.708Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "057d3284-88c8-4549-9c17-49559e237c66",
                "profileId": "057d3284-88c8-4549-9c17-49559e237c66",
                "displayName": "PapaEchoo",
                "platform": "uplay",
                "level": 144,
                "headshotRate": 44.6650124069,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 288,
                            "deaths": 151,
                            "wins": 24,
                            "losses": 14,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3236,
                            "rank": "unranked",
                            "maxRank": "platinum-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:47:36.525Z",
                "fetchedAt": "2025-04-03T16:47:36.386Z"
            },
            "createdAt": "2025-04-03T09:56:58.708Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fc537d75-eced-4d3b-8abe-877fc9246ba2",
                "profileId": "0c7bb0ae-2a3f-4ec3-8fbe-93f361f59f8c",
                "displayName": "RADSFC-2024",
                "platform": "psn",
                "level": 140,
                "headshotRate": 39.746835443,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 121,
                            "deaths": 101,
                            "wins": 11,
                            "losses": 9,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 1297,
                            "rank": "unranked",
                            "maxRank": "copper-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:50.721Z",
                "fetchedAt": "2025-04-03T16:46:50.546Z"
            },
            "createdAt": "2025-04-03T09:56:58.708Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fc537d75-eced-4d3b-8abe-877fc9246ba2",
                "profileId": "fc537d75-eced-4d3b-8abe-877fc9246ba2",
                "displayName": "Fatt-e",
                "platform": "uplay",
                "level": 140,
                "headshotRate": 39.746835443,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:47:50.567Z",
                "fetchedAt": "2025-04-03T16:47:50.474Z"
            },
            "createdAt": "2025-04-03T09:56:58.708Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "458cab6c-e262-4b64-8c66-e4d8ecacd8af",
                "profileId": "458cab6c-e262-4b64-8c66-e4d8ecacd8af",
                "displayName": "Boarder.Hopper",
                "platform": "uplay",
                "level": 65,
                "headshotRate": 58.1095596133,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 257,
                            "deaths": 116,
                            "wins": 25,
                            "losses": 9,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3433,
                            "rank": "unranked",
                            "maxRank": "platinum-1"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:47:36.525Z",
                "fetchedAt": "2025-04-03T16:47:36.386Z"
            },
            "createdAt": "2025-04-03T09:46:59.961Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "fcc0fafd-2460-4065-af58-91191b3c3c11",
                "profileId": "fcc0fafd-2460-4065-af58-91191b3c3c11",
                "displayName": "Nomoremoney129",
                "platform": "uplay",
                "level": 123,
                "headshotRate": 61.1695414388,
                "overlayUser": true,
                "overlayOnline": false,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 141,
                            "deaths": 72,
                            "wins": 18,
                            "losses": 2,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3081,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T21:32:32.173Z",
                "fetchedAt": "2025-04-03T21:32:32.078Z"
            },
            "createdAt": "2025-04-03T09:46:59.961Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "985c7a8f-eecd-419b-a025-8512d92fc481",
                "profileId": "985c7a8f-eecd-419b-a025-8512d92fc481",
                "displayName": "Stmpn.M80",
                "platform": "uplay",
                "level": 60,
                "headshotRate": 39.9644760213,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 126,
                            "deaths": 60,
                            "wins": 15,
                            "losses": 3,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 2742,
                            "rank": "unranked",
                            "maxRank": "gold-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:49:11.831Z",
                "fetchedAt": "2025-04-03T16:49:11.734Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "778485fa-ca72-4238-95c2-1906be37895e",
                "profileId": "778485fa-ca72-4238-95c2-1906be37895e",
                "displayName": "alfzao",
                "platform": "uplay",
                "level": 74,
                "headshotRate": 60.303030303,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:46:58.561Z",
                "fetchedAt": "2025-04-03T16:46:58.480Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "be99b106-9de9-4646-8100-b32a3ff806fd",
                "profileId": "3ad24e97-53c1-40dc-9f17-cd5d64f0385b",
                "displayName": "xDelmaxy",
                "platform": "xbl",
                "level": 67,
                "headshotRate": 50.5732484076,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:48:35.750Z",
                "fetchedAt": "2025-04-03T16:48:35.660Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "62a0b93c-5012-451b-a57d-d4d41fea7614",
                "profileId": "62a0b93c-5012-451b-a57d-d4d41fea7614",
                "displayName": "Swyx.",
                "platform": "uplay",
                "level": 65,
                "headshotRate": 67.2926447574,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:23:38.563Z",
                "fetchedAt": "2025-04-03T16:23:38.479Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "bc3c6d1b-687b-4cf6-af8c-6dde86f86b57",
                "profileId": "bc3c6d1b-687b-4cf6-af8c-6dde86f86b57",
                "displayName": "SSupaNikaaa",
                "platform": "uplay",
                "level": 78,
                "headshotRate": 44.8979591837,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:28:58.279Z",
                "fetchedAt": "2025-04-03T16:28:58.195Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "4e0145e7-cbff-4f3b-892c-256b5ca12817",
                "profileId": "4e0145e7-cbff-4f3b-892c-256b5ca12817",
                "displayName": "woundz.",
                "platform": "uplay",
                "level": 147,
                "headshotRate": 59.5777951525,
                "leaderboardPosition": 9979,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 510,
                            "deaths": 304,
                            "wins": 42,
                            "losses": 28,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3775,
                            "rank": "unranked",
                            "maxRank": "emerald-3"
                        }
                    }
                },
                "updatedAt": "2025-04-03T21:21:06.321Z",
                "fetchedAt": "2025-04-03T21:21:06.241Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "9918b4d5-9cec-4c25-aa7d-b2b50a0fc807",
                "profileId": "9918b4d5-9cec-4c25-aa7d-b2b50a0fc807",
                "displayName": "RETIREDGYMBOY69",
                "platform": "uplay",
                "level": 97,
                "headshotRate": 67.5830469645,
                "seasonalRecords": {},
                "updatedAt": "2025-04-03T16:46:07.588Z",
                "fetchedAt": "2025-04-03T16:46:07.462Z"
            },
            "createdAt": "2025-04-03T09:36:58.428Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "eee37f64-6584-4566-a3ed-fb0ca409fb27",
                "profileId": "eee37f64-6584-4566-a3ed-fb0ca409fb27",
                "displayName": "TheAnneFlank.",
                "platform": "uplay",
                "level": 126,
                "headshotRate": 51.6013071895,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 678,
                            "deaths": 695,
                            "wins": 83,
                            "losses": 67,
                            "abandons": 1,
                            "rankPoints": 1000,
                            "maxRankPoints": 3017,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:23:38.563Z",
                "fetchedAt": "2025-04-03T16:23:38.479Z"
            },
            "createdAt": "2025-04-03T09:26:58.812Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "7c1364a2-1648-457f-981a-fb99bb697f78",
                "profileId": "7c1364a2-1648-457f-981a-fb99bb697f78",
                "displayName": "c.53",
                "platform": "uplay",
                "level": 160,
                "headshotRate": 49.6199571234,
                "leaderboardPosition": 5277,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 794,
                            "deaths": 528,
                            "wins": 112,
                            "losses": 35,
                            "abandons": 3,
                            "rankPoints": 1000,
                            "maxRankPoints": 4510,
                            "maxTopRankPosition": 3970,
                            "rank": "unranked",
                            "maxRank": "champion"
                        }
                    }
                },
                "updatedAt": "2025-04-03T19:45:36.700Z",
                "fetchedAt": "2025-04-03T19:45:36.612Z"
            },
            "createdAt": "2025-04-03T09:26:58.812Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "d2d25e9c-fdc7-48b5-81d2-e5ebd192db5d",
                "profileId": "d2d25e9c-fdc7-48b5-81d2-e5ebd192db5d",
                "displayName": "Agency.W",
                "platform": "uplay",
                "level": 190,
                "headshotRate": 54.2972699697,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 336,
                            "deaths": 49,
                            "wins": 26,
                            "losses": 2,
                            "abandons": 2,
                            "rankPoints": 1000,
                            "maxRankPoints": 3083,
                            "rank": "unranked",
                            "maxRank": "platinum-5"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:46:46.506Z",
                "fetchedAt": "2025-04-03T16:46:46.411Z"
            },
            "createdAt": "2025-04-03T09:26:58.812Z",
            "reason": "cheating"
        },
        {
            "profile": {
                "userId": "07c3d144-cca0-411d-ae0e-9daff9bf18f7",
                "profileId": "07c3d144-cca0-411d-ae0e-9daff9bf18f7",
                "displayName": "twirlnn",
                "platform": "uplay",
                "level": 95,
                "headshotRate": 62.5124626122,
                "seasonalRecords": {
                    "prep-phase": {
                        "ranked": {
                            "mode": "ranked",
                            "kills": 481,
                            "deaths": 375,
                            "wins": 67,
                            "losses": 24,
                            "abandons": 0,
                            "rankPoints": 1000,
                            "maxRankPoints": 3861,
                            "rank": "unranked",
                            "maxRank": "emerald-2"
                        }
                    }
                },
                "updatedAt": "2025-04-03T16:48:29.738Z",
                "fetchedAt": "2025-04-03T16:48:29.590Z"
            },
            "createdAt": "2025-04-03T09:16:59.713Z",
            "reason": "cheating"
        }
    ]
}
"""

# %%
import json
data2 = json.loads(data)

# %%
import pandas as pd
import numpy as np

# %%
# Extract relevant fields into a list of dictionaries
records = [
    {
        "Display Name": ban["profile"]["displayName"],
        "Platform": ban["profile"]["platform"],
        "Level": ban["profile"]["level"],
        "Headshot Rate (%)": ban["profile"]["headshotRate"],
        "Reason": ban["reason"]
    }
    for ban in data2["bans"]
]

# Convert to DataFrame
df = pd.DataFrame(records)

# Display basic statistics
summary = {
    "Total Bans": len(df),
    "Average Level": df["Level"].mean(),
    "Average Headshot Rate (%)": df["Headshot Rate (%)"].mean(),
    "Max Headshot Rate (%)": df["Headshot Rate (%)"].max(),
    "Min Headshot Rate (%)": df["Headshot Rate (%)"].min(),
    "Most Common Platform": df["Platform"].mode()[0]
}

summary_df = pd.DataFrame([summary])

# %%
summary_df
# Out:
#    Total Bans  Average Level  Average Headshot Rate (%)  \
# 0         100       30121.03                  53.009366
#
#    Max Headshot Rate (%)  Min Headshot Rate (%) Most Common Platform
# 0              97.160883              28.645833                uplay

# %%
# Updated parsing to include seasonal records if present
parsed_with_seasonal_df = pd.DataFrame([
    {
        "Display Name": entry["profile"].get("displayName"),
        "Platform": entry["profile"].get("platform"),
        "Level": entry["profile"].get("level"),
        "Headshot Rate (%)": entry["profile"].get("headshotRate"),
        "Kills": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("kills", np.nan),
        "Deaths": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("deaths", np.nan),
        "Wins": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("wins", np.nan),
        "Losses": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("losses", np.nan),
        "Abandons": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("abandons", np.nan),
        "Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rankPoints", np.nan),
        "Max Rank Points": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRankPoints", np.nan),
        "Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("rank", np.nan),
        "Max Rank": entry["profile"].get("seasonalRecords", {}).get("prep-phase", {}).get("ranked", {}).get("maxRank", np.nan),
        "Reason": entry.get("reason", "N/A")
    }
    for entry in data2['bans']
])

# %%
parsed_with_seasonal_df
# Out:
#        Display Name Platform  Level  Headshot Rate (%)  Kills  Deaths   Wins  \
# 0        netaneyuzu    uplay     62          36.920530  336.0   233.0   35.0
# 1       Depzaivcl2k    uplay     77          54.472985    NaN     NaN    NaN
# 2       Tristin9412      xbl     93          39.456282    NaN     NaN    NaN
# 3    FloppaTheBeast    uplay     53          37.854890   99.0    60.0    9.0
# 4            Fasik.    uplay     55          58.115183  103.0    62.0   12.0
# ..              ...      ...    ...                ...    ...     ...    ...
# 95  RETIREDGYMBOY69    uplay     97          67.583047    NaN     NaN    NaN
# 96    TheAnneFlank.    uplay    126          51.601307  678.0   695.0   83.0
# 97             c.53    uplay    160          49.619957  794.0   528.0  112.0
# 98         Agency.W    uplay    190          54.297270  336.0    49.0   26.0
# 99          twirlnn    uplay     95          62.512463  481.0   375.0   67.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(parsed_with_seasonal_df['Headshot Rate (%)'], edgecolor='black', bins=20)
# Out:
# (array([ 1.,  2.,  4.,  7.,  9., 12., 18., 13., 14.,  9.,  3.,  4.,  1.,
#          0.,  0.,  0.,  0.,  2.,  0.,  1.]),
#  array([28.64583333, 32.07158583, 35.49733833, 38.92309083, 42.34884332,
#         45.77459582, 49.20034832, 52.62610081, 56.05185331, 59.47760581,
#         62.90335831, 66.3291108 , 69.7548633 , 73.1806158 , 76.6063683 ,
#         80.03212079, 83.45787329, 86.88362579, 90.30937829, 93.73513078,
#         97.16088328]),
#  <BarContainer object of 20 artists>)

# %%
import json

with open('../cheater_usernames_statscc/usernames.txt', 'r') as file:
    data = json.load(file)

# %%
len(data)
# Out:
# 3

# %%
def add_usernames(df, data):
    current_append = len(data) + 1
    append_name = 'append' + f'{current_append}'
    append_list = [x for x in df['Display Name']]
    
    data[append_name] = append_list
    
    return data

# %%
data_new = add_usernames(df, data)

# %%
len(data_new)
# Out:
# 4

# %%
# Write data to file
with open('../cheater_usernames_statscc/usernames.txt', 'w') as file:
    json.dump(data_new, file, indent=1)
